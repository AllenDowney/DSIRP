# %% [markdown]
# # Chapter xx

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)

# %% [markdown]
# Here's an exercise from [Chapter 12 of Think Python](https://greenteapress.com/thinkpython/html/thinkpython013.html#toc141)
#
# > Write a program that reads a word list from a file and prints all the sets of words that are anagrams. Here is an example of what the output might look like:
#
# ```
# ['deltas', 'desalt', 'lasted', 'salted', 'slated', 'staled']
# ['retainers', 'ternaries']
# ['generating', 'greatening']
# ['resmelts', 'smelters', 'termless']
# ```
#
# > Modify the previous program so that it prints the largest set of anagrams first, followed by the second largest set, and so on.
#
# >In Scrabble a “bingo” is when you play all seven tiles in your rack, along with a letter on the board, to form an eight-letter word. What set of 8 letters forms the most possible bingos? Hint: there are seven.
#
#     Solution: http://thinkpython.com/code/anagram_sets.py.

# %%
def signature(s):
    """Returns the signature of this string.

    Signature is a string that contains all of the letters in order.

    s: string
    """
    # TODO: rewrite using sorted()
    t = list(s)
    t.sort()
    t = ''.join(t)
    return t

# %%
signature('retainers')
# Out:
# 'aeeinrrst'

# %%
signature('retainers') == signature('ternaries')
# Out:
# True

# %%
signature('retainers') == signature('canaries')
# Out:
# False

# %%
def all_anagrams(word_iterator):
    """Finds all anagrams in a list of words.

    filename: string filename of the word list

    Returns: a map from each word to a list of its anagrams.
    """
    d = {}
    for word in word_iterator:
        t = signature(word)

        # TODO: rewrite using defaultdict
        if t not in d:
            d[t] = [word]
        else:
            d[t].append(word)
    return d

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %%
def iterate_words(filename):
    """Read lines from a file and split them into words."""
    for line in open(filename):
        for word in line.split():
            yield word.strip()

# %%
anagram_dict = all_anagrams(iterate_words('american-english'))

# %%
def print_anagram_sets(d):
    """Prints the anagram sets in d.

    d: map from words to list of their anagrams
    """
    for v in d.values():
        if len(v) > 1:
            print(len(v), v)

# %%
print_anagram_sets(anagram_dict)
# Out:
# 2 ['Abner', 'Arneb']
# 2 ["Abner's", "Arneb's"]
# 2 ['Aires', 'Aries']
# 2 ["Aires's", "Aries's"]
# 2 ['Alar', 'Aral']
# 2 ["Alar's", "Aral's"]
# 2 ['Alberio', 'Albireo']
# 2 ["Alberio's", "Albireo's"]
# 2 ['Andre', 'Arden']
# 2 ["Andre's", "Arden's"]
# 2 ['Annmarie', 'Armenian']
# 2 ["Annmarie's", "Armenian's"]
# 2 ['Arno', 'Aron']
# 2 ["Arno's", "Aron's"]
# 2 ['Atari', 'Atria']
# 2 ["Atari's", "Atria's"]
# 2 ['Banneker', 'Bernanke']
# 2 ["Banneker's", "Bernanke's"]
# 2 ['Belgian', 'Bengali']
# 2 ["Belgian's", "Bengali's"]
# 2 ['Bellow', 'Bowell']
# 2 ["Bellow's", "Bowell's"]
# 2 ['Bert', 'Bret']
# 2 ["Bert's", "Bret's"]
# 2 ['Biogen', 'Boeing']
# 2 ["Biogen's", "Boeing's"]
# 2 ['Booker', 'Brooke']
# 2 ["Booker's", "Brooke's"]
# 2 ['Born', 'Brno']
# 2 ["Born's", "Brno's"]
# 2 ['Brain', 'Brian']
# 2 ["Brain's", "Brian's"]
# 2 ['Branden', 'Brendan']
# 2 ["Branden's", "Brendan's"]
# 2 ['Breton', 'Bronte']
# 2 ["Breton's", "Bronte's"]
# 2 ['Brut', 'Burt']
# 2 ["Brut's", "Burt's"]
# 2 ['Bryon', 'Byron']
# 2 ["Bryon's", "Byron's"]
# 2 ['Callisto', 'Castillo']
# 2 ["Callisto's", "Castillo's"]
# 2 ['Canon', 'Conan']
# 2 ["Canon's", "Conan's"]
# 2 ['Cantor', 'Carnot']
# 2 ["Cantor's", "Carnot's"]
# 2 ['Carla', 'Clara']
# 2 ["Carla's", "Clara's"]
# 2 ['Carlo', 'Carol']
# 2 ["Carlo's", "Carol's"]
# 2 ['Carmine', 'Crimean']
# 2 ["Carmine's", "Crimean's"]
# 2 ['Caroline', 'Cornelia']
# 2 ["Caroline's", "Cornelia's"]
# 2 ['Carter', 'Crater']
# 2 ["Carter's", "Crater's"]
# 2 ['Cary', 'Cray']
# 2 ["Cary's", "Cray's"]
# 3 ['Castor', 'Castro', 'Croats']
# 2 ["Castor's", "Castro's"]
# 2 ['Ceylon', 'Conley']
# 2 ["Ceylon's", "Conley's"]
# 2 ['Chaitin', 'Chianti']
# 2 ["Chaitin's", "Chianti's"]
# 2 ['Christian', 'Christina']
# 2 ["Christian's", "Christina's"]
# 2 ['Clemons', 'Clemson']
# 2 ["Clemons's", "Clemson's"]
# 2 ['Cleo', 'Cole']
# 2 ["Cleo's", "Cole's"]
# 2 ['Dali', 'Dial']
# 2 ["Dali's", "Dial's"]
# 2 ['Dalian', 'Danial']
# 2 ["Dalian's", "Danial's"]
# 3 ['Dane', 'Dean', 'Dena']
# 3 ["Dane's", "Dean's", "Dena's"]
# 2 ['Dannie', 'Dianne']
# 2 ["Dannie's", "Dianne's"]
# 2 ['Dino', 'Dion']
# 2 ["Dino's", "Dion's"]
# 2 ['Dionne', 'Donnie']
# 2 ["Dionne's", "Donnie's"]
# 2 ['Dunbar', 'Durban']
# 2 ["Dunbar's", "Durban's"]
# 2 ['Earnest', 'Eastern']
# 2 ['Eire', 'Erie']
# 2 ["Eire's", "Erie's"]
# 2 ['Elam', 'Elma']
# 2 ["Elam's", "Elma's"]
# 2 ['Elanor', 'Elnora']
# 2 ["Elanor's", "Elnora's"]
# 2 ['Elias', 'Elisa']
# 2 ["Elias's", "Elisa's"]
# 2 ['Elise', 'Elsie']
# 2 ["Elise's", "Elsie's"]
# 2 ['Eliseo', 'Eloise']
# 2 ["Eliseo's", "Eloise's"]
# 2 ['Fannie', 'Fenian']
# 2 ["Fannie's", "Fenian's"]
# 2 ['Forest', 'Foster']
# 2 ["Forest's", "Foster's"]
# 2 ['Forrest', 'Forster']
# 2 ["Forrest's", "Forster's"]
# 2 ['Freida', 'Frieda']
# 2 ["Freida's", "Frieda's"]
# 2 ['Frey', 'Frye']
# 2 ["Frey's", "Frye's"]
# 2 ['Gael', 'Gale']
# 2 ["Gael's", "Gale's"]
# 2 ['Gail', 'Gila']
# 2 ["Gail's", "Gila's"]
# 2 ['Gary', 'Gray']
# 2 ["Gary's", "Gray's"]
# 2 ['Georgian', 'Georgina']
# 2 ["Georgian's", "Georgina's"]
# 2 ['Handy', 'Haydn']
# 2 ["Handy's", "Haydn's"]
# 2 ['Hardy', 'Hydra']
# 2 ["Hardy's", "Hydra's"]
# 2 ['Ian', 'Ina']
# 2 ["Ian's", "Ina's"]
# 2 ['Jaime', 'Jamie']
# 2 ["Jaime's", "Jamie's"]
# 2 ['Jane', 'Jean']
# 2 ["Jane's", "Jean's"]
# 2 ['Janine', 'Jannie']
# 2 ["Janine's", "Jannie's"]
# 2 ['Jason', 'Jonas']
# 2 ["Jason's", "Jonas's"]
# 2 ['Jeanine', 'Jeannie']
# 2 ["Jeanine's", "Jeannie's"]
# 2 ['Jeffery', 'Jeffrey']
# 2 ["Jeffery's", "Jeffrey's"]
# 2 ['Keith', 'Kieth']
# 2 ["Keith's", "Kieth's"]
# 2 ['Kirsten', 'Kristen']
# 2 ["Kirsten's", "Kristen's"]
# 2 ['Klein', 'Kline']
# 2 ["Klein's", "Kline's"]
# 2 ['Laius', 'Luisa']
# 2 ["Laius's", "Luisa's"]
# 3 ['Lane', 'Lean', 'Lena']
# 3 ["Lane's", "Lean's", "Lena's"]
# 2 ['Lauri', 'Luria']
# 2 ["Lauri's", "Luria's"]
# 2 ['Leila', 'Lelia']
# 2 ["Leila's", "Lelia's"]
# 2 ['Lenny', 'Lynne']
# 2 ["Lenny's", "Lynne's"]
# 2 ['Leno', 'Leon']
# 2 ["Leno's", "Leon's"]
# 2 ['Lenora', 'Lorena']
# 2 ["Lenora's", "Lorena's"]
# 2 ['Lenore', 'Lorene']
# 2 ["Lenore's", "Lorene's"]
# 2 ['Loire', 'Lorie']
# 2 ["Loire's", "Lorie's"]
# 3 ['Mabel', 'Mable', 'Melba']
# 3 ["Mabel's", "Mable's", "Melba's"]
# 2 ['Mai', 'Mia']
# 2 ["Mai's", "Mia's"]
# 2 ['Malian', 'Manila']
# 2 ["Malian's", "Manila's"]
# 2 ['Malians', 'Manilas']
# 2 ['Maoism', 'Mimosa']
# 2 ["Maoism's", "Mimosa's"]
# 3 ['Maori', 'Mario', 'Moira']
# 3 ["Maori's", "Mario's", "Moira's"]
# 2 ['Marat', 'Marta']
# 2 ["Marat's", "Marta's"]
# 2 ['Marcie', 'Mercia']
# 2 ["Marcie's", "Mercia's"]
# 2 ['Mari', 'Mira']
# 2 ["Mari's", "Mira's"]
# 2 ['Marian', 'Marina']
# 2 ["Marian's", "Marina's"]
# 2 ['Marlon', 'Molnar']
# 2 ["Marlon's", "Molnar's"]
# 2 ['Martian', 'Martina']
# 2 ["Martian's", "Martina's"]
# 2 ['Mary', 'Myra']
# 2 ["Mary's", "Myra's"]
# 2 ['Maseru', 'Mauser']
# 2 ["Maseru's", "Mauser's"]
# 2 ['Meade', 'Medea']
# 2 ["Meade's", "Medea's"]
# 2 ['Michael', 'Micheal']
# 2 ["Michael's", "Micheal's"]
# 2 ['Monet', 'Monte']
# 2 ["Monet's", "Monte's"]
# 2 ['Monroe', 'Moreno']
# 2 ["Monroe's", "Moreno's"]
# 2 ['Moor', 'Moro']
# 2 ["Moor's", "Moro's"]
# 2 ['Neil', 'Nile']
# 2 ["Neil's", "Nile's"]
# 2 ['Neo', 'Noe']
# 2 ["Neo's", "Noe's"]
# 2 ['Nobel', 'Noble']
# 2 ["Nobel's", "Noble's"]
# 2 ['Palau', 'Paula']
# 2 ["Palau's", "Paula's"]
# 2 ['Paris', 'Parsi']
# 2 ["Paris's", "Parsi's"]
# 2 ['Peel', 'Pele']
# 2 ["Peel's", "Pele's"]
# 2 ['Ramon', 'Roman']
# 2 ["Ramon's", "Roman's"]
# 2 ['Regor', 'Roger']
# 2 ["Regor's", "Roger's"]
# 2 ['Reid', 'Ride']
# 2 ["Reid's", "Ride's"]
# 2 ['Roach', 'Rocha']
# 2 ["Roach's", "Rocha's"]
# 2 ['Roland', 'Ronald']
# 2 ["Roland's", "Ronald's"]
# 2 ['Rosanne', 'Roseann']
# 2 ["Rosanne's", "Roseann's"]
# 2 ['Saar', 'Sara']
# 2 ["Saar's", "Sara's"]
# 2 ['Sakha', 'Shaka']
# 2 ["Sakha's", "Shaka's"]
# 2 ['Salem', 'Selma']
# 2 ["Salem's", "Selma's"]
# 2 ['Santa', 'Satan']
# 2 ["Santa's", "Satan's"]
# 2 ['Sedna', 'Snead']
# 2 ["Sedna's", "Snead's"]
# 2 ['Serpens', 'Spenser']
# 2 ["Serpens's", "Spenser's"]
# 2 ['Seton', 'Stone']
# 2 ["Seton's", "Stone's"]
# 2 ['Sharpe', 'Sherpa']
# 2 ["Sharpe's", "Sherpa's"]
# 2 ['Sheila', 'Shelia']
# 2 ["Sheila's", "Shelia's"]
# 2 ['Shetland', 'Stendhal']
# 2 ["Shetland's", "Stendhal's"]
# 2 ['Sibyl', 'Sybil']
# 2 ["Sibyl's", "Sybil's"]
# 2 ['Stein', 'Stine']
# 2 ["Stein's", "Stine's"]
# 2 ['Sumerian', 'Suriname']
# 2 ["Sumerian's", "Suriname's"]
# 2 ['Thais', 'Tisha']
# 2 ['Titus', 'Tutsi']
# 2 ["Titus's", "Tutsi's"]
# 2 ['Tory', 'Troy']
# 2 ["Tory's", "Troy's"]
# 2 ['Trey', 'Tyre']
# 2 ["Trey's", "Tyre's"]
# 2 ['Tucson', 'Tuscon']
# 2 ["Tucson's", "Tuscon's"]
# 2 ['Valarie', 'Valeria']
# 2 ["Valarie's", "Valeria's"]
# 2 ['Warner', 'Warren']
# 2 ["Warner's", "Warren's"]
# 2 ['Wiley', 'Wylie']
# 2 ["Wiley's", "Wylie's"]
# 2 ['Yates', 'Yeats']
# 2 ["Yates's", "Yeats's"]
# 2 ['abeam', 'ameba']
# 3 ['abed', 'bade', 'bead']
# 4 ['abet', 'bate', 'beat', 'beta']
# 6 ['abets', 'baste', 'bates', 'beast', 'beats', 'betas']
# 2 ['abhorred', 'harbored']
# 2 ['abhorring', 'harboring']
# 2 ['abides', 'biased']
# 2 ['able', 'bale']
# 2 ['abler', 'blare']
# 4 ['ablest', 'bleats', 'stable', 'tables']
# 2 ['aboard', 'abroad']
# 2 ['abode', 'adobe']
# 2 ["abode's", "adobe's"]
# 2 ['abodes', 'adobes']
# 2 ['abridge', 'brigade']
# 2 ['abridges', 'brigades']
# 2 ['abuse', 'beaus']
# 3 ['abut', 'tabu', 'tuba']
# 3 ['abuts', 'tabus', 'tubas']
# 2 ['accouterments', 'accoutrements']
# 2 ['accrual', 'caracul']
# 2 ["accrual's", "caracul's"]
# 2 ['accrues', 'accuser']
# 2 ['aces', 'case']
# 2 ['ache', 'each']
# 2 ['aches', 'chase']
# 3 ['acme', 'came', 'mace']
# 2 ["acme's", "mace's"]
# 2 ['acmes', 'maces']
# 2 ['acne', 'cane']
# 2 ["acne's", "cane's"]
# 2 ['aconites', 'canoeist']
# 3 ['acre', 'care', 'race']
# 3 ["acre's", "care's", "race's"]
# 4 ['acres', 'cares', 'races', 'scare']
# 2 ['acrider', 'carried']
# 2 ['act', 'cat']
# 2 ["act's", "cat's"]
# 2 ['acted', 'cadet']
# 2 ['action', 'cation']
# 2 ["action's", "cation's"]
# 2 ['actions', 'cations']
# 4 ['actors', 'castor', 'costar', 'scrota']
# 3 ['actress', 'casters', 'recasts']
# 4 ['acts', 'cast', 'cats', 'scat']
# 2 ['actuator', 'autocrat']
# 2 ["actuator's", "autocrat's"]
# 2 ['actuators', 'autocrats']
# 2 ['acuter', 'curate']
# 2 ['add', 'dad']
# 3 ['adder', 'dared', 'dread']
# 2 ["adder's", "dread's"]
# 3 ['adders', 'dreads', 'sadder']
# 2 ['addle', 'laded']
# 2 ['addles', 'saddle']
# 2 ['adds', 'dads']
# 2 ['adept', 'taped']
# 2 ['adepts', 'pasted']
# 2 ['adhere', 'header']
# 2 ['adhered', 'redhead']
# 3 ['adheres', 'headers', 'sheared']
# 2 ['adjuster', 'readjust']
# 2 ['adjusters', 'readjusts']
# 3 ['admen', 'amend', 'named']
# 2 ['admirer', 'married']
# 2 ["admirer's", "married's"]
# 2 ['admirers', 'marrieds']
# 3 ['admires', 'misread', 'sidearm']
# 2 ['admits', 'amidst']
# 2 ['admonition', 'domination']
# 2 ["admonition's", "domination's"]
# 2 ['adore', 'oared']
# 2 ['adores', 'soared']
# 2 ['adorn', 'radon']
# 3 ['adroitly', 'dilatory', 'idolatry']
# 2 ['ads', 'sad']
# 2 ['advances', 'canvased']
# 2 ['adverb', 'braved']
# 2 ['adverts', 'starved']
# 2 ['advise', 'visaed']
# 2 ['adze', 'daze']
# 2 ["adze's", "daze's"]
# 2 ['adzes', 'dazes']
# 2 ['aeries', 'easier']
# 2 ['aery', 'year']
# 2 ["aery's", "year's"]
# 2 ['affair', 'raffia']
# 2 ["affair's", "raffia's"]
# 2 ['afield', 'failed']
# 2 ['aft', 'fat']
# 2 ['afterwords', 'forwardest']
# 2 ['agar', 'raga']
# 2 ["agar's", "raga's"]
# 2 ['ageism', 'images']
# 2 ['ages', 'sage']
# 2 ['aging', 'nigga']
# 2 ["aging's", "nigga's"]
# 2 ['agings', 'niggas']
# 2 ['agism', 'sigma']
# 3 ['agnostic', 'coasting', 'coatings']
# 2 ['agree', 'eager']
# 2 ['agreed', 'geared']
# 2 ['agrees', 'grease']
# 2 ['ah', 'ha']
# 2 ['aide', 'idea']
# 2 ["aide's", "idea's"]
# 3 ['aides', 'aside', 'ideas']
# 3 ['aids', 'dais', 'said']
# 2 ['ailed', 'ideal']
# 2 ['ailments', 'manliest']
# 2 ['ails', 'sail']
# 2 ['aimed', 'media']
# 3 ['airings', 'arising', 'raising']
# 2 ['airless', 'serials']
# 2 ['airman', 'marina']
# 2 ["airman's", "marina's"]
# 3 ['airmen', 'marine', 'remain']
# 2 ['airs', 'sari']
# 2 ['aisles', 'lassie']
# 2 ['ajar', 'raja']
# 2 ['alarming', 'marginal']
# 2 ['alarmingly', 'marginally']
# 2 ['alb', 'lab']
# 2 ["alb's", "lab's"]
# 3 ['albs', 'labs', 'slab']
# 2 ['alcove', 'coeval']
# 2 ["alcove's", "coeval's"]
# 2 ['alcoves', 'coevals']
# 2 ['ale', 'lea']
# 2 ["ale's", "lea's"]
# 3 ['alert', 'alter', 'later']
# 4 ['alerted', 'altered', 'related', 'treadle']
# 5 ['alerting', 'altering', 'integral', 'relating', 'triangle']
# 4 ['alerts', 'alters', 'salter', 'staler']
# 4 ['ales', 'leas', 'sale', 'seal']
# 2 ['alga', 'gala']
# 2 ["alga's", "gala's"]
# 2 ['algorithm', 'logarithm']
# 2 ["algorithm's", "logarithm's"]
# 2 ['algorithmic', 'logarithmic']
# 2 ['algorithms', 'logarithms']
# 2 ['alien', 'aline']
# 3 ['aliens', 'alines', 'saline']
# 3 ['aligned', 'dealing', 'leading']
# 2 ['alignment', 'lamenting']
# 2 ['aligns', 'signal']
# 3 ['alined', 'denial', 'nailed']
# 2 ['alinement', 'lineament']
# 2 ["alinement's", "lineament's"]
# 2 ['alinements', 'lineaments']
# 2 ['alining', 'nailing']
# 2 ['alit', 'tail']
# 2 ['allergies', 'galleries']
# 4 ['allergy', 'gallery', 'largely', 'regally']
# 2 ["allergy's", "gallery's"]
# 2 ['allot', 'atoll']
# 2 ['allots', 'atolls']
# 2 ['allotted', 'totalled']
# 2 ['allotting', 'totalling']
# 2 ['allover', 'overall']
# 2 ['allows', 'sallow']
# 2 ['alloy', 'loyal']
# 2 ['allure', 'laurel']
# 2 ["allure's", "laurel's"]
# 2 ['allures', 'laurels']
# 3 ['alms', 'lams', 'slam']
# 2 ["alms's", "slam's"]
# 2 ['aloft', 'float']
# 2 ['altars', 'astral']
# 2 ['altho', 'loath']
# 2 ['altitude', 'latitude']
# 2 ["altitude's", "latitude's"]
# 2 ['altitudes', 'latitudes']
# 2 ['altruism', 'muralist']
# 2 ["altruism's", "muralist's"]
# 2 ['alum', 'maul']
# 2 ["alum's", "maul's"]
# 2 ['alumna', 'manual']
# 2 ["alumna's", "manual's"]
# 2 ['alums', 'mauls']
# 2 ['am', 'ma']
# 2 ['amble', 'blame']
# 2 ["amble's", "blame's"]
# 4 ['ambled', 'bedlam', 'blamed', 'lambed']
# 2 ['ambles', 'blames']
# 3 ['ambling', 'blaming', 'lambing']
# 4 ['amen', 'mane', 'mean', 'name']
# 2 ['amenity', 'anytime']
# 2 ['amid', 'maid']
# 2 ['among', 'mango']
# 2 ['amortize', 'atomizer']
# 2 ['amortizes', 'atomizers']
# 2 ['amp', 'map']
# 2 ["amp's", "map's"]
# 2 ['amphitheater', 'amphitheatre']
# 2 ["amphitheater's", "amphitheatre's"]
# 2 ['amphitheaters', 'amphitheatres']
# 2 ['ample', 'maple']
# 2 ['amply', 'palmy']
# 3 ['amps', 'maps', 'spam']
# 2 ['amuses', 'assume']
# 2 ['anapest', 'peasant']
# 2 ["anapest's", "peasant's"]
# 2 ['anapests', 'peasants']
# 2 ['ancestries', 'resistance']
# 2 ['ancienter', 'nectarine']
# 3 ['ancients', 'canniest', 'instance']
# 2 ['anemic', 'cinema']
# 3 ['anew', 'wane', 'wean']
# 3 ['angel', 'angle', 'glean']
# 2 ["angel's", "angle's"]
# 3 ['angels', 'angles', 'gleans']
# 2 ['anger', 'range']
# 2 ["anger's", "range's"]
# 5 ['angered', 'derange', 'enraged', 'grandee', 'grenade']
# 2 ['angering', 'enraging']
# 2 ['angers', 'ranges']
# 2 ['angled', 'dangle']
# 4 ['angrier', 'earring', 'rangier', 'rearing']
# 5 ['angriest', 'gantries', 'ingrates', 'rangiest', 'tasering']
# 2 ['angry', 'rangy']
# 3 ['angst', 'gnats', 'tangs']
# 3 ['ankh', 'hank', 'khan']
# 3 ["ankh's", "hank's", "khan's"]
# 4 ['ankhs', 'hanks', 'khans', 'shank']
# 2 ['anklets', 'lankest']
# 2 ['annoyed', 'anodyne']
# 2 ['annuities', 'insinuate']
# 2 ['anoint', 'nation']
# 2 ['anoints', 'nations']
# 2 ['answers', 'rawness']
# 2 ['ant', 'tan']
# 2 ["ant's", "tan's"]
# 2 ['antagonist', 'stagnation']
# 2 ["antagonist's", "stagnation's"]
# 2 ['ante', 'neat']
# 3 ['anteing', 'antigen', 'gentian']
# 2 ['anthologies', 'theologians']
# 2 ['antidotes', 'stationed']
# 2 ["antigen's", "gentian's"]
# 2 ['antigens', 'gentians']
# 2 ['antiparticles', 'paternalistic']
# 4 ['antis', 'saint', 'satin', 'stain']
# 3 ['antler', 'learnt', 'rental']
# 2 ["antler's", "rental's"]
# 2 ['antlers', 'rentals']
# 2 ['ants', 'tans']
# 2 ['anvils', 'silvan']
# 2 ['any', 'nay']
# 2 ['ape', 'pea']
# 2 ["ape's", "pea's"]
# 3 ['apes', 'apse', 'peas']
# 2 ['aplenty', 'penalty']
# 2 ['appal', 'papal']
# 2 ['appealing', 'lagniappe']
# 2 ['append', 'napped']
# 2 ['appends', 'snapped']
# 2 ['appraised', 'disappear']
# 2 ['apprise', 'sappier']
# 2 ['apps', 'paps']
# 2 ['aprons', 'parson']
# 3 ['apt', 'pat', 'tap']
# 3 ['apter', 'prate', 'taper']
# 2 ['arc', 'car']
# 2 ["arc's", "car's"]
# 5 ['arced', 'cadre', 'cared', 'cedar', 'raced']
# 2 ['arch', 'char']
# 2 ["arch's", "char's"]
# 2 ['archaism', 'charisma']
# 2 ["archaism's", "charisma's"]
# 3 ['arches', 'chaser', 'search']
# 2 ['archest', 'chaster']
# 2 ['arching', 'chagrin']
# 3 ['arcing', 'caring', 'racing']
# 2 ['arcked', 'racked']
# 2 ['arcking', 'racking']
# 3 ['arcs', 'cars', 'scar']
# 2 ['ardent', 'ranted']
# 3 ['are', 'ear', 'era']
# 3 ["are's", "ear's", "era's"]
# 5 ['ares', 'ears', 'eras', 'sear', 'sera']
# 3 ['argon', 'groan', 'organ']
# 3 ["argon's", "groan's", "organ's"]
# 2 ['argue', 'auger']
# 2 ['argues', 'augers']
# 2 ['arid', 'raid']
# 2 ['arise', 'raise']
# 2 ['arises', 'raises']
# 3 ['arm', 'mar', 'ram']
# 2 ["arm's", "ram's"]
# 2 ['armadas', 'madrasa']
# 2 ['armed', 'dream']
# 2 ['armfuls', 'armsful']
# 2 ['arming', 'margin']
# 2 ['armpit', 'impart']
# 2 ['armpits', 'imparts']
# 2 ['armrest', 'smarter']
# 3 ['arms', 'mars', 'rams']
# 3 ['arrest', 'rarest', 'raster']
# 3 ['arrested', 'retreads', 'serrated']
# 2 ['arrogant', 'tarragon']
# 3 ['arson', 'roans', 'sonar']
# 2 ["arson's", "sonar's"]
# 3 ['art', 'rat', 'tar']
# 3 ["art's", "rat's", "tar's"]
# 2 ['article', 'recital']
# 2 ["article's", "recital's"]
# 2 ['articles', 'recitals']
# 4 ['artiest', 'artiste', 'attires', 'tastier']
# 2 ['artisan', 'tsarina']
# 2 ["artisan's", "tsarina's"]
# 2 ['artisans', 'tsarinas']
# 3 ['artist', 'strait', 'traits']
# 2 ["artist's", "strait's"]
# 2 ['artistes', 'artsiest']
# 2 ['artists', 'straits']
# 5 ['arts', 'rats', 'star', 'tars', 'tsar']
# 2 ['artsier', 'tarries']
# 4 ['artsy', 'satyr', 'stray', 'trays']
# 2 ['arty', 'tray']
# 2 ['ascend', 'dances']
# 3 ['ascent', 'enacts', 'stance']
# 2 ["ascent's", "stance's"]
# 2 ['ascents', 'stances']
# 2 ['ascertain', 'sectarian']
# 2 ['ascertains', 'sectarians']
# 4 ['ascot', 'coast', 'coats', 'tacos']
# 2 ["ascot's", "coast's"]
# 2 ['ascots', 'coasts']
# 2 ['ascribed', 'carbides']
# 2 ['ash', 'has']
# 3 ['ashed', 'heads', 'shade']
# 2 ['ashore', 'hoarse']
# 2 ['ashy', 'hays']
# 2 ['asides', 'daises']
# 2 ['askew', 'wakes']
# 3 ['asleep', 'elapse', 'please']
# 4 ['asp', 'pas', 'sap', 'spa']
# 3 ["asp's", "sap's", "spa's"]
# 3 ['aspen', 'napes', 'panes']
# 2 ['aspirant', 'partisan']
# 2 ["aspirant's", "partisan's"]
# 2 ['aspirants', 'partisans']
# 2 ['aspirate', 'parasite']
# 2 ["aspirate's", "parasite's"]
# 2 ['aspirated', 'disparate']
# 2 ['aspirates', 'parasites']
# 3 ['aspire', 'praise', 'spirea']
# 4 ['aspired', 'despair', 'diapers', 'praised']
# 3 ['aspires', 'praises', 'spireas']
# 2 ['aspiring', 'praising']
# 4 ['asps', 'pass', 'saps', 'spas']
# 2 ['assaying', 'gainsays']
# 2 ['assent', 'sanest']
# 4 ['assert', 'asters', 'stares', 'tasers']
# 2 ['assess', 'sasses']
# 3 ['asset', 'sates', 'seats']
# 2 ['assigns', 'sassing']
# 2 ['assort', 'roasts']
# 2 ['assorting', 'organists']
# 2 ['assuage', 'sausage']
# 2 ['assuages', 'sausages']
# 6 ['aster', 'rates', 'stare', 'tares', 'taser', 'tears']
# 3 ["aster's", "stare's", "taser's"]
# 2 ['astern', 'sterna']
# 3 ['astir', 'sitar', 'stair']
# 3 ['astride', 'staider', 'tirades']
# 2 ['astute', 'statue']
# 2 ['astuter', 'stature']
# 2 ['astutest', 'statutes']
# 4 ['ate', 'eat', 'eta', 'tea']
# 2 ['ateliers', 'earliest']
# 2 ['atheists', 'hastiest']
# 2 ['atom', 'moat']
# 2 ["atom's", "moat's"]
# 2 ['atoms', 'moats']
# 2 ['atone', 'oaten']
# 2 ['atoned', 'donate']
# 2 ['atria', 'tiara']
# 2 ['attentive', 'tentative']
# 2 ['attentively', 'tentatively']
# 2 ['attic', 'tacit']
# 2 ['attics', 'static']
# 2 ['attuned', 'taunted']
# 2 ['attunes', 'tetanus']
# 2 ['attuning', 'taunting']
# 2 ['auction', 'caution']
# 2 ["auction's", "caution's"]
# 3 ['auctioned', 'cautioned', 'education']
# 2 ['auctioning', 'cautioning']
# 2 ['auctions', 'cautions']
# 2 ['aunt', 'tuna']
# 2 ["aunt's", "tuna's"]
# 2 ['aunts', 'tunas']
# 2 ['austerer', 'treasure']
# 2 ['avails', 'saliva']
# 2 ['avarice', 'caviare']
# 2 ["avarice's", "caviare's"]
# 2 ['avenger', 'engrave']
# 2 ['avengers', 'engraves']
# 2 ['aver', 'rave']
# 3 ['avers', 'raves', 'saver']
# 3 ['averts', 'starve', 'vaster']
# 2 ['avid', 'diva']
# 2 ['awed', 'wade']
# 2 ['awl', 'law']
# 2 ["awl's", "law's"]
# 3 ['awls', 'laws', 'slaw']
# 2 ['awning', 'waning']
# 2 ['awry', 'wary']
# 2 ['aye', 'yea']
# 2 ["aye's", "yea's"]
# 3 ['ayes', 'easy', 'yeas']
# 2 ['babbled', 'blabbed']
# 2 ['babbling', 'blabbing']
# 2 ['babiest', 'tabbies']
# 2 ['backrest', 'brackets']
# 2 ['backward', 'drawback']
# 2 ['backwards', 'drawbacks']
# 2 ['bacterial', 'calibrate']
# 2 ['bad', 'dab']
# 2 ["bad's", "dab's"]
# 3 ['badger', 'barged', 'garbed']
# 2 ['bag', 'gab']
# 2 ["bag's", "gab's"]
# 2 ['bagel', 'gable']
# 2 ["bagel's", "gable's"]
# 2 ['bagels', 'gables']
# 2 ['bags', 'gabs']
# 2 ['bails', 'basil']
# 2 ['bake', 'beak']
# 2 ["bake's", "beak's"]
# 3 ['baker', 'brake', 'break']
# 3 ["baker's", "brake's", "break's"]
# 3 ['bakers', 'brakes', 'breaks']
# 2 ['bakes', 'beaks']
# 2 ['balder', 'blared']
# 3 ['baldest', 'blasted', 'stabled']
# 2 ['baled', 'blade']
# 2 ['baleen', 'enable']
# 2 ['bales', 'sable']
# 2 ['ballsier', 'liberals']
# 2 ['balm', 'lamb']
# 2 ["balm's", "lamb's"]
# 2 ['balms', 'lambs']
# 2 ['balsa', 'basal']
# 2 ['ban', 'nab']
# 2 ['banalities', 'insatiable']
# 2 ['bandier', 'brained']
# 2 ['bane', 'bean']
# 2 ["bane's", "bean's"]
# 2 ['banes', 'beans']
# 2 ['bans', 'nabs']
# 2 ['bantams', 'batsman']
# 2 ['bar', 'bra']
# 2 ["bar's", "bra's"]
# 3 ['bard', 'brad', 'drab']
# 3 ["bard's", "brad's", "drab's"]
# 3 ['bards', 'brads', 'drabs']
# 2 ['bare', 'bear']
# 4 ['bared', 'beard', 'bread', 'debar']
# 3 ['barely', 'barley', 'bleary']
# 5 ['bares', 'baser', 'bears', 'saber', 'sabre']
# 2 ['barest', 'breast']
# 2 ['bargained', 'gabardine']
# 2 ['barging', 'garbing']
# 3 ['barked', 'braked', 'debark']
# 2 ['barking', 'braking']
# 2 ['barn', 'bran']
# 2 ["barn's", "bran's"]
# 2 ['bars', 'bras']
# 2 ['based', 'beads']
# 2 ['basely', 'belays']
# 3 ['basest', 'bastes', 'beasts']
# 2 ['basis', 'bassi']
# 4 ['bast', 'bats', 'stab', 'tabs']
# 2 ["bast's", "stab's"]
# 2 ['bastion', 'obtains']
# 2 ['bat', 'tab']
# 2 ["bat's", "tab's"]
# 2 ['bather', 'breath']
# 2 ["bather's", "breath's"]
# 2 ['bathers', 'breaths']
# 3 ['battier', 'biretta', 'terabit']
# 2 ['battle', 'tablet']
# 2 ["battle's", "tablet's"]
# 2 ['battles', 'tablets']
# 2 ['baud', 'daub']
# 2 ["baud's", "daub's"]
# 2 ['bauds', 'daubs']
# 2 ['bayed', 'beady']
# 2 ['beadiest', 'diabetes']
# 2 ["beard's", "bread's"]
# 2 ['bearded', 'breaded']
# 2 ['bearding', 'breading']
# 3 ['beards', 'breads', 'debars']
# 3 ['beastlier', 'bleariest', 'liberates']
# 2 ["beat's", "beta's"]
# 3 ['beater', 'berate', 'rebate']
# 2 ["beater's", "rebate's"]
# 3 ['beaters', 'berates', 'rebates']
# 2 ['beavered', 'bereaved']
# 2 ['beavering', 'bereaving']
# 2 ['bed', 'deb']
# 2 ["bed's", "deb's"]
# 2 ['bedroom', 'boredom']
# 2 ["bedroom's", "boredom's"]
# 2 ['beds', 'debs']
# 2 ['bedsore', 'sobered']
# 2 ['beeches', 'beseech']
# 2 ['beefier', 'freebie']
# 2 ['beets', 'beset']
# 3 ['begin', 'being', 'binge']
# 3 ['begins', 'beings', 'binges']
# 2 ['begrudge', 'debugger']
# 2 ['begrudges', 'debuggers']
# 2 ["being's", "binge's"]
# 2 ['belated', 'bleated']
# 2 ['belied', 'edible']
# 2 ['bellied', 'libeled']
# 3 ['below', 'bowel', 'elbow']
# 2 ['belts', 'blest']
# 3 ['berated', 'debater', 'rebated']
# 2 ['berating', 'rebating']
# 2 ['berthing', 'brighten']
# 2 ['besoms', 'emboss']
# 2 ['best', 'bets']
# 2 ['bestiary', 'sybarite']
# 2 ["bestiary's", "sybarite's"]
# 2 ['bestir', 'tribes']
# 2 ['betided', 'debited']
# 2 ['betiding', 'debiting']
# 2 ['bidder', 'birded']
# 2 ['bidet', 'debit']
# 2 ["bidet's", "debit's"]
# 2 ['bidets', 'debits']
# 2 ['bin', 'nib']
# 2 ["bin's", "nib's"]
# 2 ['binary', 'brainy']
# 3 ['binder', 'inbred', 'rebind']
# 2 ['binders', 'rebinds']
# 2 ['bins', 'nibs']
# 2 ['bipedal', 'piebald']
# 2 ['bipolar', 'parboil']
# 2 ["biretta's", "terabit's"]
# 2 ['birettas', 'terabits']
# 2 ['birther', 'rebirth']
# 2 ["birther's", "rebirth's"]
# 2 ['birthers', 'rebirths']
# 2 ['bistro', 'orbits']
# 2 ['bizarre', 'brazier']
# 3 ['blamer', 'marble', 'ramble']
# 2 ['blankest', 'blankets']
# 2 ['blaster', 'stabler']
# 2 ['blasting', 'stabling']
# 2 ['blearily', 'reliably']
# 2 ['bleat', 'table']
# 2 ["bleat's", "table's"]
# 2 ['bleating', 'tangible']
# 2 ['blessing', 'glibness']
# 2 ["blessing's", "glibness's"]
# 2 ['blister', 'bristle']
# 2 ["blister's", "bristle's"]
# 2 ['blisters', 'bristles']
# 2 ['blobbed', 'bobbled']
# 2 ['blobbing', 'bobbling']
# 2 ['blog', 'glob']
# 2 ["blog's", "glob's"]
# 2 ['blogged', 'boggled']
# 2 ['blogging', 'boggling']
# 2 ['blogs', 'globs']
# 2 ['blot', 'bolt']
# 2 ["blot's", "bolt's"]
# 2 ['blots', 'bolts']
# 2 ['blotted', 'bottled']
# 2 ['blotting', 'bottling']
# 2 ['bloused', 'doubles']
# 2 ['blow', 'bowl']
# 2 ["blow's", "bowl's"]
# 2 ['blower', 'bowler']
# 2 ["blower's", "bowler's"]
# 2 ['blowers', 'bowlers']
# 2 ['blowing', 'bowling']
# 2 ['blows', 'bowls']
# 2 ['blue', 'lube']
# 2 ["blue's", "lube's"]
# 2 ['blued', 'lubed']
# 2 ['bluer', 'ruble']
# 2 ['blues', 'lubes']
# 4 ['bluest', 'bustle', 'sublet', 'subtle']
# 2 ['bluing', 'lubing']
# 2 ['blushes', 'bushels']
# 3 ['bluster', 'butlers', 'subtler']
# 2 ["bo's'ns", "bos'n's"]
# 3 ["bo'suns", "bonus's", "bosun's"]
# 2 ['board', 'broad']
# 2 ["board's", "broad's"]
# 2 ['boarded', 'roadbed']
# 2 ['boarder', 'broader']
# 2 ['boards', 'broads']
# 2 ['boast', 'boats']
# 2 ['boaster', 'boaters']
# 2 ['bog', 'gob']
# 2 ["bog's", "gob's"]
# 2 ['bogeyman', 'moneybag']
# 2 ["bogeyman's", "moneybag's"]
# 2 ['bogs', 'gobs']
# 2 ['bole', 'lobe']
# 2 ["bole's", "lobe's"]
# 2 ['boles', 'lobes']
# 2 ['bolster', 'lobster']
# 2 ["bolster's", "lobster's"]
# 2 ['bolsters', 'lobsters']
# 2 ['bombed', 'mobbed']
# 2 ['bombing', 'mobbing']
# 2 ['boner', 'borne']
# 2 ['boney', 'ebony']
# 2 ['bonus', 'bosun']
# 2 ['booms', 'bosom']
# 2 ['boost', 'boots']
# 2 ['bordello', 'doorbell']
# 2 ["bordello's", "doorbell's"]
# 2 ['bordellos', 'doorbells']
# 2 ['bore', 'robe']
# 2 ["bore's", "robe's"]
# 2 ['bored', 'robed']
# 3 ['bores', 'robes', 'sober']
# 2 ['boring', 'robing']
# 2 ["bos'ns", "snob's"]
# 2 ['bosh', 'hobs']
# 2 ['boss', 'sobs']
# 2 ['bosses', 'obsess']
# 2 ['bounder', 'rebound']
# 2 ["bounder's", "rebound's"]
# 3 ['bounders', 'rebounds', 'suborned']
# 2 ["bowel's", "elbow's"]
# 2 ['bowels', 'elbows']
# 2 ['bowers', 'browse']
# 3 ['brag', 'garb', 'grab']
# 3 ["brag's", "garb's", "grab's"]
# 3 ['brags', 'garbs', 'grabs']
# 2 ['braid', 'rabid']
# 2 ['braids', 'disbar']
# 2 ['braille', 'liberal']
# 2 ["braille's", "liberal's"]
# 2 ['braise', 'rabies']
# 3 ['braised', 'seabird', 'sidebar']
# 2 ['brawled', 'warbled']
# 2 ['brawler', 'warbler']
# 2 ["brawler's", "warbler's"]
# 2 ['brawlers', 'warblers']
# 2 ['brawling', 'warbling']
# 2 ['breasted', 'debaters']
# 2 ['bribed', 'ribbed']
# 2 ['bribing', 'ribbing']
# 2 ['bridal', 'ribald']
# 2 ['brides', 'debris']
# 2 ['brief', 'fiber']
# 2 ["brief's", "fiber's"]
# 2 ['briefed', 'debrief']
# 2 ['briefs', 'fibers']
# 2 ['briskest', 'briskets']
# 2 ['bristled', 'driblets']
# 2 ['broadcaster', 'rebroadcast']
# 2 ["broadcaster's", "rebroadcast's"]
# 2 ['broadcasters', 'rebroadcasts']
# 2 ['broadside', 'sideboard']
# 2 ["broadside's", "sideboard's"]
# 2 ['broadsides', 'sideboards']
# 2 ['broth', 'throb']
# 2 ["broth's", "throb's"]
# 2 ['broths', 'throbs']
# 4 ['bruise', 'buries', 'busier', 'rubies']
# 2 ['brunt', 'burnt']
# 2 ['brush', 'shrub']
# 2 ["brush's", "shrub's"]
# 3 ['brute', 'rebut', 'tuber']
# 2 ["brute's", "tuber's"]
# 4 ['brutes', 'buster', 'rebuts', 'tubers']
# 2 ['bud', 'dub']
# 2 ["bud's", "dub's"]
# 2 ['budge', 'debug']
# 2 ['budges', 'debugs']
# 2 ['buds', 'dubs']
# 2 ['buffer', 'rebuff']
# 2 ["buffer's", "rebuff's"]
# 2 ['buffered', 'rebuffed']
# 2 ['buffering', 'rebuffing']
# 2 ['buffers', 'rebuffs']
# 2 ['bugle', 'bulge']
# 2 ["bugle's", "bulge's"]
# 2 ['bugled', 'bulged']
# 2 ['bugler', 'burgle']
# 2 ['buglers', 'burgles']
# 2 ['bugles', 'bulges']
# 2 ['bugling', 'bulging']
# 2 ['builder', 'rebuild']
# 2 ['builders', 'rebuilds']
# 2 ['builtin', 'inbuilt']
# 2 ['bun', 'nub']
# 2 ["bun's", "nub's"]
# 2 ['bunked', 'debunk']
# 3 ['buns', 'nubs', 'snub']
# 2 ['bur', 'rub']
# 2 ["bur's", "rub's"]
# 3 ['burble', 'lubber', 'rubble']
# 2 ['burbles', 'lubbers']
# 2 ['burden', 'burned']
# 2 ['burg', 'grub']
# 2 ["burg's", "grub's"]
# 2 ['burgs', 'grubs']
# 2 ['burs', 'rubs']
# 2 ['bury', 'ruby']
# 2 ['bus', 'sub']
# 2 ["bus's", "sub's"]
# 2 ['bush', 'hubs']
# 2 ['buss', 'subs']
# 4 ['bust', 'buts', 'stub', 'tubs']
# 2 ["bust's", "stub's"]
# 2 ['busted', 'debuts']
# 2 ["bustle's", "sublet's"]
# 2 ['bustles', 'sublets']
# 2 ['busts', 'stubs']
# 2 ['busy', 'buys']
# 2 ['but', 'tub']
# 2 ['buttered', 'rebutted']
# 2 ['buttering', 'rebutting']
# 2 ['cabs', 'scab']
# 2 ['cachets', 'catches']
# 2 ['cackled', 'clacked']
# 2 ['cackling', 'clacking']
# 2 ['cadge', 'caged']
# 2 ['cadger', 'graced']
# 2 ["cadre's", "cedar's"]
# 4 ['cadres', 'cedars', 'sacred', 'scared']
# 2 ['cads', 'scad']
# 2 ['caduceus', 'caucused']
# 3 ['caisson', 'casinos', 'cassino']
# 2 ["caisson's", "cassino's"]
# 2 ['caissons', 'cassinos']
# 2 ['califs', 'fiscal']
# 2 ['caliper', 'replica']
# 2 ["caliper's", "replica's"]
# 2 ['calipers', 'replicas']
# 2 ['calk', 'lack']
# 2 ["calk's", "lack's"]
# 2 ['calked', 'lacked']
# 2 ['calking', 'lacking']
# 2 ['calkings', 'slacking']
# 3 ['calks', 'lacks', 'slack']
# 3 ['caller', 'cellar', 'recall']
# 3 ["caller's", "cellar's", "recall's"]
# 3 ['callers', 'cellars', 'recalls']
# 2 ['calligraphy', 'graphically']
# 2 ['calm', 'clam']
# 2 ["calm's", "clam's"]
# 2 ['calms', 'clams']
# 2 ['calumnies', 'masculine']
# 2 ['calypso', 'cosplay']
# 2 ['cambered', 'embraced']
# 2 ['cambering', 'embracing']
# 2 ['camels', 'mescal']
# 2 ['camped', 'decamp']
# 2 ['campers', 'scamper']
# 2 ['campiest', 'campsite']
# 2 ['camps', 'scamp']
# 2 ['cams', 'scam']
# 2 ['canaries', 'cesarian']
# 2 ['candle', 'lanced']
# 2 ['caned', 'dance']
# 2 ['canister', 'scantier']
# 2 ['cannot', 'canton']
# 2 ['canoe', 'ocean']
# 2 ["canoe's", "ocean's"]
# 2 ['canoed', 'deacon']
# 2 ['canoeists', 'cessation']
# 2 ['canoes', 'oceans']
# 2 ['canopying', 'poignancy']
# 2 ['cans', 'scan']
# 2 ['canted', 'decant']
# 4 ['canter', 'nectar', 'recant', 'trance']
# 3 ["canter's", "nectar's", "trance's"]
# 3 ['cantered', 'decanter', 'recanted']
# 2 ['cantering', 'recanting']
# 4 ['canters', 'recants', 'scanter', 'trances']
# 2 ['cantor', 'carton']
# 2 ["cantor's", "carton's"]
# 2 ['cantors', 'cartons']
# 2 ['cants', 'scant']
# 2 ['cape', 'pace']
# 2 ["cape's", "pace's"]
# 2 ['caped', 'paced']
# 3 ['caper', 'crape', 'recap']
# 3 ["caper's", "crape's", "recap's"]
# 5 ['capers', 'crapes', 'parsec', 'recaps', 'scrape']
# 3 ['capes', 'paces', 'space']
# 3 ['capitol', 'optical', 'topical']
# 2 ['capstan', 'catnaps']
# 2 ['capsule', 'upscale']
# 2 ['carbs', 'crabs']
# 2 ['caress', 'scares']
# 6 ['caret', 'cater', 'crate', 'react', 'recta', 'trace']
# 3 ["caret's", "crate's", "trace's"]
# 7 ['carets', 'caster', 'caters', 'crates', 'reacts', 'recast', 'traces']
# 2 ['cargoes', 'corsage']
# 2 ["caring's", "racing's"]
# 2 ['carol', 'coral']
# 2 ["carol's", "coral's"]
# 2 ['carolled', 'collared']
# 2 ['carolling', 'collaring']
# 2 ['carols', 'corals']
# 2 ['carom', 'macro']
# 2 ["carom's", "macro's"]
# 2 ['caromed', 'comrade']
# 2 ['caroms', 'macros']
# 2 ['carp', 'crap']
# 2 ["carp's", "crap's"]
# 2 ['carped', 'redcap']
# 3 ['carpel', 'parcel', 'placer']
# 3 ["carpel's", "parcel's", "placer's"]
# 4 ['carpels', 'parcels', 'placers', 'scalper']
# 2 ['carpets', 'spectra']
# 3 ['carps', 'craps', 'scrap']
# 2 ['carries', 'scarier']
# 3 ['carted', 'crated', 'traced']
# 3 ['cartel', 'claret', 'rectal']
# 2 ["cartel's", "claret's"]
# 3 ['cartels', 'clarets', 'scarlet']
# 3 ['carting', 'crating', 'tracing']
# 2 ['carve', 'crave']
# 2 ['carved', 'craved']
# 2 ['carves', 'craves']
# 2 ['carving', 'craving']
# 2 ["carving's", "craving's"]
# 2 ['carvings', 'cravings']
# 2 ['cashed', 'chased']
# 2 ['cashes', 'chases']
# 2 ['cashing', 'chasing']
# 2 ['cask', 'sack']
# 2 ["cask's", "sack's"]
# 2 ['casks', 'sacks']
# 2 ['casserole', 'escaroles']
# 2 ["cast's", "scat's"]
# 2 ["caster's", "recast's"]
# 2 ['castle', 'cleats']
# 2 ["castor's", "costar's"]
# 2 ['castors', 'costars']
# 2 ['casts', 'scats']
# 2 ['casual', 'causal']
# 2 ['casually', 'causally']
# 2 ['catalogue', 'coagulate']
# 2 ['catalogued', 'coagulated']
# 2 ['catalogues', 'coagulates']
# 2 ['cataloguing', 'coagulating']
# 2 ['catechism', 'schematic']
# 2 ["catechism's", "schematic's"]
# 2 ['catechisms', 'schematics']
# 3 ['catered', 'created', 'reacted']
# 3 ['caterer', 'retrace', 'terrace']
# 2 ["caterer's", "terrace's"]
# 3 ['caterers', 'retraces', 'terraces']
# 3 ['catering', 'creating', 'reacting']
# 2 ['caterings', 'recasting']
# 2 ['cattily', 'tacitly']
# 3 ['cattiness', 'scantiest', 'tacitness']
# 2 ["cattiness's", "tacitness's"]
# 2 ['cause', 'sauce']
# 2 ["cause's", "sauce's"]
# 2 ['caused', 'sauced']
# 2 ['causes', 'sauces']
# 2 ['causing', 'saucing']
# 2 ['cavaliers', 'cavalries']
# 2 ['caveat', 'vacate']
# 2 ['caveats', 'vacates']
# 2 ['cavern', 'craven']
# 2 ["cavern's", "craven's"]
# 2 ['caverns', 'cravens']
# 2 ['censer', 'screen']
# 2 ["censer's", "screen's"]
# 2 ['censers', 'screens']
# 2 ['censor', 'crones']
# 2 ['censored', 'encoders']
# 2 ['center', 'recent']
# 2 ['centigram', 'cremating']
# 2 ['cents', 'scent']
# 2 ['certifiable', 'rectifiable']
# 2 ['certification', 'rectification']
# 2 ["certification's", "rectification's"]
# 2 ['certifications', 'rectifications']
# 2 ['certified', 'rectified']
# 2 ['certifies', 'rectifies']
# 2 ['certify', 'rectify']
# 2 ['certifying', 'rectifying']
# 2 ['certitude', 'rectitude']
# 2 ["certitude's", "rectitude's"]
# 2 ['cervices', 'crevices']
# 2 ['cesium', 'miscue']
# 2 ["cesium's", "miscue's"]
# 2 ['chagrins', 'crashing']
# 2 ['chain', 'china']
# 2 ["chain's", "china's"]
# 3 ['chalets', 'latches', 'satchel']
# 2 ['chanters', 'stancher']
# 3 ['chants', 'snatch', 'stanch']
# 2 ['chapt', 'patch']
# 2 ['charm', 'march']
# 2 ["charm's", "march's"]
# 2 ['charmed', 'marched']
# 2 ['charmer', 'marcher']
# 2 ["charmer's", "marcher's"]
# 2 ['charmers', 'marchers']
# 2 ['charming', 'marching']
# 2 ['chars', 'crash']
# 2 ['charts', 'starch']
# 2 ["chaser's", "search's"]
# 2 ['chasers', 'crashes']
# 3 ['chaste', 'cheats', 'sachet']
# 3 ['chastens', 'snatches', 'stanches']
# 2 ['chatter', 'ratchet']
# 2 ["chatter's", "ratchet's"]
# 2 ['chattered', 'ratcheted']
# 2 ['chattering', 'ratcheting']
# 2 ['chatters', 'ratchets']
# 2 ['cheap', 'peach']
# 2 ['cheat', 'teach']
# 3 ['cheater', 'hectare', 'teacher']
# 3 ["cheater's", "hectare's", "teacher's"]
# 3 ['cheaters', 'hectares', 'teachers']
# 2 ['cheating', 'teaching']
# 2 ['checker', 'recheck']
# 2 ["checker's", "recheck's"]
# 2 ['checkered', 'rechecked']
# 2 ['checkering', 'rechecking']
# 2 ['checkers', 'rechecks']
# 2 ['cheeps', 'speech']
# 2 ['chest', 'techs']
# 2 ['chief', 'fiche']
# 2 ["chief's", "fiche's"]
# 2 ['chiefest', 'fetiches']
# 2 ['chiefs', 'fiches']
# 2 ['chiles', 'chisel']
# 2 ['chin', 'inch']
# 2 ["chin's", "inch's"]
# 2 ['chit', 'itch']
# 2 ["chit's", "itch's"]
# 2 ['choked', 'hocked']
# 2 ['chokers', 'shocker']
# 2 ['choking', 'hocking']
# 2 ['cholera', 'chorale']
# 2 ["cholera's", "chorale's"]
# 2 ['chorals', 'scholar']
# 2 ['chords', 'schrod']
# 3 ['chore', 'ocher', 'ochre']
# 3 ["chore's", "ocher's", "ochre's"]
# 2 ['chose', 'echos']
# 2 ['chum', 'much']
# 2 ["chum's", "much's"]
# 2 ['churl', 'lurch']
# 2 ["churl's", "lurch's"]
# 3 ['cider', 'cried', 'riced']
# 2 ['cilantro', 'contrail']
# 2 ["cilantro's", "contrail's"]
# 3 ['cinders', 'discern', 'rescind']
# 2 ['ciphered', 'decipher']
# 2 ['circle', 'cleric']
# 2 ["circle's", "cleric's"]
# 2 ['circles', 'clerics']
# 2 ['cistern', 'cretins']
# 2 ['citadel', 'dialect']
# 2 ["citadel's", "dialect's"]
# 2 ['citadels', 'dialects']
# 2 ['cited', 'edict']
# 2 ['cities', 'iciest']
# 2 ['citric', 'critic']
# 2 ['citrus', 'rustic']
# 2 ["citrus's", "rustic's"]
# 2 ['citruses', 'curtsies']
# 2 ['civet', 'evict']
# 2 ['civets', 'evicts']
# 4 ['claimed', 'decimal', 'declaim', 'medical']
# 2 ['clambers', 'scramble']
# 2 ['clanged', 'glanced']
# 2 ['clanging', 'glancing']
# 3 ['claps', 'clasp', 'scalp']
# 2 ["clasp's", "scalp's"]
# 2 ['clasped', 'scalped']
# 2 ['clasping', 'scalping']
# 2 ['clasps', 'scalps']
# 2 ['clay', 'lacy']
# 2 ['clean', 'lance']
# 2 ['cleaners', 'cleanser']
# 2 ['cleanings', 'cleansing']
# 2 ['cleans', 'lances']
# 2 ['cleanse', 'scalene']
# 2 ['cleansers', 'clearness']
# 2 ['cleared', 'declare']
# 2 ['clematis', 'climates']
# 2 ['clematises', 'timescales']
# 2 ['clients', 'stencil']
# 2 ['climaxes', 'exclaims']
# 2 ['clinker', 'crinkle']
# 2 ["clinker's", "crinkle's"]
# 2 ['clinkers', 'crinkles']
# 2 ['clipper', 'cripple']
# 2 ["clipper's", "cripple's"]
# 2 ['clippers', 'cripples']
# 2 ['clobber', 'cobbler']
# 2 ["clobber's", "cobbler's"]
# 2 ['clobbers', 'cobblers']
# 2 ['clod', 'cold']
# 2 ["clod's", "cold's"]
# 3 ['clods', 'colds', 'scold']
# 2 ['cloister', 'costlier']
# 2 ['closest', 'closets']
# 2 ['clot', 'colt']
# 2 ["clot's", "colt's"]
# 2 ['clots', 'colts']
# 2 ['cloud', 'could']
# 2 ['clouts', 'locust']
# 2 ['coal', 'cola']
# 2 ["coal's", "cola's"]
# 2 ['coals', 'colas']
# 2 ['coarsen', 'corneas']
# 2 ['coarsest', 'coasters']
# 2 ['coastline', 'sectional']
# 2 ["coastline's", "sectional's"]
# 2 ['coastlines', 'sectionals']
# 2 ['coat', 'taco']
# 2 ["coat's", "taco's"]
# 2 ['cocaine', 'oceanic']
# 2 ["cocaine's", "oceanic's"]
# 2 ['cockily', 'colicky']
# 2 ['cod', 'doc']
# 2 ["cod's", "doc's"]
# 2 ['coddles', 'scolded']
# 2 ['code', 'coed']
# 2 ["code's", "coed's"]
# 2 ['codes', 'coeds']
# 2 ['cods', 'docs']
# 2 ['coexist', 'exotics']
# 2 ['cognition', 'incognito']
# 2 ["cognition's", "incognito's"]
# 2 ['coif', 'foci']
# 2 ['coil', 'loci']
# 2 ['coiled', 'docile']
# 2 ['coin', 'icon']
# 2 ["coin's", "icon's"]
# 4 ['coins', 'icons', 'scion', 'sonic']
# 2 ['colitis', 'solicit']
# 2 ['collapsed', 'scalloped']
# 2 ['collapsing', 'scalloping']
# 2 ['colones', 'console']
# 2 ['colonialist', 'oscillation']
# 2 ["colonialist's", "oscillation's"]
# 2 ['colonialists', 'oscillations']
# 2 ['comedian', 'demoniac']
# 2 ['comics', 'cosmic']
# 2 ['commissioned', 'decommission']
# 2 ['compile', 'polemic']
# 2 ['compiled', 'complied']
# 3 ['compiles', 'complies', 'polemics']
# 2 ['complaint', 'compliant']
# 2 ['compressed', 'decompress']
# 2 ['concerted', 'concreted']
# 2 ['concerting', 'concreting']
# 2 ['conciser', 'cornices']
# 2 ['conditioner', 'recondition']
# 2 ['conditioners', 'reconditions']
# 2 ['condoles', 'consoled']
# 2 ['condor', 'cordon']
# 2 ["condor's", "cordon's"]
# 2 ['condors', 'cordons']
# 2 ['conduits', 'discount']
# 2 ['cone', 'once']
# 2 ["cone's", "once's"]
# 2 ['cones', 'scone']
# 2 ['configures', 'refocusing']
# 2 ['conical', 'laconic']
# 2 ['conifers', 'forensic']
# 2 ['connecter', 'reconnect']
# 2 ['connecters', 'reconnects']
# 2 ['conservation', 'conversation']
# 2 ["conservation's", "conversation's"]
# 2 ['conserve', 'converse']
# 2 ["conserve's", "converse's"]
# 2 ['conserved', 'conversed']
# 2 ['conserves', 'converses']
# 2 ['conserving', 'conversing']
# 2 ['considerate', 'desecration']
# 2 ['consigned', 'seconding']
# 2 ['consist', 'tocsins']
# 2 ['consoles', 'coolness']
# 2 ['consolidates', 'disconsolate']
# 4 ['construe', 'counters', 'recounts', 'trounces']
# 2 ['contains', 'sanction']
# 2 ['contenting', 'contingent']
# 2 ['continued', 'unnoticed']
# 2 ['contuses', 'countess']
# 2 ['cool', 'loco']
# 2 ['coolest', 'ocelots']
# 2 ['coops', 'scoop']
# 2 ['coordinate', 'decoration']
# 2 ["coordinate's", "decoration's"]
# 2 ['coordinates', 'decorations']
# 2 ['coots', 'scoot']
# 3 ['copes', 'copse', 'scope']
# 2 ['copings', 'scoping']
# 2 ["copse's", "scope's"]
# 2 ['copses', 'scopes']
# 2 ['copula', 'cupola']
# 2 ["copula's", "cupola's"]
# 2 ['copulas', 'cupolas']
# 2 ['cords', 'scrod']
# 3 ['cored', 'credo', 'decor']
# 2 ['cores', 'score']
# 2 ['cork', 'rock']
# 2 ["cork's", "rock's"]
# 2 ['corked', 'rocked']
# 2 ['corking', 'rocking']
# 2 ['corks', 'rocks']
# 2 ['corns', 'scorn']
# 2 ['corny', 'crony']
# 2 ['corona', 'racoon']
# 2 ["corona's", "racoon's"]
# 2 ['coronas', 'racoons']
# 2 ['coroner', 'crooner']
# 2 ["coroner's", "crooner's"]
# 2 ['coroners', 'crooners']
# 2 ['corps', 'crops']
# 2 ['corpses', 'process']
# 3 ['corset', 'escort', 'sector']
# 3 ["corset's", "escort's", "sector's"]
# 2 ['corseted', 'escorted']
# 2 ['corseting', 'escorting']
# 3 ['corsets', 'escorts', 'sectors']
# 2 ['cost', 'cots']
# 2 ['coteries', 'esoteric']
# 3 ['counter', 'recount', 'trounce']
# 2 ["counter's", "recount's"]
# 2 ['countered', 'recounted']
# 2 ['countering', 'recounting']
# 3 ['countries', 'cretinous', 'neurotics']
# 2 ['course', 'source']
# 2 ["course's", "source's"]
# 3 ['coursed', 'scoured', 'sourced']
# 3 ['courses', 'sources', 'sucrose']
# 3 ['coursing', 'scouring', 'sourcing']
# 2 ['courteous', 'outsource']
# 2 ['covert', 'vector']
# 2 ["covert's", "vector's"]
# 2 ['coverts', 'vectors']
# 2 ['cowers', 'escrow']
# 2 ['cowlings', 'scowling']
# 2 ['cowls', 'scowl']
# 2 ['cows', 'scow']
# 2 ['craftiest', 'trifectas']
# 2 ['crams', 'scram']
# 2 ['crane', 'nacre']
# 2 ["crane's", "nacre's"]
# 2 ['craned', 'dancer']
# 2 ["craps's", "scrap's"]
# 2 ['crass', 'scars']
# 2 ['crater', 'tracer']
# 2 ["crater's", "tracer's"]
# 3 ['cratered', 'retraced', 'terraced']
# 3 ['cratering', 'retracing', 'terracing']
# 2 ['craters', 'tracers']
# 2 ['crawls', 'scrawl']
# 2 ['creams', 'scream']
# 2 ['creation', 'reaction']
# 2 ["creation's", "reaction's"]
# 2 ['creations', 'reactions']
# 2 ['creative', 'reactive']
# 2 ['creator', 'reactor']
# 2 ["creator's", "reactor's"]
# 2 ['creators', 'reactors']
# 2 ['credential', 'interlaced']
# 2 ['credit', 'direct']
# 2 ['credited', 'directed']
# 2 ['crediting', 'directing']
# 2 ['creditor', 'director']
# 2 ["creditor's", "director's"]
# 2 ['creditors', 'directors']
# 2 ['credits', 'directs']
# 2 ["credo's", "decor's"]
# 3 ['credos', 'decors', 'scored']
# 2 ['creep', 'crepe']
# 2 ["creep's", "crepe's"]
# 2 ['creeps', 'crepes']
# 2 ['crews', 'screw']
# 2 ['cries', 'rices']
# 2 ['crimps', 'scrimp']
# 2 ['crimson', 'microns']
# 2 ['crisp', 'scrip']
# 2 ["crisp's", "scrip's"]
# 2 ['crisps', 'scrips']
# 3 ['critters', 'restrict', 'stricter']
# 2 ['crochets', 'crotches']
# 3 ['crocus', 'occurs', 'succor']
# 2 ["crocus's", "succor's"]
# 2 ['crosser', 'scorers']
# 2 ['crud', 'curd']
# 2 ["crud's", "curd's"]
# 2 ['crude', 'cured']
# 2 ['crudest', 'crusted']
# 2 ['crudities', 'diuretics']
# 3 ['cruel', 'lucre', 'ulcer']
# 2 ['cruelest', 'lectures']
# 2 ['cruelty', 'cutlery']
# 2 ["cruelty's", "cutlery's"]
# 3 ['cruet', 'cuter', 'truce']
# 2 ["cruet's", "truce's"]
# 2 ['cruets', 'truces']
# 2 ['cruise', 'curies']
# 2 ['cruiser', 'curries']
# 2 ['cruisers', 'scurries']
# 2 ['crumpets', 'spectrum']
# 2 ['crust', 'curst']
# 2 ['crustier', 'recruits']
# 2 ['crusty', 'curtsy']
# 2 ['cubist', 'cubits']
# 2 ['cuds', 'scud']
# 2 ['cuffs', 'scuff']
# 2 ['culls', 'scull']
# 2 ['cums', 'scum']
# 2 ['cupfuls', 'cupsful']
# 2 ['cupids', 'cuspid']
# 2 ['cups', 'cusp']
# 2 ['curbs', 'scrub']
# 2 ['curdle', 'curled']
# 2 ['cure', 'ecru']
# 2 ["cure's", "ecru's"]
# 2 ['curer', 'recur']
# 2 ['cures', 'curse']
# 2 ['curtest', 'cutters']
# 2 ['curtness', 'encrusts']
# 2 ['cutlets', 'scuttle']
# 2 ['dabbles', 'slabbed']
# 2 ['daemon', 'moaned']
# 3 ['dafter', 'farted', 'rafted']
# 2 ['dagger', 'ragged']
# 2 ['dailies', 'liaised']
# 2 ['dairies', 'diaries']
# 2 ['dairy', 'diary']
# 2 ["dairy's", "diary's"]
# 4 ['dale', 'deal', 'lade', 'lead']
# 3 ["dale's", "deal's", "lead's"]
# 4 ['dales', 'deals', 'lades', 'leads']
# 2 ['dallies', 'sallied']
# 2 ['dam', 'mad']
# 2 ["dam's", "mad's"]
# 3 ['dame', 'made', 'mead']
# 2 ["dame's", "mead's"]
# 3 ['damned', 'demand', 'madden']
# 2 ['dampest', 'stamped']
# 2 ['dams', 'mads']
# 2 ['damsel', 'medals']
# 2 ['damson', 'nomads']
# 2 ['dander', 'darned']
# 2 ['dandier', 'drained']
# 2 ['dandle', 'landed']
# 4 ['danger', 'gander', 'garden', 'ranged']
# 3 ["danger's", "gander's", "garden's"]
# 3 ['dangers', 'ganders', 'gardens']
# 2 ['dangled', 'gladden']
# 4 ['danker', 'darken', 'narked', 'ranked']
# 2 ['dapper', 'rapped']
# 2 ['dapperer', 'prepared']
# 2 ['dapple', 'lapped']
# 2 ['dapples', 'slapped']
# 3 ['dare', 'dear', 'read']
# 3 ["dare's", "dear's", "read's"]
# 3 ['dares', 'dears', 'reads']
# 2 ['darling', 'larding']
# 2 ['darted', 'traded']
# 2 ['darting', 'trading']
# 2 ['dash', 'shad']
# 2 ["dash's", "shad's"]
# 2 ['dashed', 'shaded']
# 2 ['dashes', 'shades']
# 2 ['dashing', 'shading']
# 2 ['dateline', 'entailed']
# 3 ['dates', 'sated', 'stead']
# 2 ['dauber', 'earbud']
# 2 ["dauber's", "earbud's"]
# 2 ['daubers', 'earbuds']
# 2 ['daunted', 'undated']
# 2 ['dawdle', 'waddle']
# 2 ['dawdled', 'waddled']
# 2 ['dawdler', 'drawled']
# 3 ['dawdles', 'swaddle', 'waddles']
# 2 ['dawdling', 'waddling']
# 2 ['dawn', 'wand']
# 2 ["dawn's", "wand's"]
# 2 ['dawns', 'wands']
# 2 ['deadest', 'sedated']
# 2 ['deadlier', 'derailed']
# 2 ['deaf', 'fade']
# 2 ['deafer', 'feared']
# 3 ['deafest', 'defeats', 'feasted']
# 2 ['dealer', 'leader']
# 2 ["dealer's", "leader's"]
# 2 ['dealers', 'leaders']
# 2 ['dealership', 'leadership']
# 2 ["dealership's", "leadership's"]
# 2 ["dealing's", "leading's"]
# 2 ['dealings', 'signaled']
# 2 ['dealt', 'delta']
# 2 ['deans', 'sedan']
# 4 ['dearer', 'reader', 'reared', 'reread']
# 3 ['dearest', 'sedater', 'tasered']
# 3 ['dearth', 'hatred', 'thread']
# 3 ["dearth's", "hatred's", "thread's"]
# 5 ['dearths', 'hardest', 'hatreds', 'threads', 'trashed']
# 2 ['death', 'hated']
# 2 ['deaths', 'hasted']
# 2 ['deaves', 'evades']
# 2 ['debase', 'seabed']
# 2 ['debases', 'seabeds']
# 2 ['debut', 'tubed']
# 2 ['decadent', 'decanted']
# 2 ['decadents', 'descanted']
# 2 ['decaf', 'faced']
# 2 ['decal', 'laced']
# 2 ['decals', 'scaled']
# 3 ['decants', 'descant', 'scanted']
# 2 ['deceiver', 'received']
# 2 ['decide', 'deiced']
# 2 ["decimal's", "medical's"]
# 3 ['decimals', 'declaims', 'medicals']
# 2 ['decimate', 'medicate']
# 2 ['decimated', 'medicated']
# 2 ['decimates', 'medicates']
# 2 ['decimating', 'medicating']
# 2 ['decimation', 'medication']
# 2 ["decimation's", "medication's"]
# 3 ['declines', 'licensed', 'silenced']
# 2 ['decree', 'recede']
# 2 ['decreed', 'receded']
# 2 ['decrees', 'recedes']
# 2 ['decries', 'deicers']
# 2 ['deduces', 'seduced']
# 2 ['deductions', 'discounted']
# 2 ['deeding', 'deigned']
# 2 ['deep', 'peed']
# 2 ['deeper', 'peered']
# 2 ['deepest', 'steeped']
# 2 ['deeply', 'yelped']
# 2 ['deeps', 'speed']
# 2 ['deer', 'reed']
# 2 ["deer's", "reed's"]
# 2 ['deers', 'reeds']
# 2 ['default', 'faulted']
# 2 ['defend', 'fended']
# 2 ['defer', 'freed']
# 2 ['deferment', 'fermented']
# 2 ['defiant', 'fainted']
# 2 ['defiled', 'fielded']
# 2 ['defiling', 'fielding']
# 2 ['definer', 'refined']
# 2 ['deflation', 'defoliant']
# 2 ["deflation's", "defoliant's"]
# 3 ['deforest', 'forested', 'fostered']
# 2 ['deform', 'formed']
# 2 ['deforms', 'serfdom']
# 2 ['defray', 'frayed']
# 2 ['defrost', 'frosted']
# 2 ['deification', 'edification']
# 2 ["deification's", "edification's"]
# 2 ['deified', 'edified']
# 2 ['deifies', 'edifies']
# 2 ['deify', 'edify']
# 2 ['deifying', 'edifying']
# 4 ['deigns', 'design', 'signed', 'singed']
# 2 ['deism', 'dimes']
# 3 ['deletes', 'sleeted', 'steeled']
# 3 ['deli', 'idle', 'lied']
# 2 ["deli's", "idle's"]
# 2 ['delight', 'lighted']
# 2 ['delights', 'slighted']
# 2 ['delimit', 'limited']
# 4 ['delis', 'idles', 'sidle', 'slide']
# 3 ['deliver', 'relived', 'reviled']
# 3 ['delivers', 'silvered', 'slivered']
# 5 ['deltas', 'lasted', 'salted', 'slated', 'staled']
# 3 ['delude', 'dueled', 'eluded']
# 2 ['deluding', 'indulged']
# 2 ['demanded', 'maddened']
# 2 ['demanding', 'maddening']
# 2 ['demands', 'maddens']
# 2 ['demarcate', 'macerated']
# 2 ['demeanor', 'enamored']
# 3 ['demerit', 'merited', 'mitered']
# 2 ['demised', 'misdeed']
# 3 ['demo', 'dome', 'mode']
# 3 ["demo's", "dome's", "mode's"]
# 3 ['demos', 'domes', 'modes']
# 2 ['demote', 'emoted']
# 2 ['demotion', 'motioned']
# 2 ['demount', 'mounted']
# 2 ['demurest', 'mustered']
# 2 ['demurred', 'murdered']
# 2 ['demurring', 'murdering']
# 2 ['den', 'end']
# 2 ["den's", "end's"]
# 2 ['denatures', 'sauntered']
# 2 ['denials', 'snailed']
# 2 ['denied', 'indeed']
# 2 ['denier', 'reined']
# 2 ['denim', 'mined']
# 2 ['denominate', 'emendation']
# 2 ['denominates', 'emendations']
# 2 ['denotation', 'detonation']
# 2 ["denotation's", "detonation's"]
# 2 ['denotations', 'detonations']
# 3 ['dens', 'ends', 'send']
# 2 ['dense', 'needs']
# 3 ['denser', 'resend', 'sender']
# 2 ['densities', 'destinies']
# 2 ['density', 'destiny']
# 2 ["density's", "destiny's"]
# 2 ['dent', 'tend']
# 2 ['dented', 'tended']
# 4 ['dentin', 'indent', 'intend', 'tinned']
# 2 ["dentin's", "indent's"]
# 2 ['denting', 'tending']
# 2 ['dentist', 'stinted']
# 2 ['dents', 'tends']
# 2 ['denture', 'tenured']
# 2 ['denude', 'endued']
# 4 ['depart', 'parted', 'petard', 'prated']
# 2 ['departed', 'predated']
# 2 ['departing', 'predating']
# 2 ['departs', 'petards']
# 2 ['depend', 'pended']
# 2 ['deplane', 'paneled']
# 2 ['deport', 'ported']
# 2 ['deports', 'sported']
# 4 ['deposit', 'dopiest', 'posited', 'topside']
# 2 ["deposit's", "topside's"]
# 2 ['deposition', 'positioned']
# 2 ['depositor', 'droopiest']
# 2 ['deposits', 'topsides']
# 2 ['depot', 'opted']
# 3 ['depots', 'despot', 'posted']
# 2 ['deprave', 'pervade']
# 2 ['depraved', 'pervaded']
# 2 ['depraves', 'pervades']
# 2 ['depraving', 'pervading']
# 2 ['depress', 'pressed']
# 2 ['deprogram', 'programed']
# 3 ['derail', 'railed', 'relaid']
# 2 ['derailments', 'streamlined']
# 2 ['deranged', 'gardened']
# 3 ['deranges', 'grandees', 'grenades']
# 2 ['deranging', 'gardening']
# 3 ['derides', 'desired', 'resided']
# 3 ['derives', 'diverse', 'revised']
# 2 ['dervish', 'shrived']
# 2 ['descent', 'scented']
# 2 ['description', 'predictions']
# 3 ['desert', 'deters', 'rested']
# 2 ['deserts', 'dessert']
# 2 ['deserve', 'severed']
# 3 ['designer', 'redesign', 'resigned']
# 2 ['designers', 'redesigns']
# 3 ['desire', 'eiders', 'reside']
# 2 ['desires', 'resides']
# 3 ['desiring', 'residing', 'ringside']
# 2 ['despoil', 'spoiled']
# 2 ['desserts', 'stressed']
# 2 ['destining', 'indigents']
# 3 ['detail', 'dilate', 'tailed']
# 2 ['details', 'dilates']
# 3 ['detains', 'instead', 'stained']
# 2 ['deter', 'treed']
# 2 ['detest', 'tested']
# 2 ['dethrones', 'shortened']
# 3 ['detour', 'routed', 'toured']
# 2 ['detours', 'dourest']
# 2 ['deuces', 'seduce']
# 2 ['developer', 'redevelop']
# 2 ['developers', 'redevelops']
# 2 ['deviates', 'sedative']
# 2 ['devil', 'lived']
# 2 ['devise', 'sieved']
# 2 ['devoid', 'voided']
# 2 ['devolve', 'evolved']
# 2 ['devote', 'vetoed']
# 2 ['dew', 'wed']
# 2 ['dial', 'laid']
# 2 ['dialed', 'laddie']
# 2 ['diameters', 'dreamiest']
# 3 ['diaper', 'paired', 'repaid']
# 2 ['diatoms', 'mastoid']
# 2 ['dice', 'iced']
# 2 ['dicker', 'ricked']
# 2 ['diddle', 'lidded']
# 3 ['dies', 'ides', 'side']
# 2 ['diesel', 'elides']
# 4 ['diet', 'edit', 'tide', 'tied']
# 3 ["diet's", "edit's", "tide's"]
# 2 ['dieted', 'edited']
# 3 ['dieting', 'editing', 'ignited']
# 2 ['dietitian', 'initiated']
# 4 ['diets', 'edits', 'sited', 'tides']
# 2 ['differ', 'riffed']
# 2 ['digger', 'rigged']
# 2 ['dignifies', 'signified']
# 2 ['dignity', 'tidying']
# 2 ['dikes', 'skied']
# 2 ['dilly', 'idyll']
# 2 ["dilly's", "idyll's"]
# 2 ['dilutes', 'duelist']
# 2 ['dim', 'mid']
# 3 ['dimer', 'mired', 'rimed']
# 2 ['dimmer', 'rimmed']
# 2 ['dimple', 'limped']
# 3 ['diners', 'rinsed', 'snider']
# 2 ['dines', 'snide']
# 2 ['dinettes', 'insetted']
# 2 ['dingo', 'doing']
# 2 ["dingo's", "doing's"]
# 2 ['dingy', 'dying']
# 2 ['dipper', 'ripped']
# 2 ['dire', 'ride']
# 2 ['directer', 'redirect']
# 2 ['directest', 'trisected']
# 2 ['directions', 'discretion']
# 3 ['direr', 'drier', 'rider']
# 3 ['direst', 'driest', 'stride']
# 2 ['dirge', 'ridge']
# 2 ["dirge's", "ridge's"]
# 2 ['dirges', 'ridges']
# 2 ['dirtiness', 'disinters']
# 2 ['dis', 'ids']
# 2 ['discerned', 'rescinded']
# 2 ['discerning', 'rescinding']
# 2 ['discerns', 'rescinds']
# 2 ['discover', 'divorces']
# 2 ['discoverer', 'rediscover']
# 2 ['discoverers', 'rediscovers']
# 2 ['discreet', 'discrete']
# 2 ['disease', 'seaside']
# 2 ["disease's", "seaside's"]
# 2 ['diseases', 'seasides']
# 2 ['dishes', 'hissed']
# 2 ['dishing', 'shindig']
# 2 ['dishonest', 'hedonists']
# 3 ['disk', 'kids', 'skid']
# 2 ["disk's", "skid's"]
# 2 ['disks', 'skids']
# 2 ['dispel', 'lisped']
# 2 ['disperse', 'presides']
# 2 ['disport', 'tripods']
# 2 ['disprove', 'provides']
# 2 ['dissent', 'snidest']
# 3 ['dissenter', 'residents', 'tiredness']
# 2 ["dissenter's", "tiredness's"]
# 2 ['dissing', 'sidings']
# 2 ['distaste', 'staidest']
# 2 ['distention', 'tendonitis']
# 2 ["distention's", "tendonitis's"]
# 2 ['distincter', 'interdicts']
# 2 ['disuse', 'issued']
# 2 ['dithers', 'shirted']
# 2 ['ditties', 'tidiest']
# ...
# 3 ['relives', 'reviles', 'servile']
# 2 ['reliving', 'reviling']
# 2 ['rent', 'tern']
# 2 ["rent's", "tern's"]
# 2 ['rented', 'tender']
# 2 ['renters', 'sterner']
# 3 ['rents', 'stern', 'terns']
# 2 ['reorg', 'roger']
# 2 ['reorged', 'rogered']
# 2 ['reorging', 'rogering']
# 2 ['reorgs', 'rogers']
# 2 ['repartee', 'repeater']
# 2 ["repartee's", "repeater's"]
# 2 ['repasts', 'sparest']
# 2 ['repertoires', 'repertories']
# 2 ['reposing', 'spongier']
# 2 ['reprise', 'respire']
# 2 ['reprises', 'respires']
# 3 ['reprising', 'respiring', 'springier']
# 2 ["resale's", "sealer's"]
# 2 ['resales', 'sealers']
# 2 ['rescue', 'secure']
# 2 ['rescuer', 'securer']
# 2 ['rescues', 'secures']
# 2 ['rescuing', 'securing']
# 2 ['research', 'searcher']
# 2 ["research's", "searcher's"]
# 2 ['resell', 'seller']
# 2 ['resells', 'sellers']
# 4 ['reserve', 'reveres', 'reverse', 'severer']
# 2 ["reserve's", "reverse's"]
# 2 ['reserved', 'reversed']
# 2 ['reserves', 'reverses']
# 2 ['reserving', 'reversing']
# 3 ["resin's", "rinse's", "siren's"]
# 3 ['resins', 'rinses', 'sirens']
# 2 ['resist', 'sister']
# 2 ["resist's", "sister's"]
# 2 ['resistant', 'straitens']
# 3 ['resistor', 'roisters', 'sorriest']
# 2 ['resists', 'sisters']
# 2 ['resold', 'solder']
# 3 ['resort', 'roster', 'sorter']
# 3 ["resort's", "roster's", "sorter's"]
# 2 ['resorted', 'restored']
# 2 ['resorting', 'restoring']
# 3 ['resorts', 'rosters', 'sorters']
# 2 ['resound', 'sounder']
# 3 ['respect', 'scepter', 'specter']
# 3 ["respect's", "scepter's", "specter's"]
# 3 ['respects', 'scepters', 'specters']
# 2 ['respell', 'speller']
# 2 ['respells', 'spellers']
# 2 ['restart', 'starter']
# 2 ["restart's", "starter's"]
# 2 ['restarts', 'starters']
# 2 ['resting', 'stinger']
# 2 ['restive', 'veriest']
# 2 ['restock', 'rockets']
# 5 ['restrain', 'retrains', 'strainer', 'terrains', 'trainers']
# 2 ['restrains', 'strainers']
# 2 ['rests', 'tress']
# 2 ['results', 'rustles']
# 2 ['retain', 'retina']
# 3 ['retard', 'tarred', 'trader']
# 2 ["retard's", "trader's"]
# 3 ['retards', 'starred', 'traders']
# 2 ['retell', 'teller']
# 2 ['retells', 'tellers']
# 2 ['rethink', 'thinker']
# 2 ["rethink's", "thinker's"]
# 2 ['rethinks', 'thinkers']
# 2 ['retinae', 'trainee']
# 3 ['retinue', 'reunite', 'uterine']
# 2 ['retinues', 'reunites']
# 3 ['retired', 'retried', 'tireder']
# 2 ['retires', 'retries']
# 3 ['retrain', 'terrain', 'trainer']
# 2 ['retrial', 'trailer']
# 2 ["retrial's", "trailer's"]
# 2 ['retrials', 'trailers']
# 2 ['retry', 'terry']
# 2 ['return', 'turner']
# 2 ["return's", "turner's"]
# 2 ['returns', 'turners']
# 2 ['retweet', 'tweeter']
# 2 ['retweets', 'tweeters']
# 2 ['reupholster', 'upholsterer']
# 2 ['reupholsters', 'upholsterers']
# 2 ['reveals', 'several']
# 2 ['review', 'viewer']
# 2 ["review's", "viewer's"]
# 2 ['reviews', 'viewers']
# 2 ['rewired', 'weirder']
# 2 ['rework', 'worker']
# 2 ['reworks', 'workers']
# 2 ['rewound', 'wounder']
# 3 ['rickets', 'sticker', 'tickers']
# 2 ["rickets's", "sticker's"]
# 2 ['riles', 'slier']
# 2 ['ringlets', 'sterling']
# 3 ['riot', 'tiro', 'trio']
# 3 ["riot's", "tiro's", "trio's"]
# 2 ['rioters', 'roister']
# 4 ['riots', 'tiros', 'torsi', 'trios']
# 2 ['ripens', 'sniper']
# 2 ['ripples', 'slipper']
# 2 ["rise's", "sire's"]
# 2 ['rises', 'sires']
# 2 ['rising', 'siring']
# 3 ['rite', 'tier', 'tire']
# 3 ["rite's", "tier's", "tire's"]
# 4 ['rites', 'tiers', 'tires', 'tries']
# 2 ['rival', 'viral']
# 2 ['rivaling', 'virginal']
# 2 ['rivets', 'strive']
# 3 ['roast', 'sorta', 'taros']
# 2 ['rockiest', 'stockier']
# 2 ['rodents', 'snorted']
# 2 ['rogue', 'rouge']
# 2 ["rogue's", "rouge's"]
# 3 ['roost', 'roots', 'torso']
# 2 ["roost's", "torso's"]
# 2 ['roosts', 'torsos']
# 2 ["rose's", "sore's"]
# 2 ['roses', 'sores']
# 3 ['rosiest', 'sorties', 'stories']
# 2 ['rot', 'tor']
# 2 ["rot's", "tor's"]
# 2 ['rotates', 'toaster']
# 2 ['rote', 'tore']
# 3 ['rots', 'sort', 'tors']
# 2 ['roundest', 'tonsured']
# 2 ['roused', 'soured']
# 2 ['rouses', 'serous']
# 2 ['rousing', 'souring']
# 2 ['rout', 'tour']
# 2 ["rout's", "tour's"]
# 2 ['routing', 'touring']
# 3 ['routs', 'torus', 'tours']
# 3 ['rowdier', 'wordier', 'worried']
# 2 ['rowdiest', 'wordiest']
# 2 ['rowdiness', 'wordiness']
# 2 ["rowdiness's", "wordiness's"]
# 2 ['royalist', 'solitary']
# 2 ["royalist's", "solitary's"]
# 2 ['rude', 'rued']
# 4 ['rues', 'ruse', 'sure', 'user']
# 2 ['ruination', 'urination']
# 2 ["ruination's", "urination's"]
# 2 ['run', 'urn']
# 2 ["run's", "urn's"]
# 2 ['runs', 'urns']
# 2 ['runt', 'turn']
# 2 ["runt's", "turn's"]
# 2 ['runts', 'turns']
# 2 ['runway', 'unwary']
# 2 ["ruse's", "user's"]
# 2 ['ruses', 'users']
# 2 ['rushes', 'ushers']
# 2 ['russet', 'surest']
# 2 ['russets', 'trusses']
# 2 ['rust', 'ruts']
# 2 ['rustiest', 'trusties']
# 2 ['rustled', 'strudel']
# 2 ['rusts', 'truss']
# 2 ["saber's", "sabre's"]
# 2 ['sabers', 'sabres']
# 2 ['sachem', 'schema']
# 2 ['sadden', 'sanded']
# 2 ['sagest', 'stages']
# 2 ['sails', 'sisal']
# 3 ["saint's", "satin's", "stain's"]
# 2 ['saints', 'stains']
# 2 ["sale's", "seal's"]
# 2 ['sales', 'seals']
# 2 ["salient's", "saltine's"]
# 2 ['salients', 'saltines']
# 2 ['salivated', 'validates']
# 2 ['sallying', 'signally']
# 2 ['saltest', 'stalest']
# 2 ['saltiness', 'stainless']
# 2 ["saltiness's", "stainless's"]
# 2 ['saltpeter', 'saltpetre']
# 2 ["saltpeter's", "saltpetre's"]
# 3 ['salve', 'slave', 'vales']
# 2 ["salve's", "slave's"]
# 2 ['salved', 'slaved']
# 2 ["salver's", "slaver's"]
# 2 ['salvers', 'slavers']
# 2 ['salves', 'slaves']
# 2 ['salving', 'slaving']
# 2 ['sander', 'snared']
# 2 ['sandier', 'sardine']
# 2 ['sanity', 'satiny']
# 2 ['sateen', 'senate']
# 2 ["sateen's", "senate's"]
# 2 ["satyr's", "stray's"]
# 2 ['satyrs', 'strays']
# 2 ['sauciest', 'suitcase']
# 2 ['save', 'vase']
# 2 ["save's", "vase's"]
# 2 ['saves', 'vases']
# 2 ['saviour', 'various']
# 2 ['saw', 'was']
# 2 ['sawed', 'wades']
# 2 ['sawn', 'swan']
# 2 ["seabird's", "sidebar's"]
# 2 ['seabirds', 'sidebars']
# 3 ['seated', 'sedate', 'teased']
# 2 ['seating', 'teasing']
# 2 ['seduction', 'suctioned']
# 2 ['seer', 'sere']
# 2 ['seething', 'sheeting']
# 2 ['selves', 'vessel']
# 2 ['senator', 'treason']
# 2 ["senator's", "treason's"]
# 2 ['sensor', 'snores']
# 2 ['sensual', 'unseals']
# 2 ['servant', 'taverns']
# 4 ['serve', 'sever', 'veers', 'verse']
# 2 ["serve's", "verse's"]
# 2 ['served', 'versed']
# 3 ['serves', 'severs', 'verses']
# 2 ['serving', 'versing']
# 2 ['settable', 'testable']
# 3 ['setter', 'street', 'tester']
# 3 ["setter's", "street's", "tester's"]
# 4 ['setters', 'streets', 'tersest', 'testers']
# 2 ['setting', 'testing']
# 2 ["settler's", "trestle's"]
# 2 ['settlers', 'trestles']
# 2 ['setup', 'upset']
# 2 ["setup's", "upset's"]
# 2 ['setups', 'upsets']
# 2 ['sewed', 'weeds']
# 2 ['shams', 'smash']
# 2 ["share's", "shear's"]
# 2 ['shattering', 'straighten']
# 3 ['sheet', 'thees', 'these']
# 2 ['sheets', 'theses']
# 2 ["sherd's", "shred's"]
# 2 ['sherds', 'shreds']
# 2 ['shiner', 'shrine']
# 2 ["shiner's", "shrine's"]
# 2 ['shiners', 'shrines']
# 2 ['shipmates', 'steamship']
# 2 ['shittier', 'thirties']
# 2 ['shiver', 'shrive']
# 2 ['shivers', 'shrives']
# 2 ["shoot's", "sooth's"]
# 2 ['shooting', 'soothing']
# 3 ['shout', 'south', 'thous']
# 2 ["shout's", "south's"]
# 2 ['shower', 'whores']
# 2 ["shriek's", "shrike's"]
# 2 ['shrieks', 'shrikes']
# 2 ['sideways', 'waysides']
# 2 ["sidle's", "slide's"]
# 2 ['sidles', 'slides']
# 2 ['sidling', 'sliding']
# 2 ["sifter's", "strife's"]
# 2 ["sign's", "sing's"]
# 2 ["signer's", "singer's"]
# 2 ['signing', 'singing']
# 2 ["signing's", "singing's"]
# 2 ['signs', 'sings']
# 2 ['silly', 'slily']
# 2 ["silo's", "soil's"]
# 2 ['silos', 'soils']
# 2 ["silver's", "sliver's"]
# 2 ['silvering', 'slivering']
# 2 ['silvers', 'slivers']
# 3 ['sinew', 'swine', 'wines']
# 2 ["sinew's", "swine's"]
# 2 ['sinews', 'swines']
# 2 ['singling', 'slinging']
# 2 ["sink's", "skin's"]
# 2 ['sinks', 'skins']
# 2 ["sitar's", "stair's"]
# 2 ['sitars', 'stairs']
# 2 ['site', 'ties']
# 2 ['sites', 'sties']
# 5 ['skate', 'stake', 'steak', 'takes', 'teaks']
# 3 ["skate's", "stake's", "steak's"]
# 3 ['skated', 'staked', 'tasked']
# 3 ['skater', 'streak', 'takers']
# 2 ["skater's", "streak's"]
# 2 ['skaters', 'streaks']
# 3 ['skates', 'stakes', 'steaks']
# 4 ['skating', 'staking', 'takings', 'tasking']
# 2 ['skirting', 'striking']
# 2 ['slander', 'snarled']
# 2 ['slangiest', 'tasseling']
# 4 ['slates', 'stales', 'steals', 'tassel']
# 2 ['sleet', 'steel']
# 2 ["sleet's", "steel's"]
# 2 ['sleets', 'steels']
# 2 ['sleety', 'steely']
# 2 ["slime's", "smile's"]
# 2 ["sloe's", "sole's"]
# 2 ["sloop's", "spool's"]
# 2 ['sloops', 'spools']
# 2 ['slyest', 'styles']
# 2 ['smartened', 'tradesmen']
# 2 ["smother's", "thermos's"]
# 2 ['snake', 'sneak']
# 2 ["snake's", "sneak's"]
# 2 ['snakes', 'sneaks']
# 2 ['snaky', 'yanks']
# 2 ["snap's", "span's"]
# 2 ['snaps', 'spans']
# 2 ['snatched', 'stanched']
# 2 ['snatching', 'stanching']
# 2 ["snip's", "spin's"]
# 2 ['snipes', 'spines']
# 2 ['snips', 'spins']
# 2 ['snoop', 'spoon']
# 2 ["snoop's", "spoon's"]
# 2 ['snooped', 'spooned']
# 2 ['snooping', 'spooning']
# 2 ['snoops', 'spoons']
# 2 ['snot', 'tons']
# 2 ['soapstone', 'teaspoons']
# 2 ['soldier', 'solider']
# 2 ['solitaires', 'solitaries']
# 2 ['somber', 'sombre']
# 2 ['somberly', 'sombrely']
# 3 ['sonnet', 'tenons', 'tonnes']
# 2 ['sorbet', 'strobe']
# 2 ["sorbet's", "strobe's"]
# 2 ['sorbets', 'strobes']
# 2 ['sorest', 'stores']
# 3 ['sorted', 'stored', 'strode']
# 2 ['sorting', 'storing']
# 2 ['sots', 'toss']
# 2 ['sought', 'toughs']
# 2 ['sounding', 'undoings']
# 3 ['sower', 'swore', 'worse']
# 2 ["sower's", "worse's"]
# 2 ['spams', 'spasm']
# 2 ["spare's", "spear's"]
# 2 ['sparsest', 'trespass']
# 2 ['spawning', 'wingspan']
# 2 ['spilt', 'split']
# 2 ['spindled', 'splendid']
# 2 ['spoonfuls', 'spoonsful']
# 2 ["sport's", "strop's"]
# 2 ['sports', 'strops']
# 2 ['spotlight', 'stoplight']
# 2 ["spotlight's", "stoplight's"]
# 2 ['spotlights', 'stoplights']
# 2 ['spouts', 'tossup']
# 2 ["sprat's", "strap's"]
# 2 ['sprats', 'straps']
# 2 ['sprout', 'stupor']
# 2 ["sprout's", "stupor's"]
# 2 ['sprouts', 'stupors']
# 2 ['stack', 'tacks']
# 2 ['stag', 'tags']
# 2 ['stalk', 'talks']
# 2 ['stalker', 'talkers']
# 2 ['stamp', 'tamps']
# 2 ['stank', 'tanks']
# 2 ["star's", "tsar's"]
# 3 ['stared', 'trades', 'treads']
# 2 ['starlets', 'startles']
# 2 ['stars', 'tsars']
# 2 ['start', 'tarts']
# 2 ['startup', 'upstart']
# 2 ["startup's", "upstart's"]
# 2 ['startups', 'upstarts']
# 3 ['state', 'taste', 'teats']
# 2 ["state's", "taste's"]
# 2 ['stated', 'tasted']
# 2 ['stateless', 'tasteless']
# 2 ['statement', 'testament']
# 2 ["statement's", "testament's"]
# 2 ['statements', 'testaments']
# 3 ['stater', 'taster', 'treats']
# 2 ['states', 'tastes']
# 2 ['stateside', 'steadiest']
# 2 ['stating', 'tasting']
# 2 ['statute', 'tautest']
# 2 ['staunched', 'unscathed']
# 2 ['stayed', 'steady']
# 2 ['stent', 'tents']
# 3 ['stew', 'west', 'wets']
# 2 ["stew's", "west's"]
# 2 ['steward', 'strawed']
# 2 ['stewed', 'tweeds']
# 2 ['stewing', 'twinges']
# 2 ['stick', 'ticks']
# 2 ['stickler', 'trickles']
# 2 ['stiff', 'tiffs']
# 3 ['stiller', 'tillers', 'trellis']
# 2 ['stilt', 'tilts']
# 2 ['sting', 'tings']
# 2 ['stingray', 'straying']
# 2 ['stinker', 'tinkers']
# 2 ['stint', 'tints']
# 2 ['stipple', 'tipples']
# 2 ['stoat', 'toast']
# 2 ["stoat's", "toast's"]
# 2 ['stoats', 'toasts']
# 2 ['stoke', 'tokes']
# 2 ['stoker', 'stroke']
# 2 ["stoker's", "stroke's"]
# 2 ['stokers', 'strokes']
# 3 ['stoner', 'tenors', 'tensor']
# 2 ['stoners', 'tensors']
# 2 ['stopping', 'toppings']
# 3 ['story', 'troys', 'tyros']
# 2 ['stout', 'touts']
# 2 ['stove', 'votes']
# 3 ['stow', 'tows', 'twos']
# 2 ['strain', 'trains']
# 2 ['strapping', 'trappings']
# 2 ["strapping's", "trappings's"]
# 2 ['straw', 'warts']
# 2 ['strew', 'wrest']
# 2 ['strewed', 'wrested']
# 2 ['strewing', 'wresting']
# 2 ['strews', 'wrests']
# 2 ['striated', 'tardiest']
# 2 ['strident', 'tridents']
# 2 ['strike', 'trikes']
# 2 ['strip', 'trips']
# 2 ['striptease', 'tapestries']
# 2 ['stroll', 'trolls']
# 2 ['strove', 'voters']
# 2 ['struck', 'trucks']
# 2 ['strumpet', 'trumpets']
# 2 ['strut', 'trust']
# 2 ["strut's", "trust's"]
# 2 ['struts', 'trusts']
# 2 ['stuck', 'tucks']
# 2 ['student', 'stunted']
# 2 ['stumble', 'tumbles']
# 3 ['stumbler', 'tumblers', 'tumbrels']
# 2 ['stye', 'yest']
# 2 ['sue', 'use']
# 2 ['sues', 'uses']
# 2 ['suing', 'using']
# 2 ['suites', 'tissue']
# 2 ['sump', 'umps']
# 2 ['sunblock', 'unblocks']
# 2 ['sunburned', 'unburdens']
# 2 ['sundering', 'undersign']
# 2 ['sunders', 'undress']
# 2 ['sunspot', 'unstops']
# 2 ['supper', 'uppers']
# 2 ['surge', 'urges']
# 2 ['suture', 'uterus']
# 2 ["suture's", "uterus's"]
# 2 ['swag', 'wags']
# 2 ['swallow', 'wallows']
# 2 ["swap's", "wasp's"]
# 2 ['swaps', 'wasps']
# 2 ['swarm', 'warms']
# 2 ['swarthiest', 'sweatshirt']
# 2 ['swashing', 'washings']
# 3 ['swath', 'thaws', 'whats']
# 3 ['sway', 'ways', 'yaws']
# 2 ["sway's", "yaws's"]
# 3 ['swear', 'wares', 'wears']
# 2 ['swearer', 'wearers']
# 2 ['sweat', 'waste']
# 2 ["sweat's", "waste's"]
# 2 ['sweatier', 'weariest']
# 2 ['sweats', 'wastes']
# 2 ['sweep', 'weeps']
# 2 ['sweeper', 'weepers']
# 2 ['sweeping', 'weepings']
# 2 ['sweet', 'weest']
# 2 ['swell', 'wells']
# 3 ['swelter', 'welters', 'wrestle']
# 2 ["swelter's", "wrestle's"]
# 2 ['swelters', 'wrestles']
# 2 ['swig', 'wigs']
# 2 ['swill', 'wills']
# 2 ['swindles', 'wildness']
# 2 ['swing', 'wings']
# 2 ['swinger', 'wingers']
# 2 ['swipe', 'wipes']
# 2 ['swisher', 'wishers']
# 2 ['sword', 'words']
# 2 ['tablespoonfuls', 'tablespoonsful']
# 2 ["tabu's", "tuba's"]
# 2 ['taint', 'titan']
# 2 ["taint's", "titan's"]
# 2 ['taints', 'titans']
# 2 ['take', 'teak']
# 2 ["take's", "teak's"]
# 2 ["tale's", "teal's"]
# 2 ['talon', 'tonal']
# 2 ['tannest', 'tenants']
# 2 ['tardier', 'tarried']
# 2 ['tartest', 'tatters']
# 2 ['teaspoonfuls', 'teaspoonsful']
# 2 ['teazel', 'teazle']
# 2 ["teazel's", "teazle's"]
# 2 ['teazels', 'teazles']
# 2 ['teens', 'tense']
# 2 ['tenon', 'tonne']
# 2 ["tenon's", "tonne's"]
# 2 ['tenor', 'toner']
# 2 ["terrain's", "trainer's"]
# 2 ['terrapins', 'transpire']
# 2 ['thaw', 'what']
# 2 ["thaw's", "what's"]
# 2 ['theater', 'theatre']
# 2 ["theater's", "theatre's"]
# 2 ['theaters', 'theatres']
# 2 ['theist', 'tithes']
# 3 ['thickest', 'thickets', 'thickset']
# 3 ['throw', 'worth', 'wroth']
# 2 ["throw's", "worth's"]
# 2 ['thrust', 'truths']
# 2 ['tilde', 'tiled']
# 2 ['tilted', 'titled']
# 2 ['tilting', 'titling']
# 2 ['timber', 'timbre']
# 2 ["timber's", "timbre's"]
# 2 ['timbers', 'timbres']
# 2 ['tired', 'tried']
# 2 ['titters', 'tritest']
# 2 ['toady', 'today']
# 2 ["toady's", "today's"]
# 2 ['tocsin', 'tonics']
# 2 ['torpedo', 'trooped']
# 2 ['torpid', 'tripod']
# 2 ['tort', 'trot']
# 2 ["tort's", "trot's"]
# 2 ['torts', 'trots']
# 2 ['tost', 'tots']
# 3 ['tow', 'two', 'wot']
# 2 ["tow's", "two's"]
# 2 ['tower', 'wrote']
# 2 ['town', 'wont']
# 2 ["town's", "wont's"]
# 2 ["trade's", "tread's"]
# 2 ['trail', 'trial']
# 2 ["trail's", "trial's"]
# 2 ['trailed', 'trialed']
# 2 ['trailing', 'trialing']
# 2 ['trails', 'trials']
# 2 ['travel', 'varlet']
# 2 ["travel's", "varlet's"]
# 2 ['travels', 'varlets']
# 2 ['tribune', 'turbine']
# 2 ["tribune's", "turbine's"]
# 2 ['tribunes', 'turbines']
# 2 ['trout', 'tutor']
# 2 ["trout's", "tutor's"]
# 2 ['trouts', 'tutors']
# 2 ['troy', 'tyro']
# 2 ['truest', 'utters']
# 2 ['tumbler', 'tumbrel']
# 2 ["tumbler's", "tumbrel's"]
# 2 ['tuners', 'unrest']
# 2 ['tunes', 'unset']
# 2 ['twist', 'twits']
# 2 ['unaltered', 'unrelated']
# 2 ['unbar', 'urban']
# 2 ['underflow', 'wonderful']
# 2 ['undersigns', 'undressing']
# 2 ['unions', 'unison']
# 2 ['unite', 'untie']
# 2 ['united', 'untied']
# 2 ['unites', 'unties']
# 2 ['vale', 'veal']
# 2 ["vale's", "veal's"]
# 2 ['vast', 'vats']
# 2 ['vein', 'vine']
# 2 ["vein's", "vine's"]
# 2 ['veins', 'vines']
# 2 ['vest', 'vets']
# 2 ['veto', 'vote']
# 2 ["veto's", "vote's"]
# 2 ['vies', 'vise']
# 2 ['view', 'wive']
# 2 ['views', 'wives']
# 2 ['vowels', 'wolves']
# 2 ['waist', 'waits']
# 2 ['waiters', 'wariest']
# 2 ['waiver', 'wavier']
# 2 ['wake', 'weak']
# 2 ['wale', 'weal']
# 2 ["wale's", "weal's"]
# 2 ['wales', 'weals']
# 3 ['wander', 'warden', 'warned']
# 2 ['wanders', 'wardens']
# 2 ['wanes', 'weans']
# 2 ["want's", "wasn't"]
# 2 ['ware', 'wear']
# 2 ["ware's", "wear's"]
# 2 ['warp', 'wrap']
# 2 ["warp's", "wrap's"]
# 2 ['warps', 'wraps']
# 2 ["waster's", "waters's"]
# 2 ['way', 'yaw']
# 2 ["way's", "yaw's"]
# 3 ['weather', 'whereat', 'wreathe']
# 2 ['weathers', 'wreathes']
# 2 ['weir', 'wire']
# 2 ["weir's", "wire's"]
# 3 ['weird', 'wider', 'wired']
# 3 ['weirs', 'wires', 'wiser']
# 2 ['whale', 'wheal']
# 2 ["whale's", "wheal's"]
# 2 ['whales', 'wheals']
# 2 ['wheedle', 'wheeled']
# 2 ['whist', 'whits']
# 2 ['whit', 'with']
# 3 ['whiter', 'wither', 'writhe']
# 2 ['widen', 'wined']
# 2 ['wield', 'wiled']
# 2 ['wiggler', 'wriggle']
# 2 ["wiggler's", "wriggle's"]
# 2 ['wigglers', 'wriggles']
# 2 ['wist', 'wits']
# 2 ['withers', 'writhes']
# 2 ['woodworm', 'wormwood']
# 2 ['wriest', 'writes']
# 2 ['wrist', 'writs']

# %%
def print_anagram_sets_in_order(d):
    """Prints the anagram sets in d in decreasing order of size.

    d: map from words to list of their anagrams
    """
    # make a list of (length, word pairs)
    t = []
    for v in d.values():
        if len(v) > 1:
            t.append((len(v), v))

    # sort in ascending order of length
    t.sort()

    # print the sorted list
    for x in t:
        print(x)

# %%
print_anagram_sets_in_order(anagram_dict)
# Out:
# (2, ['Abner', 'Arneb'])
# (2, ["Abner's", "Arneb's"])
# (2, ['Aires', 'Aries'])
# (2, ["Aires's", "Aries's"])
# (2, ['Alar', 'Aral'])
# (2, ["Alar's", "Aral's"])
# (2, ['Alberio', 'Albireo'])
# (2, ["Alberio's", "Albireo's"])
# (2, ['Andre', 'Arden'])
# (2, ["Andre's", "Arden's"])
# (2, ['Annmarie', 'Armenian'])
# (2, ["Annmarie's", "Armenian's"])
# (2, ['Arno', 'Aron'])
# (2, ["Arno's", "Aron's"])
# (2, ['Atari', 'Atria'])
# (2, ["Atari's", "Atria's"])
# (2, ['Banneker', 'Bernanke'])
# (2, ["Banneker's", "Bernanke's"])
# (2, ['Belgian', 'Bengali'])
# (2, ["Belgian's", "Bengali's"])
# (2, ['Bellow', 'Bowell'])
# (2, ["Bellow's", "Bowell's"])
# (2, ['Bert', 'Bret'])
# (2, ["Bert's", "Bret's"])
# (2, ['Biogen', 'Boeing'])
# (2, ["Biogen's", "Boeing's"])
# (2, ['Booker', 'Brooke'])
# (2, ["Booker's", "Brooke's"])
# (2, ['Born', 'Brno'])
# (2, ["Born's", "Brno's"])
# (2, ['Brain', 'Brian'])
# (2, ["Brain's", "Brian's"])
# (2, ['Branden', 'Brendan'])
# (2, ["Branden's", "Brendan's"])
# (2, ['Breton', 'Bronte'])
# (2, ["Breton's", "Bronte's"])
# (2, ['Brut', 'Burt'])
# (2, ["Brut's", "Burt's"])
# (2, ['Bryon', 'Byron'])
# (2, ["Bryon's", "Byron's"])
# (2, ['Callisto', 'Castillo'])
# (2, ["Callisto's", "Castillo's"])
# (2, ['Canon', 'Conan'])
# (2, ["Canon's", "Conan's"])
# (2, ['Cantor', 'Carnot'])
# (2, ["Cantor's", "Carnot's"])
# (2, ['Carla', 'Clara'])
# (2, ["Carla's", "Clara's"])
# (2, ['Carlo', 'Carol'])
# (2, ["Carlo's", "Carol's"])
# (2, ['Carmine', 'Crimean'])
# (2, ["Carmine's", "Crimean's"])
# (2, ['Caroline', 'Cornelia'])
# (2, ["Caroline's", "Cornelia's"])
# (2, ['Carter', 'Crater'])
# (2, ["Carter's", "Crater's"])
# (2, ['Cary', 'Cray'])
# (2, ["Cary's", "Cray's"])
# (2, ["Castor's", "Castro's"])
# (2, ['Ceylon', 'Conley'])
# (2, ["Ceylon's", "Conley's"])
# (2, ['Chaitin', 'Chianti'])
# (2, ["Chaitin's", "Chianti's"])
# (2, ['Christian', 'Christina'])
# (2, ["Christian's", "Christina's"])
# (2, ['Clemons', 'Clemson'])
# (2, ["Clemons's", "Clemson's"])
# (2, ['Cleo', 'Cole'])
# (2, ["Cleo's", "Cole's"])
# (2, ['Dali', 'Dial'])
# (2, ["Dali's", "Dial's"])
# (2, ['Dalian', 'Danial'])
# (2, ["Dalian's", "Danial's"])
# (2, ['Dannie', 'Dianne'])
# (2, ["Dannie's", "Dianne's"])
# (2, ['Dino', 'Dion'])
# (2, ["Dino's", "Dion's"])
# (2, ['Dionne', 'Donnie'])
# (2, ["Dionne's", "Donnie's"])
# (2, ['Dunbar', 'Durban'])
# (2, ["Dunbar's", "Durban's"])
# (2, ['Earnest', 'Eastern'])
# (2, ['Eire', 'Erie'])
# (2, ["Eire's", "Erie's"])
# (2, ['Elam', 'Elma'])
# (2, ["Elam's", "Elma's"])
# (2, ['Elanor', 'Elnora'])
# (2, ["Elanor's", "Elnora's"])
# (2, ['Elias', 'Elisa'])
# (2, ["Elias's", "Elisa's"])
# (2, ['Elise', 'Elsie'])
# (2, ["Elise's", "Elsie's"])
# (2, ['Eliseo', 'Eloise'])
# (2, ["Eliseo's", "Eloise's"])
# (2, ['Fannie', 'Fenian'])
# (2, ["Fannie's", "Fenian's"])
# (2, ['Forest', 'Foster'])
# (2, ["Forest's", "Foster's"])
# (2, ['Forrest', 'Forster'])
# (2, ["Forrest's", "Forster's"])
# (2, ['Freida', 'Frieda'])
# (2, ["Freida's", "Frieda's"])
# (2, ['Frey', 'Frye'])
# (2, ["Frey's", "Frye's"])
# (2, ['Gael', 'Gale'])
# (2, ["Gael's", "Gale's"])
# (2, ['Gail', 'Gila'])
# (2, ["Gail's", "Gila's"])
# (2, ['Gary', 'Gray'])
# (2, ["Gary's", "Gray's"])
# (2, ['Georgian', 'Georgina'])
# (2, ["Georgian's", "Georgina's"])
# (2, ['Handy', 'Haydn'])
# (2, ["Handy's", "Haydn's"])
# (2, ['Hardy', 'Hydra'])
# (2, ["Hardy's", "Hydra's"])
# (2, ['Ian', 'Ina'])
# (2, ["Ian's", "Ina's"])
# (2, ['Jaime', 'Jamie'])
# (2, ["Jaime's", "Jamie's"])
# (2, ['Jane', 'Jean'])
# (2, ["Jane's", "Jean's"])
# (2, ['Janine', 'Jannie'])
# (2, ["Janine's", "Jannie's"])
# (2, ['Jason', 'Jonas'])
# (2, ["Jason's", "Jonas's"])
# (2, ['Jeanine', 'Jeannie'])
# (2, ["Jeanine's", "Jeannie's"])
# (2, ['Jeffery', 'Jeffrey'])
# (2, ["Jeffery's", "Jeffrey's"])
# (2, ['Keith', 'Kieth'])
# (2, ["Keith's", "Kieth's"])
# (2, ['Kirsten', 'Kristen'])
# (2, ["Kirsten's", "Kristen's"])
# (2, ['Klein', 'Kline'])
# (2, ["Klein's", "Kline's"])
# (2, ['Laius', 'Luisa'])
# (2, ["Laius's", "Luisa's"])
# (2, ['Lauri', 'Luria'])
# (2, ["Lauri's", "Luria's"])
# (2, ['Leila', 'Lelia'])
# (2, ["Leila's", "Lelia's"])
# (2, ['Lenny', 'Lynne'])
# (2, ["Lenny's", "Lynne's"])
# (2, ['Leno', 'Leon'])
# (2, ["Leno's", "Leon's"])
# (2, ['Lenora', 'Lorena'])
# (2, ["Lenora's", "Lorena's"])
# (2, ['Lenore', 'Lorene'])
# (2, ["Lenore's", "Lorene's"])
# (2, ['Loire', 'Lorie'])
# (2, ["Loire's", "Lorie's"])
# (2, ['Mai', 'Mia'])
# (2, ["Mai's", "Mia's"])
# (2, ['Malian', 'Manila'])
# (2, ["Malian's", "Manila's"])
# (2, ['Malians', 'Manilas'])
# (2, ['Maoism', 'Mimosa'])
# (2, ["Maoism's", "Mimosa's"])
# (2, ['Marat', 'Marta'])
# (2, ["Marat's", "Marta's"])
# (2, ['Marcie', 'Mercia'])
# (2, ["Marcie's", "Mercia's"])
# (2, ['Mari', 'Mira'])
# (2, ["Mari's", "Mira's"])
# (2, ['Marian', 'Marina'])
# (2, ["Marian's", "Marina's"])
# (2, ['Marlon', 'Molnar'])
# (2, ["Marlon's", "Molnar's"])
# (2, ['Martian', 'Martina'])
# (2, ["Martian's", "Martina's"])
# (2, ['Mary', 'Myra'])
# (2, ["Mary's", "Myra's"])
# (2, ['Maseru', 'Mauser'])
# (2, ["Maseru's", "Mauser's"])
# (2, ['Meade', 'Medea'])
# (2, ["Meade's", "Medea's"])
# (2, ['Michael', 'Micheal'])
# (2, ["Michael's", "Micheal's"])
# (2, ['Monet', 'Monte'])
# (2, ["Monet's", "Monte's"])
# (2, ['Monroe', 'Moreno'])
# (2, ["Monroe's", "Moreno's"])
# (2, ['Moor', 'Moro'])
# (2, ["Moor's", "Moro's"])
# (2, ['Neil', 'Nile'])
# (2, ["Neil's", "Nile's"])
# (2, ['Neo', 'Noe'])
# (2, ["Neo's", "Noe's"])
# (2, ['Nobel', 'Noble'])
# (2, ["Nobel's", "Noble's"])
# (2, ['Palau', 'Paula'])
# (2, ["Palau's", "Paula's"])
# (2, ['Paris', 'Parsi'])
# (2, ["Paris's", "Parsi's"])
# (2, ['Peel', 'Pele'])
# (2, ["Peel's", "Pele's"])
# (2, ['Ramon', 'Roman'])
# (2, ["Ramon's", "Roman's"])
# (2, ['Regor', 'Roger'])
# (2, ["Regor's", "Roger's"])
# (2, ['Reid', 'Ride'])
# (2, ["Reid's", "Ride's"])
# (2, ['Roach', 'Rocha'])
# (2, ["Roach's", "Rocha's"])
# (2, ['Roland', 'Ronald'])
# (2, ["Roland's", "Ronald's"])
# (2, ['Rosanne', 'Roseann'])
# (2, ["Rosanne's", "Roseann's"])
# (2, ['Saar', 'Sara'])
# (2, ["Saar's", "Sara's"])
# (2, ['Sakha', 'Shaka'])
# (2, ["Sakha's", "Shaka's"])
# (2, ['Salem', 'Selma'])
# (2, ["Salem's", "Selma's"])
# (2, ['Santa', 'Satan'])
# (2, ["Santa's", "Satan's"])
# (2, ['Sedna', 'Snead'])
# (2, ["Sedna's", "Snead's"])
# (2, ['Serpens', 'Spenser'])
# (2, ["Serpens's", "Spenser's"])
# (2, ['Seton', 'Stone'])
# (2, ["Seton's", "Stone's"])
# (2, ['Sharpe', 'Sherpa'])
# (2, ["Sharpe's", "Sherpa's"])
# (2, ['Sheila', 'Shelia'])
# (2, ["Sheila's", "Shelia's"])
# (2, ['Shetland', 'Stendhal'])
# (2, ["Shetland's", "Stendhal's"])
# (2, ['Sibyl', 'Sybil'])
# (2, ["Sibyl's", "Sybil's"])
# (2, ['Stein', 'Stine'])
# (2, ["Stein's", "Stine's"])
# (2, ['Sumerian', 'Suriname'])
# (2, ["Sumerian's", "Suriname's"])
# (2, ['Thais', 'Tisha'])
# (2, ['Titus', 'Tutsi'])
# (2, ["Titus's", "Tutsi's"])
# (2, ['Tory', 'Troy'])
# (2, ["Tory's", "Troy's"])
# (2, ['Trey', 'Tyre'])
# (2, ["Trey's", "Tyre's"])
# (2, ['Tucson', 'Tuscon'])
# (2, ["Tucson's", "Tuscon's"])
# (2, ['Valarie', 'Valeria'])
# (2, ["Valarie's", "Valeria's"])
# (2, ['Warner', 'Warren'])
# (2, ["Warner's", "Warren's"])
# (2, ['Wiley', 'Wylie'])
# (2, ["Wiley's", "Wylie's"])
# (2, ['Yates', 'Yeats'])
# (2, ["Yates's", "Yeats's"])
# (2, ['abeam', 'ameba'])
# (2, ['abhorred', 'harbored'])
# (2, ['abhorring', 'harboring'])
# (2, ['abides', 'biased'])
# (2, ['able', 'bale'])
# (2, ['abler', 'blare'])
# (2, ['aboard', 'abroad'])
# (2, ['abode', 'adobe'])
# (2, ["abode's", "adobe's"])
# (2, ['abodes', 'adobes'])
# (2, ['abridge', 'brigade'])
# (2, ['abridges', 'brigades'])
# (2, ['abuse', 'beaus'])
# (2, ['accouterments', 'accoutrements'])
# (2, ['accrual', 'caracul'])
# (2, ["accrual's", "caracul's"])
# (2, ['accrues', 'accuser'])
# (2, ['aces', 'case'])
# (2, ['ache', 'each'])
# (2, ['aches', 'chase'])
# (2, ["acme's", "mace's"])
# (2, ['acmes', 'maces'])
# (2, ['acne', 'cane'])
# (2, ["acne's", "cane's"])
# (2, ['aconites', 'canoeist'])
# (2, ['acrider', 'carried'])
# (2, ['act', 'cat'])
# (2, ["act's", "cat's"])
# (2, ['acted', 'cadet'])
# (2, ['action', 'cation'])
# (2, ["action's", "cation's"])
# (2, ['actions', 'cations'])
# (2, ['actuator', 'autocrat'])
# (2, ["actuator's", "autocrat's"])
# (2, ['actuators', 'autocrats'])
# (2, ['acuter', 'curate'])
# (2, ['add', 'dad'])
# (2, ["adder's", "dread's"])
# (2, ['addle', 'laded'])
# (2, ['addles', 'saddle'])
# (2, ['adds', 'dads'])
# (2, ['adept', 'taped'])
# (2, ['adepts', 'pasted'])
# (2, ['adhere', 'header'])
# (2, ['adhered', 'redhead'])
# (2, ['adjuster', 'readjust'])
# (2, ['adjusters', 'readjusts'])
# (2, ['admirer', 'married'])
# (2, ["admirer's", "married's"])
# (2, ['admirers', 'marrieds'])
# (2, ['admits', 'amidst'])
# (2, ['admonition', 'domination'])
# (2, ["admonition's", "domination's"])
# (2, ['adore', 'oared'])
# (2, ['adores', 'soared'])
# (2, ['adorn', 'radon'])
# (2, ['ads', 'sad'])
# (2, ['advances', 'canvased'])
# (2, ['adverb', 'braved'])
# (2, ['adverts', 'starved'])
# (2, ['advise', 'visaed'])
# (2, ['adze', 'daze'])
# (2, ["adze's", "daze's"])
# (2, ['adzes', 'dazes'])
# (2, ['aeries', 'easier'])
# (2, ['aery', 'year'])
# (2, ["aery's", "year's"])
# (2, ['affair', 'raffia'])
# (2, ["affair's", "raffia's"])
# (2, ['afield', 'failed'])
# (2, ['aft', 'fat'])
# (2, ['afterwords', 'forwardest'])
# (2, ['agar', 'raga'])
# (2, ["agar's", "raga's"])
# (2, ['ageism', 'images'])
# (2, ['ages', 'sage'])
# (2, ['aging', 'nigga'])
# (2, ["aging's", "nigga's"])
# (2, ['agings', 'niggas'])
# (2, ['agism', 'sigma'])
# (2, ['agree', 'eager'])
# (2, ['agreed', 'geared'])
# (2, ['agrees', 'grease'])
# (2, ['ah', 'ha'])
# (2, ['aide', 'idea'])
# (2, ["aide's", "idea's"])
# (2, ['ailed', 'ideal'])
# (2, ['ailments', 'manliest'])
# (2, ['ails', 'sail'])
# (2, ['aimed', 'media'])
# (2, ['airless', 'serials'])
# (2, ['airman', 'marina'])
# (2, ["airman's", "marina's"])
# (2, ['airs', 'sari'])
# (2, ['aisles', 'lassie'])
# (2, ['ajar', 'raja'])
# (2, ['alarming', 'marginal'])
# (2, ['alarmingly', 'marginally'])
# (2, ['alb', 'lab'])
# (2, ["alb's", "lab's"])
# (2, ['alcove', 'coeval'])
# (2, ["alcove's", "coeval's"])
# (2, ['alcoves', 'coevals'])
# (2, ['ale', 'lea'])
# (2, ["ale's", "lea's"])
# (2, ['alga', 'gala'])
# (2, ["alga's", "gala's"])
# (2, ['algorithm', 'logarithm'])
# (2, ["algorithm's", "logarithm's"])
# (2, ['algorithmic', 'logarithmic'])
# (2, ['algorithms', 'logarithms'])
# (2, ['alien', 'aline'])
# (2, ['alignment', 'lamenting'])
# (2, ['aligns', 'signal'])
# (2, ['alinement', 'lineament'])
# (2, ["alinement's", "lineament's"])
# (2, ['alinements', 'lineaments'])
# (2, ['alining', 'nailing'])
# (2, ['alit', 'tail'])
# (2, ['allergies', 'galleries'])
# (2, ["allergy's", "gallery's"])
# (2, ['allot', 'atoll'])
# (2, ['allots', 'atolls'])
# (2, ['allotted', 'totalled'])
# (2, ['allotting', 'totalling'])
# (2, ['allover', 'overall'])
# (2, ['allows', 'sallow'])
# (2, ['alloy', 'loyal'])
# (2, ['allure', 'laurel'])
# (2, ["allure's", "laurel's"])
# (2, ['allures', 'laurels'])
# (2, ["alms's", "slam's"])
# (2, ['aloft', 'float'])
# (2, ['altars', 'astral'])
# (2, ['altho', 'loath'])
# (2, ['altitude', 'latitude'])
# (2, ["altitude's", "latitude's"])
# (2, ['altitudes', 'latitudes'])
# (2, ['altruism', 'muralist'])
# (2, ["altruism's", "muralist's"])
# (2, ['alum', 'maul'])
# (2, ["alum's", "maul's"])
# (2, ['alumna', 'manual'])
# (2, ["alumna's", "manual's"])
# (2, ['alums', 'mauls'])
# (2, ['am', 'ma'])
# (2, ['amble', 'blame'])
# (2, ["amble's", "blame's"])
# (2, ['ambles', 'blames'])
# (2, ['amenity', 'anytime'])
# (2, ['amid', 'maid'])
# (2, ['among', 'mango'])
# (2, ['amortize', 'atomizer'])
# (2, ['amortizes', 'atomizers'])
# (2, ['amp', 'map'])
# (2, ["amp's", "map's"])
# (2, ['amphitheater', 'amphitheatre'])
# (2, ["amphitheater's", "amphitheatre's"])
# (2, ['amphitheaters', 'amphitheatres'])
# (2, ['ample', 'maple'])
# (2, ['amply', 'palmy'])
# (2, ['amuses', 'assume'])
# (2, ['anapest', 'peasant'])
# (2, ["anapest's", "peasant's"])
# (2, ['anapests', 'peasants'])
# (2, ['ancestries', 'resistance'])
# (2, ['ancienter', 'nectarine'])
# (2, ['anemic', 'cinema'])
# (2, ["angel's", "angle's"])
# (2, ['anger', 'range'])
# (2, ["anger's", "range's"])
# (2, ['angering', 'enraging'])
# (2, ['angers', 'ranges'])
# (2, ['angled', 'dangle'])
# (2, ['angry', 'rangy'])
# (2, ['anklets', 'lankest'])
# (2, ['annoyed', 'anodyne'])
# (2, ['annuities', 'insinuate'])
# (2, ['anoint', 'nation'])
# (2, ['anoints', 'nations'])
# (2, ['answers', 'rawness'])
# (2, ['ant', 'tan'])
# (2, ["ant's", "tan's"])
# (2, ['antagonist', 'stagnation'])
# (2, ["antagonist's", "stagnation's"])
# (2, ['ante', 'neat'])
# (2, ['anthologies', 'theologians'])
# (2, ['antidotes', 'stationed'])
# (2, ["antigen's", "gentian's"])
# (2, ['antigens', 'gentians'])
# (2, ['antiparticles', 'paternalistic'])
# (2, ["antler's", "rental's"])
# (2, ['antlers', 'rentals'])
# (2, ['ants', 'tans'])
# (2, ['anvils', 'silvan'])
# (2, ['any', 'nay'])
# (2, ['ape', 'pea'])
# (2, ["ape's", "pea's"])
# (2, ['aplenty', 'penalty'])
# (2, ['appal', 'papal'])
# (2, ['appealing', 'lagniappe'])
# (2, ['append', 'napped'])
# (2, ['appends', 'snapped'])
# (2, ['appraised', 'disappear'])
# (2, ['apprise', 'sappier'])
# (2, ['apps', 'paps'])
# (2, ['aprons', 'parson'])
# (2, ['arc', 'car'])
# (2, ["arc's", "car's"])
# (2, ['arch', 'char'])
# (2, ["arch's", "char's"])
# (2, ['archaism', 'charisma'])
# (2, ["archaism's", "charisma's"])
# (2, ['archest', 'chaster'])
# (2, ['arching', 'chagrin'])
# (2, ['arcked', 'racked'])
# (2, ['arcking', 'racking'])
# (2, ['ardent', 'ranted'])
# (2, ['argue', 'auger'])
# (2, ['argues', 'augers'])
# (2, ['arid', 'raid'])
# (2, ['arise', 'raise'])
# (2, ['arises', 'raises'])
# (2, ["arm's", "ram's"])
# (2, ['armadas', 'madrasa'])
# (2, ['armed', 'dream'])
# (2, ['armfuls', 'armsful'])
# (2, ['arming', 'margin'])
# (2, ['armpit', 'impart'])
# (2, ['armpits', 'imparts'])
# (2, ['armrest', 'smarter'])
# (2, ['arrogant', 'tarragon'])
# (2, ["arson's", "sonar's"])
# (2, ['article', 'recital'])
# (2, ["article's", "recital's"])
# (2, ['articles', 'recitals'])
# (2, ['artisan', 'tsarina'])
# (2, ["artisan's", "tsarina's"])
# (2, ['artisans', 'tsarinas'])
# (2, ["artist's", "strait's"])
# (2, ['artistes', 'artsiest'])
# (2, ['artists', 'straits'])
# (2, ['artsier', 'tarries'])
# (2, ['arty', 'tray'])
# (2, ['ascend', 'dances'])
# (2, ["ascent's", "stance's"])
# (2, ['ascents', 'stances'])
# (2, ['ascertain', 'sectarian'])
# (2, ['ascertains', 'sectarians'])
# (2, ["ascot's", "coast's"])
# (2, ['ascots', 'coasts'])
# (2, ['ascribed', 'carbides'])
# (2, ['ash', 'has'])
# (2, ['ashore', 'hoarse'])
# (2, ['ashy', 'hays'])
# (2, ['asides', 'daises'])
# (2, ['askew', 'wakes'])
# (2, ['aspirant', 'partisan'])
# (2, ["aspirant's", "partisan's"])
# (2, ['aspirants', 'partisans'])
# (2, ['aspirate', 'parasite'])
# (2, ["aspirate's", "parasite's"])
# (2, ['aspirated', 'disparate'])
# (2, ['aspirates', 'parasites'])
# (2, ['aspiring', 'praising'])
# (2, ['assaying', 'gainsays'])
# (2, ['assent', 'sanest'])
# (2, ['assess', 'sasses'])
# (2, ['assigns', 'sassing'])
# (2, ['assort', 'roasts'])
# (2, ['assorting', 'organists'])
# (2, ['assuage', 'sausage'])
# (2, ['assuages', 'sausages'])
# (2, ['astern', 'sterna'])
# (2, ['astute', 'statue'])
# (2, ['astuter', 'stature'])
# (2, ['astutest', 'statutes'])
# (2, ['ateliers', 'earliest'])
# (2, ['atheists', 'hastiest'])
# (2, ['atom', 'moat'])
# (2, ["atom's", "moat's"])
# (2, ['atoms', 'moats'])
# (2, ['atone', 'oaten'])
# (2, ['atoned', 'donate'])
# (2, ['atria', 'tiara'])
# (2, ['attentive', 'tentative'])
# (2, ['attentively', 'tentatively'])
# (2, ['attic', 'tacit'])
# (2, ['attics', 'static'])
# (2, ['attuned', 'taunted'])
# (2, ['attunes', 'tetanus'])
# (2, ['attuning', 'taunting'])
# (2, ['auction', 'caution'])
# (2, ["auction's", "caution's"])
# (2, ['auctioning', 'cautioning'])
# (2, ['auctions', 'cautions'])
# (2, ['aunt', 'tuna'])
# (2, ["aunt's", "tuna's"])
# (2, ['aunts', 'tunas'])
# (2, ['austerer', 'treasure'])
# (2, ['avails', 'saliva'])
# (2, ['avarice', 'caviare'])
# (2, ["avarice's", "caviare's"])
# (2, ['avenger', 'engrave'])
# (2, ['avengers', 'engraves'])
# (2, ['aver', 'rave'])
# (2, ['avid', 'diva'])
# (2, ['awed', 'wade'])
# (2, ['awl', 'law'])
# (2, ["awl's", "law's"])
# (2, ['awning', 'waning'])
# (2, ['awry', 'wary'])
# (2, ['aye', 'yea'])
# (2, ["aye's", "yea's"])
# (2, ['babbled', 'blabbed'])
# (2, ['babbling', 'blabbing'])
# (2, ['babiest', 'tabbies'])
# (2, ['backrest', 'brackets'])
# (2, ['backward', 'drawback'])
# (2, ['backwards', 'drawbacks'])
# (2, ['bacterial', 'calibrate'])
# (2, ['bad', 'dab'])
# (2, ["bad's", "dab's"])
# (2, ['bag', 'gab'])
# (2, ["bag's", "gab's"])
# (2, ['bagel', 'gable'])
# (2, ["bagel's", "gable's"])
# (2, ['bagels', 'gables'])
# (2, ['bags', 'gabs'])
# (2, ['bails', 'basil'])
# (2, ['bake', 'beak'])
# (2, ["bake's", "beak's"])
# (2, ['bakes', 'beaks'])
# (2, ['balder', 'blared'])
# (2, ['baled', 'blade'])
# (2, ['baleen', 'enable'])
# (2, ['bales', 'sable'])
# (2, ['ballsier', 'liberals'])
# (2, ['balm', 'lamb'])
# (2, ["balm's", "lamb's"])
# (2, ['balms', 'lambs'])
# (2, ['balsa', 'basal'])
# (2, ['ban', 'nab'])
# (2, ['banalities', 'insatiable'])
# (2, ['bandier', 'brained'])
# (2, ['bane', 'bean'])
# (2, ["bane's", "bean's"])
# (2, ['banes', 'beans'])
# (2, ['bans', 'nabs'])
# (2, ['bantams', 'batsman'])
# (2, ['bar', 'bra'])
# (2, ["bar's", "bra's"])
# (2, ['bare', 'bear'])
# (2, ['barest', 'breast'])
# (2, ['bargained', 'gabardine'])
# (2, ['barging', 'garbing'])
# (2, ['barking', 'braking'])
# (2, ['barn', 'bran'])
# (2, ["barn's", "bran's"])
# (2, ['bars', 'bras'])
# (2, ['based', 'beads'])
# (2, ['basely', 'belays'])
# (2, ['basis', 'bassi'])
# (2, ["bast's", "stab's"])
# (2, ['bastion', 'obtains'])
# (2, ['bat', 'tab'])
# (2, ["bat's", "tab's"])
# (2, ['bather', 'breath'])
# (2, ["bather's", "breath's"])
# (2, ['bathers', 'breaths'])
# (2, ['battle', 'tablet'])
# (2, ["battle's", "tablet's"])
# (2, ['battles', 'tablets'])
# (2, ['baud', 'daub'])
# (2, ["baud's", "daub's"])
# (2, ['bauds', 'daubs'])
# (2, ['bayed', 'beady'])
# (2, ['beadiest', 'diabetes'])
# (2, ["beard's", "bread's"])
# (2, ['bearded', 'breaded'])
# (2, ['bearding', 'breading'])
# (2, ["beat's", "beta's"])
# (2, ["beater's", "rebate's"])
# (2, ['beavered', 'bereaved'])
# (2, ['beavering', 'bereaving'])
# (2, ['bed', 'deb'])
# (2, ["bed's", "deb's"])
# (2, ['bedroom', 'boredom'])
# (2, ["bedroom's", "boredom's"])
# (2, ['beds', 'debs'])
# (2, ['bedsore', 'sobered'])
# (2, ['beeches', 'beseech'])
# (2, ['beefier', 'freebie'])
# (2, ['beets', 'beset'])
# (2, ['begrudge', 'debugger'])
# (2, ['begrudges', 'debuggers'])
# (2, ["being's", "binge's"])
# (2, ['belated', 'bleated'])
# (2, ['belied', 'edible'])
# (2, ['bellied', 'libeled'])
# (2, ['belts', 'blest'])
# (2, ['berating', 'rebating'])
# (2, ['berthing', 'brighten'])
# (2, ['besoms', 'emboss'])
# (2, ['best', 'bets'])
# (2, ['bestiary', 'sybarite'])
# (2, ["bestiary's", "sybarite's"])
# (2, ['bestir', 'tribes'])
# (2, ['betided', 'debited'])
# (2, ['betiding', 'debiting'])
# (2, ['bidder', 'birded'])
# (2, ['bidet', 'debit'])
# (2, ["bidet's", "debit's"])
# (2, ['bidets', 'debits'])
# (2, ['bin', 'nib'])
# (2, ["bin's", "nib's"])
# (2, ['binary', 'brainy'])
# (2, ['binders', 'rebinds'])
# (2, ['bins', 'nibs'])
# (2, ['bipedal', 'piebald'])
# (2, ['bipolar', 'parboil'])
# (2, ["biretta's", "terabit's"])
# (2, ['birettas', 'terabits'])
# (2, ['birther', 'rebirth'])
# (2, ["birther's", "rebirth's"])
# (2, ['birthers', 'rebirths'])
# (2, ['bistro', 'orbits'])
# (2, ['bizarre', 'brazier'])
# (2, ['blankest', 'blankets'])
# (2, ['blaster', 'stabler'])
# (2, ['blasting', 'stabling'])
# (2, ['blearily', 'reliably'])
# (2, ['bleat', 'table'])
# (2, ["bleat's", "table's"])
# (2, ['bleating', 'tangible'])
# (2, ['blessing', 'glibness'])
# (2, ["blessing's", "glibness's"])
# (2, ['blister', 'bristle'])
# (2, ["blister's", "bristle's"])
# (2, ['blisters', 'bristles'])
# (2, ['blobbed', 'bobbled'])
# (2, ['blobbing', 'bobbling'])
# (2, ['blog', 'glob'])
# (2, ["blog's", "glob's"])
# (2, ['blogged', 'boggled'])
# (2, ['blogging', 'boggling'])
# (2, ['blogs', 'globs'])
# (2, ['blot', 'bolt'])
# (2, ["blot's", "bolt's"])
# (2, ['blots', 'bolts'])
# (2, ['blotted', 'bottled'])
# (2, ['blotting', 'bottling'])
# (2, ['bloused', 'doubles'])
# (2, ['blow', 'bowl'])
# (2, ["blow's", "bowl's"])
# (2, ['blower', 'bowler'])
# (2, ["blower's", "bowler's"])
# (2, ['blowers', 'bowlers'])
# (2, ['blowing', 'bowling'])
# (2, ['blows', 'bowls'])
# (2, ['blue', 'lube'])
# (2, ["blue's", "lube's"])
# (2, ['blued', 'lubed'])
# (2, ['bluer', 'ruble'])
# (2, ['blues', 'lubes'])
# (2, ['bluing', 'lubing'])
# (2, ['blushes', 'bushels'])
# (2, ["bo's'ns", "bos'n's"])
# (2, ['board', 'broad'])
# (2, ["board's", "broad's"])
# (2, ['boarded', 'roadbed'])
# (2, ['boarder', 'broader'])
# (2, ['boards', 'broads'])
# (2, ['boast', 'boats'])
# (2, ['boaster', 'boaters'])
# (2, ['bog', 'gob'])
# (2, ["bog's", "gob's"])
# (2, ['bogeyman', 'moneybag'])
# (2, ["bogeyman's", "moneybag's"])
# (2, ['bogs', 'gobs'])
# (2, ['bole', 'lobe'])
# (2, ["bole's", "lobe's"])
# (2, ['boles', 'lobes'])
# (2, ['bolster', 'lobster'])
# (2, ["bolster's", "lobster's"])
# (2, ['bolsters', 'lobsters'])
# (2, ['bombed', 'mobbed'])
# (2, ['bombing', 'mobbing'])
# (2, ['boner', 'borne'])
# (2, ['boney', 'ebony'])
# (2, ['bonus', 'bosun'])
# (2, ['booms', 'bosom'])
# (2, ['boost', 'boots'])
# (2, ['bordello', 'doorbell'])
# (2, ["bordello's", "doorbell's"])
# (2, ['bordellos', 'doorbells'])
# (2, ['bore', 'robe'])
# (2, ["bore's", "robe's"])
# (2, ['bored', 'robed'])
# (2, ['boring', 'robing'])
# (2, ["bos'ns", "snob's"])
# (2, ['bosh', 'hobs'])
# (2, ['boss', 'sobs'])
# (2, ['bosses', 'obsess'])
# (2, ['bounder', 'rebound'])
# (2, ["bounder's", "rebound's"])
# (2, ["bowel's", "elbow's"])
# (2, ['bowels', 'elbows'])
# (2, ['bowers', 'browse'])
# (2, ['braid', 'rabid'])
# (2, ['braids', 'disbar'])
# (2, ['braille', 'liberal'])
# (2, ["braille's", "liberal's"])
# (2, ['braise', 'rabies'])
# (2, ['brawled', 'warbled'])
# (2, ['brawler', 'warbler'])
# (2, ["brawler's", "warbler's"])
# (2, ['brawlers', 'warblers'])
# (2, ['brawling', 'warbling'])
# (2, ['breasted', 'debaters'])
# (2, ['bribed', 'ribbed'])
# (2, ['bribing', 'ribbing'])
# (2, ['bridal', 'ribald'])
# (2, ['brides', 'debris'])
# (2, ['brief', 'fiber'])
# (2, ["brief's", "fiber's"])
# (2, ['briefed', 'debrief'])
# (2, ['briefs', 'fibers'])
# (2, ['briskest', 'briskets'])
# (2, ['bristled', 'driblets'])
# (2, ['broadcaster', 'rebroadcast'])
# (2, ["broadcaster's", "rebroadcast's"])
# (2, ['broadcasters', 'rebroadcasts'])
# (2, ['broadside', 'sideboard'])
# (2, ["broadside's", "sideboard's"])
# (2, ['broadsides', 'sideboards'])
# (2, ['broth', 'throb'])
# (2, ["broth's", "throb's"])
# (2, ['broths', 'throbs'])
# (2, ['brunt', 'burnt'])
# (2, ['brush', 'shrub'])
# (2, ["brush's", "shrub's"])
# (2, ["brute's", "tuber's"])
# (2, ['bud', 'dub'])
# (2, ["bud's", "dub's"])
# (2, ['budge', 'debug'])
# (2, ['budges', 'debugs'])
# (2, ['buds', 'dubs'])
# (2, ['buffer', 'rebuff'])
# (2, ["buffer's", "rebuff's"])
# (2, ['buffered', 'rebuffed'])
# (2, ['buffering', 'rebuffing'])
# (2, ['buffers', 'rebuffs'])
# (2, ['bugle', 'bulge'])
# (2, ["bugle's", "bulge's"])
# (2, ['bugled', 'bulged'])
# (2, ['bugler', 'burgle'])
# (2, ['buglers', 'burgles'])
# (2, ['bugles', 'bulges'])
# (2, ['bugling', 'bulging'])
# (2, ['builder', 'rebuild'])
# (2, ['builders', 'rebuilds'])
# (2, ['builtin', 'inbuilt'])
# (2, ['bun', 'nub'])
# (2, ["bun's", "nub's"])
# (2, ['bunked', 'debunk'])
# (2, ['bur', 'rub'])
# (2, ["bur's", "rub's"])
# (2, ['burbles', 'lubbers'])
# (2, ['burden', 'burned'])
# (2, ['burg', 'grub'])
# (2, ["burg's", "grub's"])
# (2, ['burgs', 'grubs'])
# (2, ['burs', 'rubs'])
# (2, ['bury', 'ruby'])
# (2, ['bus', 'sub'])
# (2, ["bus's", "sub's"])
# (2, ['bush', 'hubs'])
# (2, ['buss', 'subs'])
# (2, ["bust's", "stub's"])
# (2, ['busted', 'debuts'])
# (2, ["bustle's", "sublet's"])
# (2, ['bustles', 'sublets'])
# (2, ['busts', 'stubs'])
# (2, ['busy', 'buys'])
# (2, ['but', 'tub'])
# (2, ['buttered', 'rebutted'])
# (2, ['buttering', 'rebutting'])
# (2, ['cabs', 'scab'])
# (2, ['cachets', 'catches'])
# (2, ['cackled', 'clacked'])
# (2, ['cackling', 'clacking'])
# (2, ['cadge', 'caged'])
# (2, ['cadger', 'graced'])
# (2, ["cadre's", "cedar's"])
# (2, ['cads', 'scad'])
# (2, ['caduceus', 'caucused'])
# (2, ["caisson's", "cassino's"])
# (2, ['caissons', 'cassinos'])
# (2, ['califs', 'fiscal'])
# (2, ['caliper', 'replica'])
# (2, ["caliper's", "replica's"])
# (2, ['calipers', 'replicas'])
# (2, ['calk', 'lack'])
# (2, ["calk's", "lack's"])
# (2, ['calked', 'lacked'])
# (2, ['calking', 'lacking'])
# (2, ['calkings', 'slacking'])
# (2, ['calligraphy', 'graphically'])
# (2, ['calm', 'clam'])
# (2, ["calm's", "clam's"])
# (2, ['calms', 'clams'])
# (2, ['calumnies', 'masculine'])
# (2, ['calypso', 'cosplay'])
# (2, ['cambered', 'embraced'])
# (2, ['cambering', 'embracing'])
# (2, ['camels', 'mescal'])
# (2, ['camped', 'decamp'])
# (2, ['campers', 'scamper'])
# (2, ['campiest', 'campsite'])
# (2, ['camps', 'scamp'])
# (2, ['cams', 'scam'])
# (2, ['canaries', 'cesarian'])
# (2, ['candle', 'lanced'])
# (2, ['caned', 'dance'])
# (2, ['canister', 'scantier'])
# (2, ['cannot', 'canton'])
# (2, ['canoe', 'ocean'])
# (2, ["canoe's", "ocean's"])
# (2, ['canoed', 'deacon'])
# (2, ['canoeists', 'cessation'])
# (2, ['canoes', 'oceans'])
# (2, ['canopying', 'poignancy'])
# (2, ['cans', 'scan'])
# (2, ['canted', 'decant'])
# (2, ['cantering', 'recanting'])
# (2, ['cantor', 'carton'])
# (2, ["cantor's", "carton's"])
# (2, ['cantors', 'cartons'])
# (2, ['cants', 'scant'])
# (2, ['cape', 'pace'])
# (2, ["cape's", "pace's"])
# (2, ['caped', 'paced'])
# (2, ['capstan', 'catnaps'])
# (2, ['capsule', 'upscale'])
# (2, ['carbs', 'crabs'])
# (2, ['caress', 'scares'])
# (2, ['cargoes', 'corsage'])
# (2, ["caring's", "racing's"])
# (2, ['carol', 'coral'])
# (2, ["carol's", "coral's"])
# (2, ['carolled', 'collared'])
# (2, ['carolling', 'collaring'])
# (2, ['carols', 'corals'])
# (2, ['carom', 'macro'])
# (2, ["carom's", "macro's"])
# (2, ['caromed', 'comrade'])
# (2, ['caroms', 'macros'])
# (2, ['carp', 'crap'])
# (2, ["carp's", "crap's"])
# (2, ['carped', 'redcap'])
# (2, ['carpets', 'spectra'])
# (2, ['carries', 'scarier'])
# (2, ["cartel's", "claret's"])
# (2, ['carve', 'crave'])
# (2, ['carved', 'craved'])
# (2, ['carves', 'craves'])
# (2, ['carving', 'craving'])
# (2, ["carving's", "craving's"])
# (2, ['carvings', 'cravings'])
# (2, ['cashed', 'chased'])
# (2, ['cashes', 'chases'])
# (2, ['cashing', 'chasing'])
# (2, ['cask', 'sack'])
# (2, ["cask's", "sack's"])
# (2, ['casks', 'sacks'])
# (2, ['casserole', 'escaroles'])
# (2, ["cast's", "scat's"])
# (2, ["caster's", "recast's"])
# (2, ['castle', 'cleats'])
# (2, ["castor's", "costar's"])
# (2, ['castors', 'costars'])
# (2, ['casts', 'scats'])
# (2, ['casual', 'causal'])
# (2, ['casually', 'causally'])
# (2, ['catalogue', 'coagulate'])
# (2, ['catalogued', 'coagulated'])
# (2, ['catalogues', 'coagulates'])
# (2, ['cataloguing', 'coagulating'])
# (2, ['catechism', 'schematic'])
# (2, ["catechism's", "schematic's"])
# (2, ['catechisms', 'schematics'])
# (2, ["caterer's", "terrace's"])
# (2, ['caterings', 'recasting'])
# (2, ['cattily', 'tacitly'])
# (2, ["cattiness's", "tacitness's"])
# (2, ['cause', 'sauce'])
# (2, ["cause's", "sauce's"])
# (2, ['caused', 'sauced'])
# (2, ['causes', 'sauces'])
# (2, ['causing', 'saucing'])
# (2, ['cavaliers', 'cavalries'])
# (2, ['caveat', 'vacate'])
# (2, ['caveats', 'vacates'])
# (2, ['cavern', 'craven'])
# (2, ["cavern's", "craven's"])
# (2, ['caverns', 'cravens'])
# (2, ['censer', 'screen'])
# (2, ["censer's", "screen's"])
# (2, ['censers', 'screens'])
# (2, ['censor', 'crones'])
# (2, ['censored', 'encoders'])
# (2, ['center', 'recent'])
# (2, ['centigram', 'cremating'])
# (2, ['cents', 'scent'])
# (2, ['certifiable', 'rectifiable'])
# (2, ['certification', 'rectification'])
# (2, ["certification's", "rectification's"])
# (2, ['certifications', 'rectifications'])
# (2, ['certified', 'rectified'])
# (2, ['certifies', 'rectifies'])
# (2, ['certify', 'rectify'])
# (2, ['certifying', 'rectifying'])
# (2, ['certitude', 'rectitude'])
# (2, ["certitude's", "rectitude's"])
# (2, ['cervices', 'crevices'])
# (2, ['cesium', 'miscue'])
# (2, ["cesium's", "miscue's"])
# (2, ['chagrins', 'crashing'])
# (2, ['chain', 'china'])
# (2, ["chain's", "china's"])
# (2, ['chanters', 'stancher'])
# (2, ['chapt', 'patch'])
# (2, ['charm', 'march'])
# (2, ["charm's", "march's"])
# (2, ['charmed', 'marched'])
# (2, ['charmer', 'marcher'])
# (2, ["charmer's", "marcher's"])
# (2, ['charmers', 'marchers'])
# (2, ['charming', 'marching'])
# (2, ['chars', 'crash'])
# (2, ['charts', 'starch'])
# (2, ["chaser's", "search's"])
# (2, ['chasers', 'crashes'])
# (2, ['chatter', 'ratchet'])
# (2, ["chatter's", "ratchet's"])
# (2, ['chattered', 'ratcheted'])
# (2, ['chattering', 'ratcheting'])
# (2, ['chatters', 'ratchets'])
# (2, ['cheap', 'peach'])
# (2, ['cheat', 'teach'])
# (2, ['cheating', 'teaching'])
# (2, ['checker', 'recheck'])
# (2, ["checker's", "recheck's"])
# (2, ['checkered', 'rechecked'])
# (2, ['checkering', 'rechecking'])
# (2, ['checkers', 'rechecks'])
# (2, ['cheeps', 'speech'])
# (2, ['chest', 'techs'])
# (2, ['chief', 'fiche'])
# (2, ["chief's", "fiche's"])
# (2, ['chiefest', 'fetiches'])
# (2, ['chiefs', 'fiches'])
# (2, ['chiles', 'chisel'])
# (2, ['chin', 'inch'])
# (2, ["chin's", "inch's"])
# (2, ['chit', 'itch'])
# (2, ["chit's", "itch's"])
# (2, ['choked', 'hocked'])
# (2, ['chokers', 'shocker'])
# (2, ['choking', 'hocking'])
# (2, ['cholera', 'chorale'])
# (2, ["cholera's", "chorale's"])
# (2, ['chorals', 'scholar'])
# (2, ['chords', 'schrod'])
# (2, ['chose', 'echos'])
# (2, ['chum', 'much'])
# (2, ["chum's", "much's"])
# (2, ['churl', 'lurch'])
# (2, ["churl's", "lurch's"])
# (2, ['cilantro', 'contrail'])
# (2, ["cilantro's", "contrail's"])
# (2, ['ciphered', 'decipher'])
# (2, ['circle', 'cleric'])
# (2, ["circle's", "cleric's"])
# (2, ['circles', 'clerics'])
# (2, ['cistern', 'cretins'])
# (2, ['citadel', 'dialect'])
# (2, ["citadel's", "dialect's"])
# (2, ['citadels', 'dialects'])
# (2, ['cited', 'edict'])
# (2, ['cities', 'iciest'])
# (2, ['citric', 'critic'])
# (2, ['citrus', 'rustic'])
# (2, ["citrus's", "rustic's"])
# (2, ['citruses', 'curtsies'])
# (2, ['civet', 'evict'])
# (2, ['civets', 'evicts'])
# (2, ['clambers', 'scramble'])
# (2, ['clanged', 'glanced'])
# (2, ['clanging', 'glancing'])
# (2, ["clasp's", "scalp's"])
# (2, ['clasped', 'scalped'])
# (2, ['clasping', 'scalping'])
# (2, ['clasps', 'scalps'])
# (2, ['clay', 'lacy'])
# (2, ['clean', 'lance'])
# (2, ['cleaners', 'cleanser'])
# (2, ['cleanings', 'cleansing'])
# (2, ['cleans', 'lances'])
# (2, ['cleanse', 'scalene'])
# (2, ['cleansers', 'clearness'])
# (2, ['cleared', 'declare'])
# (2, ['clematis', 'climates'])
# (2, ['clematises', 'timescales'])
# (2, ['clients', 'stencil'])
# (2, ['climaxes', 'exclaims'])
# (2, ['clinker', 'crinkle'])
# (2, ["clinker's", "crinkle's"])
# (2, ['clinkers', 'crinkles'])
# (2, ['clipper', 'cripple'])
# (2, ["clipper's", "cripple's"])
# (2, ['clippers', 'cripples'])
# (2, ['clobber', 'cobbler'])
# (2, ["clobber's", "cobbler's"])
# (2, ['clobbers', 'cobblers'])
# (2, ['clod', 'cold'])
# (2, ["clod's", "cold's"])
# (2, ['cloister', 'costlier'])
# (2, ['closest', 'closets'])
# (2, ['clot', 'colt'])
# (2, ["clot's", "colt's"])
# (2, ['clots', 'colts'])
# (2, ['cloud', 'could'])
# (2, ['clouts', 'locust'])
# (2, ['coal', 'cola'])
# (2, ["coal's", "cola's"])
# (2, ['coals', 'colas'])
# (2, ['coarsen', 'corneas'])
# (2, ['coarsest', 'coasters'])
# (2, ['coastline', 'sectional'])
# (2, ["coastline's", "sectional's"])
# (2, ['coastlines', 'sectionals'])
# (2, ['coat', 'taco'])
# (2, ["coat's", "taco's"])
# (2, ['cocaine', 'oceanic'])
# (2, ["cocaine's", "oceanic's"])
# (2, ['cockily', 'colicky'])
# (2, ['cod', 'doc'])
# (2, ["cod's", "doc's"])
# (2, ['coddles', 'scolded'])
# (2, ['code', 'coed'])
# (2, ["code's", "coed's"])
# (2, ['codes', 'coeds'])
# (2, ['cods', 'docs'])
# (2, ['coexist', 'exotics'])
# (2, ['cognition', 'incognito'])
# (2, ["cognition's", "incognito's"])
# (2, ['coif', 'foci'])
# (2, ['coil', 'loci'])
# (2, ['coiled', 'docile'])
# (2, ['coin', 'icon'])
# (2, ["coin's", "icon's"])
# (2, ['colitis', 'solicit'])
# (2, ['collapsed', 'scalloped'])
# (2, ['collapsing', 'scalloping'])
# (2, ['colones', 'console'])
# (2, ['colonialist', 'oscillation'])
# (2, ["colonialist's", "oscillation's"])
# (2, ['colonialists', 'oscillations'])
# (2, ['comedian', 'demoniac'])
# (2, ['comics', 'cosmic'])
# (2, ['commissioned', 'decommission'])
# (2, ['compile', 'polemic'])
# (2, ['compiled', 'complied'])
# (2, ['complaint', 'compliant'])
# (2, ['compressed', 'decompress'])
# (2, ['concerted', 'concreted'])
# (2, ['concerting', 'concreting'])
# (2, ['conciser', 'cornices'])
# (2, ['conditioner', 'recondition'])
# (2, ['conditioners', 'reconditions'])
# (2, ['condoles', 'consoled'])
# (2, ['condor', 'cordon'])
# (2, ["condor's", "cordon's"])
# (2, ['condors', 'cordons'])
# (2, ['conduits', 'discount'])
# (2, ['cone', 'once'])
# (2, ["cone's", "once's"])
# (2, ['cones', 'scone'])
# (2, ['configures', 'refocusing'])
# (2, ['conical', 'laconic'])
# (2, ['conifers', 'forensic'])
# (2, ['connecter', 'reconnect'])
# (2, ['connecters', 'reconnects'])
# (2, ['conservation', 'conversation'])
# (2, ["conservation's", "conversation's"])
# (2, ['conserve', 'converse'])
# (2, ["conserve's", "converse's"])
# (2, ['conserved', 'conversed'])
# (2, ['conserves', 'converses'])
# (2, ['conserving', 'conversing'])
# (2, ['considerate', 'desecration'])
# (2, ['consigned', 'seconding'])
# (2, ['consist', 'tocsins'])
# (2, ['consoles', 'coolness'])
# (2, ['consolidates', 'disconsolate'])
# (2, ['contains', 'sanction'])
# (2, ['contenting', 'contingent'])
# (2, ['continued', 'unnoticed'])
# (2, ['contuses', 'countess'])
# (2, ['cool', 'loco'])
# (2, ['coolest', 'ocelots'])
# (2, ['coops', 'scoop'])
# (2, ['coordinate', 'decoration'])
# (2, ["coordinate's", "decoration's"])
# (2, ['coordinates', 'decorations'])
# (2, ['coots', 'scoot'])
# (2, ['copings', 'scoping'])
# (2, ["copse's", "scope's"])
# (2, ['copses', 'scopes'])
# (2, ['copula', 'cupola'])
# (2, ["copula's", "cupola's"])
# (2, ['copulas', 'cupolas'])
# (2, ['cords', 'scrod'])
# (2, ['cores', 'score'])
# (2, ['cork', 'rock'])
# (2, ["cork's", "rock's"])
# (2, ['corked', 'rocked'])
# (2, ['corking', 'rocking'])
# (2, ['corks', 'rocks'])
# (2, ['corns', 'scorn'])
# (2, ['corny', 'crony'])
# (2, ['corona', 'racoon'])
# (2, ["corona's", "racoon's"])
# (2, ['coronas', 'racoons'])
# (2, ['coroner', 'crooner'])
# (2, ["coroner's", "crooner's"])
# (2, ['coroners', 'crooners'])
# (2, ['corps', 'crops'])
# (2, ['corpses', 'process'])
# (2, ['corseted', 'escorted'])
# (2, ['corseting', 'escorting'])
# (2, ['cost', 'cots'])
# (2, ['coteries', 'esoteric'])
# (2, ["counter's", "recount's"])
# (2, ['countered', 'recounted'])
# (2, ['countering', 'recounting'])
# (2, ['course', 'source'])
# (2, ["course's", "source's"])
# (2, ['courteous', 'outsource'])
# (2, ['covert', 'vector'])
# (2, ["covert's", "vector's"])
# (2, ['coverts', 'vectors'])
# (2, ['cowers', 'escrow'])
# (2, ['cowlings', 'scowling'])
# (2, ['cowls', 'scowl'])
# (2, ['cows', 'scow'])
# (2, ['craftiest', 'trifectas'])
# (2, ['crams', 'scram'])
# (2, ['crane', 'nacre'])
# (2, ["crane's", "nacre's"])
# (2, ['craned', 'dancer'])
# (2, ["craps's", "scrap's"])
# (2, ['crass', 'scars'])
# (2, ['crater', 'tracer'])
# (2, ["crater's", "tracer's"])
# (2, ['craters', 'tracers'])
# (2, ['crawls', 'scrawl'])
# (2, ['creams', 'scream'])
# (2, ['creation', 'reaction'])
# (2, ["creation's", "reaction's"])
# (2, ['creations', 'reactions'])
# (2, ['creative', 'reactive'])
# (2, ['creator', 'reactor'])
# (2, ["creator's", "reactor's"])
# (2, ['creators', 'reactors'])
# (2, ['credential', 'interlaced'])
# (2, ['credit', 'direct'])
# (2, ['credited', 'directed'])
# (2, ['crediting', 'directing'])
# (2, ['creditor', 'director'])
# (2, ["creditor's", "director's"])
# (2, ['creditors', 'directors'])
# (2, ['credits', 'directs'])
# (2, ["credo's", "decor's"])
# (2, ['creep', 'crepe'])
# (2, ["creep's", "crepe's"])
# (2, ['creeps', 'crepes'])
# (2, ['crews', 'screw'])
# (2, ['cries', 'rices'])
# (2, ['crimps', 'scrimp'])
# (2, ['crimson', 'microns'])
# (2, ['crisp', 'scrip'])
# (2, ["crisp's", "scrip's"])
# (2, ['crisps', 'scrips'])
# (2, ['crochets', 'crotches'])
# (2, ["crocus's", "succor's"])
# (2, ['crosser', 'scorers'])
# (2, ['crud', 'curd'])
# (2, ["crud's", "curd's"])
# (2, ['crude', 'cured'])
# (2, ['crudest', 'crusted'])
# (2, ['crudities', 'diuretics'])
# (2, ['cruelest', 'lectures'])
# (2, ['cruelty', 'cutlery'])
# (2, ["cruelty's", "cutlery's"])
# (2, ["cruet's", "truce's"])
# (2, ['cruets', 'truces'])
# (2, ['cruise', 'curies'])
# (2, ['cruiser', 'curries'])
# (2, ['cruisers', 'scurries'])
# (2, ['crumpets', 'spectrum'])
# (2, ['crust', 'curst'])
# (2, ['crustier', 'recruits'])
# (2, ['crusty', 'curtsy'])
# (2, ['cubist', 'cubits'])
# (2, ['cuds', 'scud'])
# (2, ['cuffs', 'scuff'])
# (2, ['culls', 'scull'])
# (2, ['cums', 'scum'])
# (2, ['cupfuls', 'cupsful'])
# (2, ['cupids', 'cuspid'])
# (2, ['cups', 'cusp'])
# (2, ['curbs', 'scrub'])
# (2, ['curdle', 'curled'])
# (2, ['cure', 'ecru'])
# (2, ["cure's", "ecru's"])
# (2, ['curer', 'recur'])
# (2, ['cures', 'curse'])
# (2, ['curtest', 'cutters'])
# (2, ['curtness', 'encrusts'])
# (2, ['cutlets', 'scuttle'])
# (2, ['dabbles', 'slabbed'])
# (2, ['daemon', 'moaned'])
# (2, ['dagger', 'ragged'])
# (2, ['dailies', 'liaised'])
# (2, ['dairies', 'diaries'])
# (2, ['dairy', 'diary'])
# (2, ["dairy's", "diary's"])
# (2, ['dallies', 'sallied'])
# (2, ['dam', 'mad'])
# (2, ["dam's", "mad's"])
# (2, ["dame's", "mead's"])
# (2, ['dampest', 'stamped'])
# (2, ['dams', 'mads'])
# (2, ['damsel', 'medals'])
# (2, ['damson', 'nomads'])
# (2, ['dander', 'darned'])
# (2, ['dandier', 'drained'])
# (2, ['dandle', 'landed'])
# (2, ['dangled', 'gladden'])
# (2, ['dapper', 'rapped'])
# (2, ['dapperer', 'prepared'])
# (2, ['dapple', 'lapped'])
# (2, ['dapples', 'slapped'])
# (2, ['darling', 'larding'])
# (2, ['darted', 'traded'])
# (2, ['darting', 'trading'])
# (2, ['dash', 'shad'])
# (2, ["dash's", "shad's"])
# (2, ['dashed', 'shaded'])
# (2, ['dashes', 'shades'])
# (2, ['dashing', 'shading'])
# (2, ['dateline', 'entailed'])
# (2, ['dauber', 'earbud'])
# (2, ["dauber's", "earbud's"])
# (2, ['daubers', 'earbuds'])
# (2, ['daunted', 'undated'])
# (2, ['dawdle', 'waddle'])
# (2, ['dawdled', 'waddled'])
# (2, ['dawdler', 'drawled'])
# (2, ['dawdling', 'waddling'])
# (2, ['dawn', 'wand'])
# (2, ["dawn's", "wand's"])
# (2, ['dawns', 'wands'])
# (2, ['deadest', 'sedated'])
# (2, ['deadlier', 'derailed'])
# (2, ['deaf', 'fade'])
# (2, ['deafer', 'feared'])
# (2, ['dealer', 'leader'])
# (2, ["dealer's", "leader's"])
# (2, ['dealers', 'leaders'])
# (2, ['dealership', 'leadership'])
# (2, ["dealership's", "leadership's"])
# (2, ["dealing's", "leading's"])
# (2, ['dealings', 'signaled'])
# (2, ['dealt', 'delta'])
# (2, ['deans', 'sedan'])
# (2, ['death', 'hated'])
# (2, ['deaths', 'hasted'])
# (2, ['deaves', 'evades'])
# (2, ['debase', 'seabed'])
# (2, ['debases', 'seabeds'])
# (2, ['debut', 'tubed'])
# (2, ['decadent', 'decanted'])
# (2, ['decadents', 'descanted'])
# (2, ['decaf', 'faced'])
# (2, ['decal', 'laced'])
# (2, ['decals', 'scaled'])
# (2, ['deceiver', 'received'])
# (2, ['decide', 'deiced'])
# (2, ["decimal's", "medical's"])
# (2, ['decimate', 'medicate'])
# (2, ['decimated', 'medicated'])
# (2, ['decimates', 'medicates'])
# (2, ['decimating', 'medicating'])
# (2, ['decimation', 'medication'])
# (2, ["decimation's", "medication's"])
# (2, ['decree', 'recede'])
# (2, ['decreed', 'receded'])
# (2, ['decrees', 'recedes'])
# (2, ['decries', 'deicers'])
# (2, ['deduces', 'seduced'])
# (2, ['deductions', 'discounted'])
# (2, ['deeding', 'deigned'])
# (2, ['deep', 'peed'])
# (2, ['deeper', 'peered'])
# (2, ['deepest', 'steeped'])
# (2, ['deeply', 'yelped'])
# (2, ['deeps', 'speed'])
# (2, ['deer', 'reed'])
# (2, ["deer's", "reed's"])
# (2, ['deers', 'reeds'])
# (2, ['default', 'faulted'])
# (2, ['defend', 'fended'])
# (2, ['defer', 'freed'])
# (2, ['deferment', 'fermented'])
# (2, ['defiant', 'fainted'])
# (2, ['defiled', 'fielded'])
# (2, ['defiling', 'fielding'])
# (2, ['definer', 'refined'])
# (2, ['deflation', 'defoliant'])
# (2, ["deflation's", "defoliant's"])
# (2, ['deform', 'formed'])
# (2, ['deforms', 'serfdom'])
# (2, ['defray', 'frayed'])
# (2, ['defrost', 'frosted'])
# (2, ['deification', 'edification'])
# (2, ["deification's", "edification's"])
# (2, ['deified', 'edified'])
# (2, ['deifies', 'edifies'])
# (2, ['deify', 'edify'])
# (2, ['deifying', 'edifying'])
# (2, ['deism', 'dimes'])
# (2, ["deli's", "idle's"])
# (2, ['delight', 'lighted'])
# (2, ['delights', 'slighted'])
# (2, ['delimit', 'limited'])
# (2, ['deluding', 'indulged'])
# (2, ['demanded', 'maddened'])
# (2, ['demanding', 'maddening'])
# (2, ['demands', 'maddens'])
# (2, ['demarcate', 'macerated'])
# (2, ['demeanor', 'enamored'])
# (2, ['demised', 'misdeed'])
# (2, ['demote', 'emoted'])
# (2, ['demotion', 'motioned'])
# (2, ['demount', 'mounted'])
# (2, ['demurest', 'mustered'])
# (2, ['demurred', 'murdered'])
# (2, ['demurring', 'murdering'])
# (2, ['den', 'end'])
# (2, ["den's", "end's"])
# (2, ['denatures', 'sauntered'])
# (2, ['denials', 'snailed'])
# (2, ['denied', 'indeed'])
# (2, ['denier', 'reined'])
# (2, ['denim', 'mined'])
# (2, ['denominate', 'emendation'])
# (2, ['denominates', 'emendations'])
# (2, ['denotation', 'detonation'])
# (2, ["denotation's", "detonation's"])
# (2, ['denotations', 'detonations'])
# (2, ['dense', 'needs'])
# (2, ['densities', 'destinies'])
# (2, ['density', 'destiny'])
# (2, ["density's", "destiny's"])
# (2, ['dent', 'tend'])
# (2, ['dented', 'tended'])
# (2, ["dentin's", "indent's"])
# (2, ['denting', 'tending'])
# (2, ['dentist', 'stinted'])
# (2, ['dents', 'tends'])
# (2, ['denture', 'tenured'])
# (2, ['denude', 'endued'])
# (2, ['departed', 'predated'])
# (2, ['departing', 'predating'])
# (2, ['departs', 'petards'])
# (2, ['depend', 'pended'])
# (2, ['deplane', 'paneled'])
# (2, ['deport', 'ported'])
# (2, ['deports', 'sported'])
# (2, ["deposit's", "topside's"])
# (2, ['deposition', 'positioned'])
# (2, ['depositor', 'droopiest'])
# (2, ['deposits', 'topsides'])
# (2, ['depot', 'opted'])
# (2, ['deprave', 'pervade'])
# (2, ['depraved', 'pervaded'])
# (2, ['depraves', 'pervades'])
# (2, ['depraving', 'pervading'])
# (2, ['depress', 'pressed'])
# (2, ['deprogram', 'programed'])
# (2, ['derailments', 'streamlined'])
# (2, ['deranged', 'gardened'])
# (2, ['deranging', 'gardening'])
# (2, ['dervish', 'shrived'])
# (2, ['descent', 'scented'])
# (2, ['description', 'predictions'])
# (2, ['deserts', 'dessert'])
# (2, ['deserve', 'severed'])
# (2, ['designers', 'redesigns'])
# (2, ['desires', 'resides'])
# (2, ['despoil', 'spoiled'])
# (2, ['desserts', 'stressed'])
# (2, ['destining', 'indigents'])
# (2, ['details', 'dilates'])
# (2, ['deter', 'treed'])
# (2, ['detest', 'tested'])
# (2, ['dethrones', 'shortened'])
# (2, ['detours', 'dourest'])
# (2, ['deuces', 'seduce'])
# (2, ['developer', 'redevelop'])
# (2, ['developers', 'redevelops'])
# (2, ['deviates', 'sedative'])
# (2, ['devil', 'lived'])
# (2, ['devise', 'sieved'])
# (2, ['devoid', 'voided'])
# (2, ['devolve', 'evolved'])
# (2, ['devote', 'vetoed'])
# (2, ['dew', 'wed'])
# (2, ['dial', 'laid'])
# (2, ['dialed', 'laddie'])
# (2, ['diameters', 'dreamiest'])
# (2, ['diatoms', 'mastoid'])
# (2, ['dice', 'iced'])
# (2, ['dicker', 'ricked'])
# (2, ['diddle', 'lidded'])
# (2, ['diesel', 'elides'])
# (2, ['dieted', 'edited'])
# (2, ['dietitian', 'initiated'])
# (2, ['differ', 'riffed'])
# (2, ['digger', 'rigged'])
# (2, ['dignifies', 'signified'])
# (2, ['dignity', 'tidying'])
# (2, ['dikes', 'skied'])
# (2, ['dilly', 'idyll'])
# (2, ["dilly's", "idyll's"])
# (2, ['dilutes', 'duelist'])
# (2, ['dim', 'mid'])
# (2, ['dimmer', 'rimmed'])
# (2, ['dimple', 'limped'])
# (2, ['dines', 'snide'])
# (2, ['dinettes', 'insetted'])
# (2, ['dingo', 'doing'])
# (2, ["dingo's", "doing's"])
# (2, ['dingy', 'dying'])
# (2, ['dipper', 'ripped'])
# (2, ['dire', 'ride'])
# (2, ['directer', 'redirect'])
# (2, ['directest', 'trisected'])
# (2, ['directions', 'discretion'])
# (2, ['dirge', 'ridge'])
# (2, ["dirge's", "ridge's"])
# (2, ['dirges', 'ridges'])
# (2, ['dirtiness', 'disinters'])
# (2, ['dis', 'ids'])
# (2, ['discerned', 'rescinded'])
# (2, ['discerning', 'rescinding'])
# (2, ['discerns', 'rescinds'])
# (2, ['discover', 'divorces'])
# (2, ['discoverer', 'rediscover'])
# (2, ['discoverers', 'rediscovers'])
# (2, ['discreet', 'discrete'])
# (2, ['disease', 'seaside'])
# (2, ["disease's", "seaside's"])
# (2, ['diseases', 'seasides'])
# (2, ['dishes', 'hissed'])
# (2, ['dishing', 'shindig'])
# (2, ['dishonest', 'hedonists'])
# (2, ["disk's", "skid's"])
# (2, ['disks', 'skids'])
# (2, ['dispel', 'lisped'])
# (2, ['disperse', 'presides'])
# (2, ['disport', 'tripods'])
# (2, ['disprove', 'provides'])
# (2, ['dissent', 'snidest'])
# (2, ["dissenter's", "tiredness's"])
# (2, ['dissing', 'sidings'])
# (2, ['distaste', 'staidest'])
# (2, ['distention', 'tendonitis'])
# (2, ["distention's", "tendonitis's"])
# (2, ['distincter', 'interdicts'])
# (2, ['disuse', 'issued'])
# (2, ['dithers', 'shirted'])
# (2, ['ditties', 'tidiest'])
# (2, ['divan', 'viand'])
# (2, ["divan's", "viand's"])
# (2, ['divans', 'viands'])
# (2, ['dive', 'vied'])
# (2, ['diver', 'drive'])
# (2, ["diver's", "drive's"])
# (2, ['diverge', 'grieved'])
# (2, ['divers', 'drives'])
# (2, ['diverts', 'strived'])
# (2, ['dives', 'vised'])
# (2, ['dockets', 'stocked'])
# (2, ['doe', 'ode'])
# (2, ["doe's", "ode's"])
# (2, ['dog', 'god'])
# (2, ["dog's", "god's"])
# (2, ['dogs', 'gods'])
# (2, ['doings', 'dosing'])
# (2, ['dole', 'lode'])
# (2, ["dole's", "lode's"])
# (2, ['dolt', 'told'])
# (2, ['don', 'nod'])
# (2, ["don's", "nod's"])
# (2, ['done', 'node'])
# (2, ['dons', 'nods'])
# (2, ['doodler', 'drooled'])
# (2, ['doom', 'mood'])
# (2, ["doom's", "mood's"])
# (2, ['dooms', 'moods'])
# (2, ['doorstep', 'torpedos'])
# (2, ['dopes', 'posed'])
# (2, ['dopier', 'period'])
# (2, ['dormant', 'mordant'])
# (2, ['dos', 'sod'])
# (2, ['dote', 'toed'])
# (2, ["doubter's", "redoubt's"])
# (2, ['dourer', 'ordure'])
# (2, ['douses', 'soused'])
# (2, ['dovetail', 'violated'])
# (2, ['dowel', 'lowed'])
# (2, ['dowels', 'slowed'])
# (2, ['downer', 'wonder'])
# (2, ["downer's", "wonder's"])
# (2, ['downers', 'wonders'])
# (2, ['download', 'woodland'])
# (2, ["download's", "woodland's"])
# (2, ['downloads', 'woodlands'])
# (2, ["dowry's", "rowdy's"])
# (2, ['dowse', 'sowed'])
# (2, ['dozen', 'zoned'])
# (2, ['drag', 'grad'])
# (2, ["drag's", "grad's"])
# (2, ['dragnet', 'granted'])
# (2, ['dragnets', 'grandest'])
# (2, ['drags', 'grads'])
# (2, ['drain', 'nadir'])
# (2, ["drain's", "nadir's"])
# (2, ['drainage', 'gardenia'])
# (2, ["drainage's", "gardenia's"])
# (2, ['drainer', 'randier'])
# (2, ['drains', 'nadirs'])
# (2, ['drake', 'raked'])
# (2, ['dramas', 'madras'])
# (2, ["drape's", "padre's"])
# (2, ['draw', 'ward'])
# (2, ["draw's", "ward's"])
# (2, ['drawing', 'warding'])
# (2, ['dray', 'yard'])
# (2, ["dray's", "yard's"])
# (2, ['drays', 'yards'])
# (2, ['dreamer', 'rearmed'])
# (2, ['dresser', 'redress'])
# (2, ["dresser's", "redress's"])
# (2, ['dried', 'redid'])
# (2, ["drier's", "rider's"])
# (2, ['driers', 'riders'])
# (2, ['drollest', 'strolled'])
# (2, ['drolly', 'lordly'])
# (2, ['drones', 'snored'])
# (2, ['drop', 'prod'])
# (2, ["drop's", "prod's"])
# (2, ['drops', 'prods'])
# (2, ['drove', 'roved'])
# (2, ['drowsing', 'wordings'])
# (2, ['drugged', 'grudged'])
# (2, ['drugging', 'grudging'])
# (2, ['dual', 'laud'])
# (2, ['duels', 'slued'])
# (2, ['duffer', 'ruffed'])
# (2, ['dummies', 'mediums'])
# (2, ['dumpier', 'umpired'])
# (2, ['dune', 'nude'])
# (2, ["dune's", "nude's"])
# (2, ['dunes', 'nudes'])
# (2, ['dungaree', 'underage'])
# (2, ['dunged', 'nudged'])
# (2, ['dunging', 'nudging'])
# (2, ['dunnest', 'stunned'])
# (2, ['duodenal', 'unloaded'])
# (2, ['dust', 'stud'])
# (2, ["dust's", "stud's"])
# (2, ['dusters', 'trussed'])
# (2, ['dusts', 'studs'])
# (2, ['dusty', 'study'])
# (2, ['duties', 'suited'])
# (2, ['dwindles', 'swindled'])
# (2, ['dyed', 'eddy'])
# (2, ['dykes', 'skyed'])
# (2, ['eagerest', 'steerage'])
# (2, ['eaglet', 'legate'])
# (2, ["eaglet's", "legate's"])
# (2, ['eaglets', 'legates'])
# (2, ['earfuls', 'refusal'])
# (2, ['earl', 'real'])
# (2, ["earl's", "real's"])
# (2, ['earn', 'near'])
# (2, ['earner', 'nearer'])
# (2, ['earnings', 'grannies'])
# (2, ['earthen', 'hearten'])
# (2, ['earthier', 'heartier'])
# (2, ['earthiest', 'heartiest'])
# (2, ['earthiness', 'heartiness'])
# (2, ["earthiness's", "heartiness's"])
# (2, ['earthliest', 'stealthier'])
# (2, ['earthlings', 'slathering'])
# (2, ['earthy', 'hearty'])
# (2, ['easel', 'lease'])
# (2, ["easel's", "lease's"])
# (2, ['easels', 'leases'])
# (2, ["east's", "seat's"])
# (2, ['eaters', 'teaser'])
# (2, ['edge', 'geed'])
# (2, ['edger', 'greed'])
# (2, ['edges', 'sedge'])
# (2, ['editions', 'sedition'])
# (2, ['editor', 'rioted'])
# (2, ['eel', 'lee'])
# (2, ["eel's", "lee's"])
# (2, ['eglantine', 'inelegant'])
# (2, ['egocentric', 'geocentric'])
# (2, ['egos', 'goes'])
# (2, ['egret', 'greet'])
# (2, ['egrets', 'greets'])
# (2, ['eh', 'he'])
# (2, ['eighth', 'height'])
# (2, ["eighth's", "height's"])
# (2, ['ekes', 'seek'])
# (2, ['elapsed', 'pleased'])
# (2, ['elapses', 'pleases'])
# (2, ['elapsing', 'pleasing'])
# (2, ['elastic', 'laciest'])
# (2, ['elastics', 'scaliest'])
# (2, ['elates', 'teasel'])
# (2, ['elation', 'toenail'])
# (2, ["elation's", "toenail's"])
# (2, ['elections', 'selection'])
# (2, ['electives', 'selective'])
# (2, ['electors', 'selector'])
# (2, ['elects', 'select'])
# (2, ['elegiacs', 'legacies'])
# (2, ['elisions', 'oiliness'])
# (2, ['elitism', 'limiest'])
# (2, ['ells', 'sell'])
# (2, ['em', 'me'])
# (2, ['emailed', 'limeade'])
# (2, ['emanates', 'manatees'])
# (2, ['emirate', 'meatier'])
# (2, ['emirates', 'steamier'])
# (2, ['emos', 'some'])
# (2, ['empires', 'premise'])
# (2, ['ems', 'mes'])
# (2, ['emus', 'muse'])
# (2, ['enamors', 'oarsmen'])
# (2, ['enclave', 'valence'])
# (2, ["enclave's", "valence's"])
# (2, ['enclaves', 'valences'])
# (2, ['encoder', 'encored'])
# (2, ['ending', 'ginned'])
# (2, ['endings', 'sending'])
# (2, ['endow', 'owned'])
# (2, ['endows', 'snowed'])
# (2, ['endues', 'ensued'])
# (2, ['endure', 'enured'])
# (2, ['endures', 'ensured'])
# (2, ['enemas', 'seamen'])
# (2, ['enervate', 'venerate'])
# (2, ['enervated', 'venerated'])
# (2, ['enervates', 'venerates'])
# (2, ['enervating', 'venerating'])
# (2, ['enervation', 'veneration'])
# (2, ["enervation's", "veneration's"])
# (2, ['enfold', 'fondle'])
# (2, ['enfolds', 'fondles'])
# (2, ['enigma', 'gamine'])
# (2, ["enigma's", "gamine's"])
# (2, ['enlarge', 'general'])
# (2, ['enlarges', 'generals'])
# (2, ['enrage', 'genera'])
# (2, ['enrol', 'loner'])
# ...
# (3, ['hams', 'mash', 'sham'])
# (3, ['hare', 'hear', 'rhea'])
# (3, ['haste', 'hates', 'heats'])
# (3, ['hatters', 'shatter', 'threats'])
# (3, ['heaps', 'phase', 'shape'])
# (3, ['heirs', 'hires', 'shire'])
# (3, ['helots', 'hostel', 'hotels'])
# (3, ['herds', 'sherd', 'shred'])
# (3, ['heros', 'horse', 'shore'])
# (3, ['hikers', 'shriek', 'shrike'])
# (3, ['hits', 'shit', 'this'])
# (3, ['hoes', 'hose', 'shoe'])
# (3, ['hoots', 'shoot', 'sooth'])
# (3, ['hops', 'posh', 'shop'])
# (3, ['hordes', 'horsed', 'shored'])
# (3, ['hornets', 'shorten', 'thrones'])
# (3, ['hustles', 'lushest', 'sleuths'])
# (3, ['ideals', 'ladies', 'sailed'])
# (3, ['impress', 'premiss', 'simpers'])
# (3, ['incest', 'insect', 'nicest'])
# (3, ['inert', 'inter', 'niter'])
# (3, ['ingest', 'signet', 'tinges'])
# (3, ['inkling', 'kilning', 'linking'])
# (3, ['inks', 'sink', 'skin'])
# (3, ['insoles', 'lesions', 'lioness'])
# (3, ['interim', 'mintier', 'termini'])
# (3, ['isle', 'leis', 'lies'])
# (3, ['islet', 'stile', 'tiles'])
# (3, ['islets', 'sliest', 'stiles'])
# (3, ['isms', 'miss', 'sims'])
# (3, ["isn't", "nit's", "tin's"])
# (3, ["item's", "mite's", "time's"])
# (3, ['kale', 'lake', 'leak'])
# (3, ["kale's", "lake's", "leak's"])
# (3, ['keels', 'leeks', 'sleek'])
# (3, ['kilned', 'kindle', 'linked'])
# (3, ['kilns', 'links', 'slink'])
# (3, ['lakes', 'leaks', 'slake'])
# (3, ['lame', 'male', 'meal'])
# (3, ["lame's", "male's", "meal's"])
# (3, ["lament's", "mantel's", "mantle's"])
# (3, ['laments', 'mantels', 'mantles'])
# (3, ['lames', 'males', 'meals'])
# (3, ['lamps', 'palms', 'psalm'])
# (3, ['laps', 'pals', 'slap'])
# (3, ['lapsed', 'pedals', 'pleads'])
# (3, ['lapses', 'passel', 'sepals'])
# (3, ['lapsing', 'palings', 'sapling'])
# (3, ["last's", "salt's", "slat's"])
# (3, ['lasts', 'salts', 'slats'])
# (3, ['late', 'tale', 'teal'])
# (3, ['latrine', 'reliant', 'retinal'])
# (3, ['layering', 'relaying', 'yearling'])
# (3, ['layers', 'relays', 'slayer'])
# (3, ['laymen', 'meanly', 'namely'])
# (3, ["least's", "slate's", "steal's"])
# (3, ['leggin', 'neglig', 'niggle'])
# (3, ["leggin's", "neglig's", "niggle's"])
# (3, ['leggins', 'negligs', 'niggles'])
# (3, ['lemons', 'melons', 'solemn'])
# (3, ['letters', 'settler', 'trestle'])
# (3, ['liefer', 'refile', 'relief'])
# (3, ['lilts', 'still', 'tills'])
# (3, ['lips', 'lisp', 'slip'])
# (3, ['list', 'silt', 'slit'])
# (3, ["list's", "silt's", "slit's"])
# (3, ["listen's", "silent's", "tinsel's"])
# (3, ['listener', 'reenlist', 'silenter'])
# (3, ['lists', 'silts', 'slits'])
# (3, ['livers', 'silver', 'sliver'])
# (3, ['loader', 'ordeal', 'reload'])
# (3, ['loaders', 'ordeals', 'reloads'])
# (3, ['loop', 'polo', 'pool'])
# (3, ["loop's", "polo's", "pool's"])
# (3, ['looped', 'poodle', 'pooled'])
# (3, ['loosed', 'oodles', 'soloed'])
# (3, ['loots', 'stool', 'tools'])
# (3, ['lopes', 'poles', 'slope'])
# (3, ['lops', 'pols', 'slop'])
# (3, ['lose', 'sloe', 'sole'])
# (3, ['loses', 'sloes', 'soles'])
# (3, ['lost', 'lots', 'slot'])
# (3, ['loves', 'solve', 'voles'])
# (3, ['lowers', 'rowels', 'slower'])
# (3, ['lowest', 'owlets', 'towels'])
# (3, ['lows', 'owls', 'slow'])
# (3, ['lumbers', 'rumbles', 'slumber'])
# (3, ['lumps', 'plums', 'slump'])
# (3, ['magneto', 'megaton', 'montage'])
# (3, ["magneto's", "megaton's", "montage's"])
# (3, ['magnetos', 'megatons', 'montages'])
# (3, ["mane's", "mean's", "name's"])
# (3, ['manured', 'maunder', 'unarmed'])
# (3, ['mares', 'reams', 'smear'])
# (3, ['marines', 'remains', 'seminar'])
# (3, ['marts', 'smart', 'trams'])
# (3, ['mast', 'mats', 'tams'])
# (3, ['master', 'stream', 'tamers'])
# (3, ["mate's", "meat's", "team's"])
# (3, ['meet', 'mete', 'teem'])
# (3, ['meets', 'metes', 'teems'])
# (3, ["merit's", "miter's", "timer's"])
# (3, ['mesa', 'same', 'seam'])
# (3, ['mesas', 'sames', 'seams'])
# (3, ['misting', 'smiting', 'timings'])
# (3, ['motes', 'smote', 'tomes'])
# (3, ['mothers', 'smother', 'thermos'])
# (3, ['nags', 'sang', 'snag'])
# (3, ['nails', 'slain', 'snail'])
# (3, ['naiver', 'ravine', 'vainer'])
# (3, ['naivest', 'natives', 'vainest'])
# (3, ['nastier', 'retains', 'retinas'])
# (3, ['neuter', 'tenure', 'tureen'])
# (3, ["neuter's", "tenure's", "tureen's"])
# (3, ['neuters', 'tenures', 'tureens'])
# (3, ['news', 'sewn', 'wens'])
# (3, ['nits', 'snit', 'tins'])
# (3, ['now', 'own', 'won'])
# (3, ['nuts', 'stun', 'tuns'])
# (3, ['observe', 'obverse', 'verbose'])
# (3, ["open's", "peon's", "pone's"])
# (3, ['opens', 'peons', 'pones'])
# (3, ['opt', 'pot', 'top'])
# (3, ['outtakes', 'stakeout', 'takeouts'])
# (3, ['overs', 'roves', 'servo'])
# (3, ['owns', 'snow', 'sown'])
# (3, ['oyster', 'storey', 'tyroes'])
# (3, ['painter', 'pertain', 'repaint'])
# (3, ['paled', 'pedal', 'plead'])
# (3, ['palsy', 'plays', 'splay'])
# (3, ['panel', 'penal', 'plane'])
# (3, ['parental', 'paternal', 'prenatal'])
# (3, ["parley's", "player's", "replay's"])
# (3, ["part's", "tarp's", "trap's"])
# (3, ['pastries', 'raspiest', 'traipses'])
# (3, ['pate', 'peat', 'tape'])
# (3, ["pate's", "peat's", "tape's"])
# (3, ['paws', 'swap', 'wasp'])
# (3, ['pays', 'spay', 'yaps'])
# (3, ['peaks', 'spake', 'speak'])
# (3, ['pelts', 'slept', 'spelt'])
# (3, ["penis's", "snipe's", "spine's"])
# (3, ['pertness', 'presents', 'serpents'])
# (3, ['peruse', 'purees', 'rupees'])
# (3, ['pesos', 'poses', 'posse'])
# (3, ['pest', 'pets', 'step'])
# (3, ['pester', 'peters', 'preset'])
# (3, ["petal's", "plate's", "pleat's"])
# (3, ['pierces', 'precise', 'recipes'])
# (3, ['piers', 'pries', 'spire'])
# (3, ['piles', 'plies', 'spiel'])
# (3, ['pilots', 'pistol', 'spoilt'])
# (3, ['pinto', 'piton', 'point'])
# (3, ["pinto's", "piton's", "point's"])
# (3, ['pits', 'spit', 'tips'])
# (3, ['platters', 'prattles', 'splatter'])
# (3, ['ports', 'sport', 'strop'])
# (3, ["poser's", "prose's", "spore's"])
# (3, ["post's", "spot's", "stop's"])
# (3, ['poster', 'presto', 'tropes'])
# (3, ['posts', 'spots', 'stops'])
# (3, ['postured', 'proudest', 'sprouted'])
# (3, ['potters', 'protest', 'spotter'])
# (3, ['prates', 'repast', 'tapers'])
# (3, ['prays', 'raspy', 'spray'])
# (3, ['present', 'repents', 'serpent'])
# (3, ["priest's", "sprite's", "stripe's"])
# (3, ['printers', 'reprints', 'sprinter'])
# (3, ['pus', 'sup', 'ups'])
# (3, ['rashes', 'shares', 'shears'])
# (3, ['rate', 'tare', 'tear'])
# (3, ["rate's", "tare's", "tear's"])
# (3, ['rattles', 'starlet', 'startle'])
# (3, ['ravels', 'salver', 'slaver'])
# (3, ['rawest', 'waster', 'waters'])
# (3, ['reales', 'resale', 'sealer'])
# (3, ['realist', 'retails', 'saltier'])
# (3, ['reis', 'rise', 'sire'])
# (3, ['relives', 'reviles', 'servile'])
# (3, ['rents', 'stern', 'terns'])
# (3, ['reprising', 'respiring', 'springier'])
# (3, ["resin's", "rinse's", "siren's"])
# (3, ['resins', 'rinses', 'sirens'])
# (3, ['resistor', 'roisters', 'sorriest'])
# (3, ['resort', 'roster', 'sorter'])
# (3, ["resort's", "roster's", "sorter's"])
# (3, ['resorts', 'rosters', 'sorters'])
# (3, ['respect', 'scepter', 'specter'])
# (3, ["respect's", "scepter's", "specter's"])
# (3, ['respects', 'scepters', 'specters'])
# (3, ['retard', 'tarred', 'trader'])
# (3, ['retards', 'starred', 'traders'])
# (3, ['retinue', 'reunite', 'uterine'])
# (3, ['retired', 'retried', 'tireder'])
# (3, ['retrain', 'terrain', 'trainer'])
# (3, ['rickets', 'sticker', 'tickers'])
# (3, ['riot', 'tiro', 'trio'])
# (3, ["riot's", "tiro's", "trio's"])
# (3, ['rite', 'tier', 'tire'])
# (3, ["rite's", "tier's", "tire's"])
# (3, ['roast', 'sorta', 'taros'])
# (3, ['roost', 'roots', 'torso'])
# (3, ['rosiest', 'sorties', 'stories'])
# (3, ['rots', 'sort', 'tors'])
# (3, ['routs', 'torus', 'tours'])
# (3, ['rowdier', 'wordier', 'worried'])
# (3, ["saint's", "satin's", "stain's"])
# (3, ['salve', 'slave', 'vales'])
# (3, ['seated', 'sedate', 'teased'])
# (3, ['serves', 'severs', 'verses'])
# (3, ['setter', 'street', 'tester'])
# (3, ["setter's", "street's", "tester's"])
# (3, ['sheet', 'thees', 'these'])
# (3, ['shout', 'south', 'thous'])
# (3, ['sinew', 'swine', 'wines'])
# (3, ["skate's", "stake's", "steak's"])
# (3, ['skated', 'staked', 'tasked'])
# (3, ['skater', 'streak', 'takers'])
# (3, ['skates', 'stakes', 'steaks'])
# (3, ['sonnet', 'tenons', 'tonnes'])
# (3, ['sorted', 'stored', 'strode'])
# (3, ['sower', 'swore', 'worse'])
# (3, ['stared', 'trades', 'treads'])
# (3, ['state', 'taste', 'teats'])
# (3, ['stater', 'taster', 'treats'])
# (3, ['stew', 'west', 'wets'])
# (3, ['stiller', 'tillers', 'trellis'])
# (3, ['stoner', 'tenors', 'tensor'])
# (3, ['story', 'troys', 'tyros'])
# (3, ['stow', 'tows', 'twos'])
# (3, ['stumbler', 'tumblers', 'tumbrels'])
# (3, ['swath', 'thaws', 'whats'])
# (3, ['sway', 'ways', 'yaws'])
# (3, ['swear', 'wares', 'wears'])
# (3, ['swelter', 'welters', 'wrestle'])
# (3, ['thickest', 'thickets', 'thickset'])
# (3, ['throw', 'worth', 'wroth'])
# (3, ['tow', 'two', 'wot'])
# (3, ['wander', 'warden', 'warned'])
# (3, ['weather', 'whereat', 'wreathe'])
# (3, ['weird', 'wider', 'wired'])
# (3, ['weirs', 'wires', 'wiser'])
# (3, ['whiter', 'wither', 'writhe'])
# (4, ['abet', 'bate', 'beat', 'beta'])
# (4, ['ablest', 'bleats', 'stable', 'tables'])
# (4, ['acres', 'cares', 'races', 'scare'])
# (4, ['actors', 'castor', 'costar', 'scrota'])
# (4, ['acts', 'cast', 'cats', 'scat'])
# (4, ['alerted', 'altered', 'related', 'treadle'])
# (4, ['alerts', 'alters', 'salter', 'staler'])
# (4, ['ales', 'leas', 'sale', 'seal'])
# (4, ['allergy', 'gallery', 'largely', 'regally'])
# (4, ['ambled', 'bedlam', 'blamed', 'lambed'])
# (4, ['amen', 'mane', 'mean', 'name'])
# (4, ['angrier', 'earring', 'rangier', 'rearing'])
# (4, ['ankhs', 'hanks', 'khans', 'shank'])
# (4, ['antis', 'saint', 'satin', 'stain'])
# (4, ['artiest', 'artiste', 'attires', 'tastier'])
# (4, ['artsy', 'satyr', 'stray', 'trays'])
# (4, ['ascot', 'coast', 'coats', 'tacos'])
# (4, ['asp', 'pas', 'sap', 'spa'])
# (4, ['aspired', 'despair', 'diapers', 'praised'])
# (4, ['asps', 'pass', 'saps', 'spas'])
# (4, ['assert', 'asters', 'stares', 'tasers'])
# (4, ['ate', 'eat', 'eta', 'tea'])
# (4, ['bared', 'beard', 'bread', 'debar'])
# (4, ['bast', 'bats', 'stab', 'tabs'])
# (4, ['bluest', 'bustle', 'sublet', 'subtle'])
# (4, ['bruise', 'buries', 'busier', 'rubies'])
# (4, ['brutes', 'buster', 'rebuts', 'tubers'])
# (4, ['bust', 'buts', 'stub', 'tubs'])
# (4, ['cadres', 'cedars', 'sacred', 'scared'])
# (4, ['canter', 'nectar', 'recant', 'trance'])
# (4, ['canters', 'recants', 'scanter', 'trances'])
# (4, ['carpels', 'parcels', 'placers', 'scalper'])
# (4, ['claimed', 'decimal', 'declaim', 'medical'])
# (4, ['coins', 'icons', 'scion', 'sonic'])
# (4, ['construe', 'counters', 'recounts', 'trounces'])
# (4, ['dale', 'deal', 'lade', 'lead'])
# (4, ['dales', 'deals', 'lades', 'leads'])
# (4, ['danger', 'gander', 'garden', 'ranged'])
# (4, ['danker', 'darken', 'narked', 'ranked'])
# (4, ['dearer', 'reader', 'reared', 'reread'])
# (4, ['deigns', 'design', 'signed', 'singed'])
# (4, ['delis', 'idles', 'sidle', 'slide'])
# (4, ['dentin', 'indent', 'intend', 'tinned'])
# (4, ['depart', 'parted', 'petard', 'prated'])
# (4, ['deposit', 'dopiest', 'posited', 'topside'])
# (4, ['diet', 'edit', 'tide', 'tied'])
# (4, ['diets', 'edits', 'sited', 'tides'])
# (4, ['drape', 'padre', 'pared', 'raped'])
# (4, ['drawers', 'redraws', 'rewards', 'warders'])
# (4, ['earns', 'nears', 'saner', 'snare'])
# (4, ['editors', 'sortied', 'steroid', 'storied'])
# (4, ['emirs', 'mires', 'miser', 'rimes'])
# (4, ['emit', 'item', 'mite', 'time'])
# (4, ['enlists', 'listens', 'silents', 'tinsels'])
# (4, ['eons', 'noes', 'nose', 'ones'])
# (4, ['esters', 'resets', 'serest', 'steers'])
# (4, ['evil', 'live', 'veil', 'vile'])
# (4, ['filets', 'fliest', 'itself', 'stifle'])
# (4, ['forest', 'fortes', 'foster', 'softer'])
# (4, ['glare', 'lager', 'large', 'regal'])
# (4, ['gnus', 'guns', 'snug', 'sung'])
# (4, ['granite', 'ingrate', 'tangier', 'tearing'])
# (4, ['hales', 'heals', 'leash', 'shale'])
# (4, ['huts', 'shut', 'thus', 'tush'])
# (4, ['idlest', 'listed', 'silted', 'tildes'])
# (4, ['ingress', 'resigns', 'signers', 'singers'])
# (4, ['inserted', 'nerdiest', 'resident', 'trendies'])
# (4, ['inset', 'nites', 'stein', 'tines'])
# (4, ['iterates', 'teariest', 'treaties', 'treatise'])
# (4, ['lair', 'liar', 'lira', 'rail'])
# (4, ["lair's", "liar's", "lira's", "rail's"])
# (4, ['lairs', 'liars', 'liras', 'rails'])
# (4, ['lameness', 'maleness', 'nameless', 'salesmen'])
# (4, ['lament', 'mantel', 'mantle', 'mental'])
# (4, ['last', 'lats', 'salt', 'slat'])
# (4, ['lasting', 'salting', 'slating', 'staling'])
# (4, ['leap', 'pale', 'peal', 'plea'])
# (4, ["leap's", "pale's", "peal's", "plea's"])
# (4, ['leapt', 'petal', 'plate', 'pleat'])
# (4, ['limes', 'miles', 'slime', 'smile'])
# (4, ['lingos', 'logins', 'losing', 'soling'])
# (4, ['loops', 'pools', 'sloop', 'spool'])
# (4, ['luster', 'lustre', 'result', 'rustle'])
# (4, ["luster's", "lustre's", "result's", "rustle's"])
# (4, ['manes', 'manse', 'means', 'names'])
# (4, ['mate', 'meat', 'tame', 'team'])
# (4, ['merit', 'miter', 'remit', 'timer'])
# (4, ['naps', 'pans', 'snap', 'span'])
# (4, ['nest', 'nets', 'sent', 'tens'])
# (4, ['nips', 'pins', 'snip', 'spin'])
# (4, ['nope', 'open', 'peon', 'pone'])
# (4, ['notes', 'onset', 'stone', 'tones'])
# (4, ['oils', 'silo', 'soil', 'soli'])
# (4, ['ores', 'roes', 'rose', 'sore'])
# (4, ['painters', 'pantries', 'pertains', 'repaints'])
# (4, ['pare', 'pear', 'rape', 'reap'])
# (4, ['parings', 'parsing', 'rasping', 'sparing'])
# (4, ['parley', 'pearly', 'player', 'replay'])
# (4, ['parries', 'rapiers', 'raspier', 'repairs'])
# (4, ['parroted', 'predator', 'prorated', 'teardrop'])
# (4, ['pars', 'raps', 'rasp', 'spar'])
# (4, ['part', 'rapt', 'tarp', 'trap'])
# (4, ['parties', 'pastier', 'pirates', 'traipse'])
# (4, ['past', 'pats', 'spat', 'taps'])
# (4, ['penis', 'pines', 'snipe', 'spine'])
# (4, ['pintos', 'piston', 'pitons', 'points'])
# (4, ['priest', 'ripest', 'sprite', 'stripe'])
# (4, ['rated', 'tared', 'trade', 'tread'])
# (4, ['reduces', 'rescued', 'secured', 'seducer'])
# (4, ['refits', 'rifest', 'sifter', 'strife'])
# (4, ['reigns', 'resign', 'signer', 'singer'])
# (4, ['reserve', 'reveres', 'reverse', 'severer'])
# (4, ['riots', 'tiros', 'torsi', 'trios'])
# (4, ['rites', 'tiers', 'tires', 'tries'])
# (4, ['rues', 'ruse', 'sure', 'user'])
# (4, ['serve', 'sever', 'veers', 'verse'])
# (4, ['setters', 'streets', 'tersest', 'testers'])
# (4, ['skating', 'staking', 'takings', 'tasking'])
# (4, ['slates', 'stales', 'steals', 'tassel'])
# (5, ['alerting', 'altering', 'integral', 'relating', 'triangle'])
# (5, ['angered', 'derange', 'enraged', 'grandee', 'grenade'])
# (5, ['angriest', 'gantries', 'ingrates', 'rangiest', 'tasering'])
# (5, ['arced', 'cadre', 'cared', 'cedar', 'raced'])
# (5, ['ares', 'ears', 'eras', 'sear', 'sera'])
# (5, ['arts', 'rats', 'star', 'tars', 'tsar'])
# (5, ['bares', 'baser', 'bears', 'saber', 'sabre'])
# (5, ['capers', 'crapes', 'parsec', 'recaps', 'scrape'])
# (5, ['dearths', 'hardest', 'hatreds', 'threads', 'trashed'])
# (5, ['deltas', 'lasted', 'salted', 'slated', 'staled'])
# (5, ['drawer', 'redraw', 'reward', 'warder', 'warred'])
# (5, ['east', 'eats', 'sate', 'seat', 'teas'])
# (5, ['emits', 'items', 'mites', 'smite', 'times'])
# (5, ['enlist', 'inlets', 'listen', 'silent', 'tinsel'])
# (5, ['ester', 'reset', 'steer', 'terse', 'trees'])
# (5, ['hares', 'hears', 'rheas', 'share', 'shear'])
# (5, ['mates', 'meats', 'steam', 'tames', 'teams'])
# (5, ['merits', 'mister', 'miters', 'remits', 'timers'])
# (5, ['parleys', 'parsley', 'players', 'replays', 'sparely'])
# (5, ['parses', 'passer', 'spares', 'sparse', 'spears'])
# (5, ['parts', 'sprat', 'strap', 'tarps', 'traps'])
# (5, ['paste', 'pates', 'septa', 'spate', 'tapes'])
# (5, ['persist', 'priests', 'spriest', 'sprites', 'stripes'])
# (5, ['pores', 'poser', 'prose', 'ropes', 'spore'])
# (5, ['reins', 'resin', 'rinse', 'risen', 'siren'])
# (5, ['restrain', 'retrains', 'strainer', 'terrains', 'trainers'])
# (5, ['skate', 'stake', 'steak', 'takes', 'teaks'])
# (6, ['abets', 'baste', 'bates', 'beast', 'beats', 'betas'])
# (6, ['aster', 'rates', 'stare', 'tares', 'taser', 'tears'])
# (6, ['caret', 'cater', 'crate', 'react', 'recta', 'trace'])
# (6, ['drapes', 'padres', 'parsed', 'rasped', 'spared', 'spread'])
# (6, ['lapse', 'leaps', 'pales', 'peals', 'pleas', 'sepal'])
# (6, ['least', 'slate', 'stale', 'steal', 'tales', 'teals'])
# (6, ['opts', 'post', 'pots', 'spot', 'stop', 'tops'])
# (6, ['palest', 'pastel', 'petals', 'plates', 'pleats', 'staple'])
# (7, ['carets', 'caster', 'caters', 'crates', 'reacts', 'recast', 'traces'])
# (7, ['pares', 'parse', 'pears', 'rapes', 'reaps', 'spare', 'spear'])

# %%
def filter_length(d, n):
    """Select only the words in d that have n letters.

    d: map from word to list of anagrams
    n: integer number of letters

    returns: new map from word to list of anagrams
    """
    res = {}
    for word, anagrams in d.items():
        if len(word) == n:
            res[word] = anagrams
    return res

# %%
eight_letters = filter_length(anagram_dict, 8)
print_anagram_sets_in_order(eight_letters)
# Out:
# (2, ['Annmarie', 'Armenian'])
# (2, ['Banneker', 'Bernanke'])
# (2, ["Bellow's", "Bowell's"])
# (2, ["Biogen's", "Boeing's"])
# (2, ["Booker's", "Brooke's"])
# (2, ["Breton's", "Bronte's"])
# (2, ['Callisto', 'Castillo'])
# (2, ["Cantor's", "Carnot's"])
# (2, ['Caroline', 'Cornelia'])
# (2, ["Carter's", "Crater's"])
# (2, ["Castor's", "Castro's"])
# (2, ["Ceylon's", "Conley's"])
# (2, ["Dalian's", "Danial's"])
# (2, ["Dannie's", "Dianne's"])
# (2, ["Dionne's", "Donnie's"])
# (2, ["Dunbar's", "Durban's"])
# (2, ["Elanor's", "Elnora's"])
# (2, ["Eliseo's", "Eloise's"])
# (2, ["Fannie's", "Fenian's"])
# (2, ["Forest's", "Foster's"])
# (2, ["Freida's", "Frieda's"])
# (2, ['Georgian', 'Georgina'])
# (2, ["Janine's", "Jannie's"])
# (2, ["Lenora's", "Lorena's"])
# (2, ["Lenore's", "Lorene's"])
# (2, ["Malian's", "Manila's"])
# (2, ["Maoism's", "Mimosa's"])
# (2, ["Marcie's", "Mercia's"])
# (2, ["Marian's", "Marina's"])
# (2, ["Marlon's", "Molnar's"])
# (2, ["Maseru's", "Mauser's"])
# (2, ["Monroe's", "Moreno's"])
# (2, ["Roland's", "Ronald's"])
# (2, ["Sharpe's", "Sherpa's"])
# (2, ["Sheila's", "Shelia's"])
# (2, ['Shetland', 'Stendhal'])
# (2, ['Sumerian', 'Suriname'])
# (2, ["Tucson's", "Tuscon's"])
# (2, ["Warner's", "Warren's"])
# (2, ['abhorred', 'harbored'])
# (2, ['abridges', 'brigades'])
# (2, ['aconites', 'canoeist'])
# (2, ["action's", "cation's"])
# (2, ['actuator', 'autocrat'])
# (2, ['adjuster', 'readjust'])
# (2, ['admirers', 'marrieds'])
# (2, ['advances', 'canvased'])
# (2, ["affair's", "raffia's"])
# (2, ['ailments', 'manliest'])
# (2, ["airman's", "marina's"])
# (2, ['alarming', 'marginal'])
# (2, ["alcove's", "coeval's"])
# (2, ['allotted', 'totalled'])
# (2, ["allure's", "laurel's"])
# (2, ['altitude', 'latitude'])
# (2, ['altruism', 'muralist'])
# (2, ["alumna's", "manual's"])
# (2, ['amortize', 'atomizer'])
# (2, ['anapests', 'peasants'])
# (2, ['angering', 'enraging'])
# (2, ['antigens', 'gentians'])
# (2, ["antler's", "rental's"])
# (2, ['archaism', 'charisma'])
# (2, ['arrogant', 'tarragon'])
# (2, ['articles', 'recitals'])
# (2, ['artisans', 'tsarinas'])
# (2, ["artist's", "strait's"])
# (2, ['artistes', 'artsiest'])
# (2, ["ascent's", "stance's"])
# (2, ['ascribed', 'carbides'])
# (2, ['aspirant', 'partisan'])
# (2, ['aspirate', 'parasite'])
# (2, ['aspiring', 'praising'])
# (2, ['assaying', 'gainsays'])
# (2, ['assuages', 'sausages'])
# (2, ['astutest', 'statutes'])
# (2, ['ateliers', 'earliest'])
# (2, ['atheists', 'hastiest'])
# (2, ['attuning', 'taunting'])
# (2, ['auctions', 'cautions'])
# (2, ['austerer', 'treasure'])
# (2, ['avengers', 'engraves'])
# (2, ['babbling', 'blabbing'])
# (2, ['backrest', 'brackets'])
# (2, ['backward', 'drawback'])
# (2, ['ballsier', 'liberals'])
# (2, ["bather's", "breath's"])
# (2, ["battle's", "tablet's"])
# (2, ['beadiest', 'diabetes'])
# (2, ['bearding', 'breading'])
# (2, ["beater's", "rebate's"])
# (2, ['beavered', 'bereaved'])
# (2, ['begrudge', 'debugger'])
# (2, ['berating', 'rebating'])
# (2, ['berthing', 'brighten'])
# (2, ['bestiary', 'sybarite'])
# (2, ['betiding', 'debiting'])
# (2, ['birettas', 'terabits'])
# (2, ['birthers', 'rebirths'])
# (2, ['blankest', 'blankets'])
# (2, ['blasting', 'stabling'])
# (2, ['blearily', 'reliably'])
# (2, ['bleating', 'tangible'])
# (2, ['blessing', 'glibness'])
# (2, ['blisters', 'bristles'])
# (2, ['blobbing', 'bobbling'])
# (2, ['blogging', 'boggling'])
# (2, ['blotting', 'bottling'])
# (2, ["blower's", "bowler's"])
# (2, ['bogeyman', 'moneybag'])
# (2, ['bolsters', 'lobsters'])
# (2, ['bordello', 'doorbell'])
# (2, ['brawlers', 'warblers'])
# (2, ['brawling', 'warbling'])
# (2, ['breasted', 'debaters'])
# (2, ['briskest', 'briskets'])
# (2, ['bristled', 'driblets'])
# (2, ["buffer's", "rebuff's"])
# (2, ['buffered', 'rebuffed'])
# (2, ['builders', 'rebuilds'])
# (2, ["bustle's", "sublet's"])
# (2, ['buttered', 'rebutted'])
# (2, ['cackling', 'clacking'])
# (2, ['caduceus', 'caucused'])
# (2, ['caissons', 'cassinos'])
# (2, ['calipers', 'replicas'])
# (2, ['calkings', 'slacking'])
# (2, ['cambered', 'embraced'])
# (2, ['campiest', 'campsite'])
# (2, ['canaries', 'cesarian'])
# (2, ['canister', 'scantier'])
# (2, ["cantor's", "carton's"])
# (2, ["caring's", "racing's"])
# (2, ['carolled', 'collared'])
# (2, ["cartel's", "claret's"])
# (2, ['carvings', 'cravings'])
# (2, ["caster's", "recast's"])
# (2, ["castor's", "costar's"])
# (2, ['casually', 'causally'])
# (2, ["cavern's", "craven's"])
# (2, ["censer's", "screen's"])
# (2, ['censored', 'encoders'])
# (2, ['cervices', 'crevices'])
# (2, ["cesium's", "miscue's"])
# (2, ['chagrins', 'crashing'])
# (2, ['chanters', 'stancher'])
# (2, ['charmers', 'marchers'])
# (2, ['charming', 'marching'])
# (2, ["chaser's", "search's"])
# (2, ['chatters', 'ratchets'])
# (2, ['cheating', 'teaching'])
# (2, ['checkers', 'rechecks'])
# (2, ['chiefest', 'fetiches'])
# (2, ['cilantro', 'contrail'])
# (2, ['ciphered', 'decipher'])
# (2, ["circle's", "cleric's"])
# (2, ['citadels', 'dialects'])
# (2, ["citrus's", "rustic's"])
# (2, ['citruses', 'curtsies'])
# (2, ['clambers', 'scramble'])
# (2, ['clanging', 'glancing'])
# (2, ['clasping', 'scalping'])
# (2, ['cleaners', 'cleanser'])
# (2, ['clematis', 'climates'])
# (2, ['climaxes', 'exclaims'])
# (2, ['clinkers', 'crinkles'])
# (2, ['clippers', 'cripples'])
# (2, ['clobbers', 'cobblers'])
# (2, ['cloister', 'costlier'])
# (2, ['coarsest', 'coasters'])
# (2, ['comedian', 'demoniac'])
# (2, ['compiled', 'complied'])
# (2, ['conciser', 'cornices'])
# (2, ['condoles', 'consoled'])
# (2, ["condor's", "cordon's"])
# (2, ['conduits', 'discount'])
# (2, ['conifers', 'forensic'])
# (2, ['conserve', 'converse'])
# (2, ['consoles', 'coolness'])
# (2, ['contains', 'sanction'])
# (2, ['contuses', 'countess'])
# (2, ["copula's", "cupola's"])
# (2, ["corona's", "racoon's"])
# (2, ['coroners', 'crooners'])
# (2, ['corseted', 'escorted'])
# (2, ['coteries', 'esoteric'])
# (2, ["course's", "source's"])
# (2, ["covert's", "vector's"])
# (2, ['cowlings', 'scowling'])
# (2, ["crater's", "tracer's"])
# (2, ['creation', 'reaction'])
# (2, ['creative', 'reactive'])
# (2, ['creators', 'reactors'])
# (2, ['credited', 'directed'])
# (2, ['creditor', 'director'])
# (2, ['crochets', 'crotches'])
# (2, ["crocus's", "succor's"])
# (2, ['cruelest', 'lectures'])
# (2, ['cruisers', 'scurries'])
# (2, ['crumpets', 'spectrum'])
# (2, ['crustier', 'recruits'])
# (2, ['curtness', 'encrusts'])
# (2, ['dapperer', 'prepared'])
# (2, ['dateline', 'entailed'])
# (2, ["dauber's", "earbud's"])
# (2, ['dawdling', 'waddling'])
# (2, ['deadlier', 'derailed'])
# (2, ["dealer's", "leader's"])
# (2, ['dealings', 'signaled'])
# (2, ['decadent', 'decanted'])
# (2, ['deceiver', 'received'])
# (2, ['decimate', 'medicate'])
# (2, ['defiling', 'fielding'])
# (2, ['deifying', 'edifying'])
# (2, ['delights', 'slighted'])
# (2, ['deluding', 'indulged'])
# (2, ['demanded', 'maddened'])
# (2, ['demeanor', 'enamored'])
# (2, ['demotion', 'motioned'])
# (2, ['demurest', 'mustered'])
# (2, ['demurred', 'murdered'])
# (2, ["dentin's", "indent's"])
# (2, ['departed', 'predated'])
# (2, ['deposits', 'topsides'])
# (2, ['depraved', 'pervaded'])
# (2, ['depraves', 'pervades'])
# (2, ['deranged', 'gardened'])
# (2, ['desserts', 'stressed'])
# (2, ['deviates', 'sedative'])
# (2, ['dinettes', 'insetted'])
# (2, ['directer', 'redirect'])
# (2, ['discerns', 'rescinds'])
# (2, ['discover', 'divorces'])
# (2, ['discreet', 'discrete'])
# (2, ['diseases', 'seasides'])
# (2, ['disperse', 'presides'])
# (2, ['disprove', 'provides'])
# (2, ['distaste', 'staidest'])
# (2, ['doorstep', 'torpedos'])
# (2, ['dovetail', 'violated'])
# (2, ["downer's", "wonder's"])
# (2, ['download', 'woodland'])
# (2, ['dragnets', 'grandest'])
# (2, ['drainage', 'gardenia'])
# (2, ['drollest', 'strolled'])
# (2, ['drowsing', 'wordings'])
# (2, ['drugging', 'grudging'])
# (2, ['dungaree', 'underage'])
# (2, ['duodenal', 'unloaded'])
# (2, ['dwindles', 'swindled'])
# (2, ['eagerest', 'steerage'])
# (2, ["eaglet's", "legate's"])
# (2, ['earnings', 'grannies'])
# (2, ['earthier', 'heartier'])
# (2, ['editions', 'sedition'])
# (2, ["eighth's", "height's"])
# (2, ['elapsing', 'pleasing'])
# (2, ['elastics', 'scaliest'])
# (2, ['electors', 'selector'])
# (2, ['elegiacs', 'legacies'])
# (2, ['elisions', 'oiliness'])
# (2, ['emanates', 'manatees'])
# (2, ['emirates', 'steamier'])
# (2, ['enclaves', 'valences'])
# (2, ['enervate', 'venerate'])
# (2, ["enigma's", "gamine's"])
# (2, ['enlarges', 'generals'])
# (2, ['enshroud', 'unhorsed'])
# (2, ['ensnares', 'nearness'])
# (2, ['entirety', 'eternity'])
# (2, ['entrails', 'latrines'])
# (2, ['epitaphs', 'happiest'])
# (2, ['erasures', 'reassure'])
# (2, ['erupting', 'reputing'])
# (2, ['escapism', 'scampies'])
# (2, ['escapist', 'spaciest'])
# (2, ['estimate', 'meatiest'])
# (2, ['excepted', 'expected'])
# (2, ['fairness', 'sanserif'])
# (2, ["farmer's", "framer's"])
# (2, ['feistier', 'fieriest'])
# (2, ['fiendish', 'finished'])
# (2, ['fighters', 'freights'])
# (2, ["filler's", "refill's"])
# (2, ["filter's", "trifle's"])
# (2, ["finder's", "friend's"])
# (2, ["finger's", "fringe's"])
# (2, ['finisher', 'refinish'])
# (2, ['flatcars', 'fractals'])
# (2, ['flirting', 'trifling'])
# (2, ['forester', 'reforest'])
# (2, ["former's", "reform's"])
# (2, ['freshest', 'freshets'])
# (2, ["gaiter's", "triage's"])
# (2, ['ganglier', 'regaling'])
# (2, ['gardener', 'garnered'])
# (2, ['gateways', 'getaways'])
# (2, ['geldings', 'sledging'])
# (2, ['generate', 'teenager'])
# (2, ['genitals', 'stealing'])
# (2, ['germinal', 'malinger'])
# (2, ["ginger's", "nigger's"])
# (2, ["gingko's", "ginkgo's"])
# (2, ['gingkoes', 'ginkgoes'])
# (2, ["girdle's", "glider's"])
# (2, ['glinting', 'tingling'])
# (2, ['glossing', 'goslings'])
# (2, ['gnashing', 'hangings'])
# (2, ["goiter's", "goitre's"])
# (2, ["grader's", "regard's"])
# (2, ['gradient', 'treading'])
# (2, ['greening', 'reneging'])
# (2, ['greenish', 'sheering'])
# (2, ['grounded', 'underdog'])
# (2, ['groupers', 'regroups'])
# (2, ['gunshots', 'shotguns'])
# (2, ['gustiest', 'gutsiest'])
# (2, ["halter's", "lather's"])
# (2, ['haltered', 'lathered'])
# (2, ['handfuls', 'handsful'])
# (2, ['handouts', 'thousand'])
# (2, ['hangover', 'overhang'])
# (2, ['hankered', 'harkened'])
# (2, ['harshest', 'thrashes'])
# (2, ['hassling', 'slashing'])
# (2, ['hatchets', 'thatches'])
# (2, ["hatter's", "threat's"])
# (2, ["hawser's", "washer's"])
# (2, ['hearings', 'shearing'])
# (2, ['heisting', 'nighties'])
# (2, ['heptagon', 'pathogen'])
# (2, ["herpes's", "sphere's"])
# (2, ['holsters', 'hostlers'])
# (2, ["hornet's", "throne's"])
# (2, ['horseman', 'menorahs'])
# (2, ['hungover', 'overhung'])
# (2, ['huntsman', 'manhunts'])
# (2, ["hustle's", "sleuth's"])
# (2, ['hustlers', 'ruthless'])
# (2, ['hustling', 'sunlight'])
# (2, ["icecap's", "ipecac's"])
# (2, ['idolater', 'tailored'])
# (2, ['immersed', 'simmered'])
# (2, ['impeding', 'impinged'])
# (2, ['imprints', 'misprint'])
# (2, ['impurest', 'stumpier'])
# (2, ['incenses', 'niceness'])
# (2, ["incest's", "insect's"])
# (2, ['indented', 'intended'])
# (2, ['infidels', 'infields'])
# (2, ['infringe', 'refining'])
# (2, ['inklings', 'slinking'])
# (2, ['insecure', 'sinecure'])
# (2, ['insisted', 'tidiness'])
# (2, ["insole's", "lesion's"])
# (2, ["instep's", "spinet's"])
# (2, ['insulted', 'unlisted'])
# (2, ['insureds', 'sundries'])
# (2, ['intenser', 'internes'])
# (2, ['interred', 'trendier'])
# (2, ['itchiest', 'theistic'])
# (2, ['keynotes', 'keystone'])
# (2, ['kitchens', 'thickens'])
# (2, ["kitsch's", "shtick's"])
# (2, ['knitters', 'trinkets'])
# (2, ['lambkins', 'lambskin'])
# (2, ["latter's", "rattle's"])
# (2, ["layout's", "outlay's"])
# (2, ['layovers', 'overlays'])
# (2, ['learners', 'relearns'])
# (2, ['leeriest', 'steelier'])
# (2, ["legman's", "mangle's"])
# (2, ["lentil's", "lintel's"])
# (2, ['leotards', 'lodestar'])
# (2, ['lessened', 'needless'])
# (2, ['levering', 'reveling'])
# (2, ['licenses', 'silences'])
# (2, ['lickings', 'slicking'])
# (2, ['lighters', 'slighter'])
# (2, ["lineup's", "lupine's"])
# (2, ['lipreads', 'spiraled'])
# (2, ['littoral', 'tortilla'])
# (2, ["loader's", "ordeal's"])
# (2, ['lookouts', 'outlooks'])
# (2, ["louver's", "velour's"])
# (2, ["lovely's", "volley's"])
# (2, ['lowering', 'roweling'])
# (2, ["lubber's", "rubble's"])
# (2, ["lumber's", "rumble's"])
# (2, ['madrasas', 'madrassa'])
# (2, ["maiden's", "median's"])
# (2, ['mangiest', 'steaming'])
# (2, ["mantis's", "matins's"])
# (2, ['mantissa', 'satanism'])
# (2, ["marble's", "ramble's"])
# (2, ['marbling', 'rambling'])
# (2, ["marker's", "remark's"])
# (2, ["master's", "stream's"])
# (2, ['mastered', 'streamed'])
# (2, ['mattress', 'smartest'])
# (2, ['medalist', 'misdealt'])
# (2, ['meriting', 'mitering'])
# (2, ["meteor's", "remote's"])
# (2, ['metering', 'regiment'])
# (2, ['migrants', 'smarting'])
# (2, ['mildness', 'mindless'])
# (2, ["minuet's", "minute's"])
# (2, ['minutely', 'untimely'])
# (2, ['miracles', 'reclaims'])
# (2, ['misdeals', 'misleads'])
# (2, ['misreads', 'sidearms'])
# (2, ['misspelt', 'simplest'])
# (2, ['monetize', 'timezone'])
# (2, ['moodiest', 'sodomite'])
# (2, ['mutilate', 'ultimate'])
# (2, ['nepotism', 'pimentos'])
# (2, ['nerviest', 'reinvest'])
# (2, ['neurosis', 'resinous'])
# (2, ['nightcap', 'patching'])
# (2, ['nitpicks', 'stickpin'])
# (2, ['nitrates', 'straiten'])
# (2, ['nitrogen', 'ringtone'])
# (2, ['observes', 'obverses'])
# (2, ['onrushes', 'unhorses'])
# (2, ["option's", "potion's"])
# (2, ['organist', 'roasting'])
# (2, ['oriental', 'relation'])
# (2, ['outsells', 'sellouts'])
# (2, ['overacts', 'overcast'])
# (2, ['overdoes', 'overdose'])
# (2, ['overtake', 'takeover'])
# (2, ['overturn', 'turnover'])
# (2, ["oyster's", "storey's"])
# (2, ['pailfuls', 'pailsful'])
# (2, ['painless', 'spaniels'])
# (2, ['palmists', 'psalmist'])
# (2, ['palsying', 'splaying'])
# (2, ['panelist', 'plainest'])
# (2, ["panier's", "rapine's"])
# (2, ['parceled', 'replaced'])
# (2, ['parleyed', 'replayed'])
# (2, ["parsec's", "scrape's"])
# (2, ["pastel's", "staple's"])
# (2, ["pathos's", "potash's"])
# (2, ["patrol's", "portal's"])
# (2, ["patron's", "tarpon's"])
# (2, ['patterns', 'transept'])
# (2, ['pedaling', 'pleading'])
# (2, ['pederast', 'predates'])
# (2, ['peelings', 'sleeping'])
# (2, ['peerless', 'sleepers'])
# (2, ['percales', 'replaces'])
# (2, ['perfects', 'prefects'])
# (2, ['perverse', 'preserve'])
# (2, ["phrase's", "seraph's"])
# (2, ['phrasing', 'sharping'])
# (2, ['pillages', 'spillage'])
# (2, ["pincer's", "prince's"])
# (2, ["planet's", "platen's"])
# (2, ['plasters', 'staplers'])
# (2, ['pleaders', 'relapsed'])
# (2, ['pointers', 'proteins'])
# (2, ['poisoner', 'snoopier'])
# (2, ["porter's", "report's"])
# (2, ['portions', 'positron'])
# (2, ["poster's", "presto's"])
# (2, ["praise's", "spirea's"])
# (2, ['predicts', 'scripted'])
# (2, ['preludes', 'repulsed'])
# (2, ['premised', 'simpered'])
# (2, ['preteens', 'pretense'])
# (2, ['preterit', 'prettier'])
# (2, ['procured', 'producer'])
# (2, ['prosiest', 'ripostes'])
# (2, ['protests', 'spotters'])
# (2, ['pursuers', 'usurpers'])
# (2, ['pursuing', 'usurping'])
# (2, ['quartets', 'squatter'])
# (2, ['randiest', 'strained'])
# (2, ['rapidest', 'traipsed'])
# (2, ["rapier's", "repair's"])
# (2, ["rattan's", "tartan's"])
# (2, ['readiest', 'steadier'])
# (2, ['realizes', 'sleazier'])
# (2, ['reclines', 'silencer'])
# (2, ['recourse', 'resource'])
# (2, ['refunded', 'underfed'])
# (2, ['reissued', 'residues'])
# (2, ['reliving', 'reviling'])
# (2, ['reorging', 'rogering'])
# (2, ['repartee', 'repeater'])
# (2, ['reposing', 'spongier'])
# (2, ['reprises', 'respires'])
# (2, ["resale's", "sealer's"])
# (2, ['rescuing', 'securing'])
# (2, ['research', 'searcher'])
# (2, ['reserved', 'reversed'])
# (2, ['reserves', 'reverses'])
# (2, ["resist's", "sister's"])
# (2, ['resorted', 'restored'])
# (2, ['respells', 'spellers'])
# (2, ['restarts', 'starters'])
# (2, ["retard's", "trader's"])
# (2, ['rethinks', 'thinkers'])
# (2, ['retinues', 'reunites'])
# (2, ['retrials', 'trailers'])
# (2, ["return's", "turner's"])
# (2, ['retweets', 'tweeters'])
# (2, ["review's", "viewer's"])
# (2, ['ringlets', 'sterling'])
# (2, ['rivaling', 'virginal'])
# (2, ['rockiest', 'stockier'])
# (2, ['roundest', 'tonsured'])
# (2, ['rowdiest', 'wordiest'])
# (2, ['royalist', 'solitary'])
# (2, ['rustiest', 'trusties'])
# (2, ['salients', 'saltines'])
# (2, ['sallying', 'signally'])
# (2, ["salver's", "slaver's"])
# (2, ["sateen's", "senate's"])
# (2, ['sauciest', 'suitcase'])
# (2, ['seabirds', 'sidebars'])
# (2, ['seething', 'sheeting'])
# (2, ['settable', 'testable'])
# (2, ['settlers', 'trestles'])
# (2, ["shiner's", "shrine's"])
# (2, ['shittier', 'thirties'])
# (2, ['shooting', 'soothing'])
# (2, ["shriek's", "shrike's"])
# (2, ['sideways', 'waysides'])
# (2, ["sifter's", "strife's"])
# (2, ["signer's", "singer's"])
# (2, ["silver's", "sliver's"])
# (2, ['singling', 'slinging'])
# (2, ["skater's", "streak's"])
# (2, ['skirting', 'striking'])
# (2, ['snatched', 'stanched'])
# (2, ['snooping', 'spooning'])
# (2, ['somberly', 'sombrely'])
# (2, ["sorbet's", "strobe's"])
# (2, ['sounding', 'undoings'])
# (2, ['sparsest', 'trespass'])
# (2, ['spawning', 'wingspan'])
# (2, ['spindled', 'splendid'])
# (2, ["sprout's", "stupor's"])
# (2, ['starlets', 'startles'])
# (2, ['startups', 'upstarts'])
# (2, ['stickler', 'trickles'])
# (2, ['stingray', 'straying'])
# (2, ["stoker's", "stroke's"])
# (2, ['stopping', 'toppings'])
# (2, ['strewing', 'wresting'])
# (2, ['striated', 'tardiest'])
# (2, ['strident', 'tridents'])
# (2, ['strumpet', 'trumpets'])
# (2, ['sunblock', 'unblocks'])
# (2, ["suture's", "uterus's"])
# (2, ['swashing', 'washings'])
# (2, ['sweatier', 'weariest'])
# (2, ['sweeping', 'weepings'])
# (2, ['swelters', 'wrestles'])
# (2, ['swindles', 'wildness'])
# (2, ["teazel's", "teazle's"])
# (2, ['theaters', 'theatres'])
# (2, ["timber's", "timbre's"])
# (2, ['trailing', 'trialing'])
# (2, ["travel's", "varlet's"])
# (2, ['tribunes', 'turbines'])
# (2, ["waster's", "waters's"])
# (2, ['weathers', 'wreathes'])
# (2, ['wigglers', 'wriggles'])
# (2, ['woodworm', 'wormwood'])
# (3, ['adroitly', 'dilatory', 'idolatry'])
# (3, ['agnostic', 'coasting', 'coatings'])
# (3, ['ancients', 'canniest', 'instance'])
# (3, ['arrested', 'retreads', 'serrated'])
# (3, ['bounders', 'rebounds', 'suborned'])
# (3, ["caller's", "cellar's", "recall's"])
# (3, ["canter's", "nectar's", "trance's"])
# (3, ['cantered', 'decanter', 'recanted'])
# (3, ["carpel's", "parcel's", "placer's"])
# (3, ['caterers', 'retraces', 'terraces'])
# (3, ['catering', 'creating', 'reacting'])
# (3, ['chastens', 'snatches', 'stanches'])
# (3, ['cheaters', 'hectares', 'teachers'])
# (3, ['compiles', 'complies', 'polemics'])
# (3, ["corset's", "escort's", "sector's"])
# (3, ['coursing', 'scouring', 'sourcing'])
# (3, ['cratered', 'retraced', 'terraced'])
# (3, ['critters', 'restrict', 'stricter'])
# (3, ["danger's", "gander's", "garden's"])
# (3, ["dearth's", "hatred's", "thread's"])
# (3, ['decimals', 'declaims', 'medicals'])
# (3, ['declines', 'licensed', 'silenced'])
# (3, ['deforest', 'forested', 'fostered'])
# (3, ['delivers', 'silvered', 'slivered'])
# (3, ['deranges', 'grandees', 'grenades'])
# (3, ['designer', 'redesign', 'resigned'])
# (3, ['desiring', 'residing', 'ringside'])
# (3, ['doubters', 'obtrudes', 'redoubts'])
# (3, ["drawer's", "reward's", "warder's"])
# (3, ['enlisted', 'listened', 'tinseled'])
# (3, ['estrange', 'reagents', 'sergeant'])
# (3, ["garret's", "garter's", "grater's"])
# (3, ['gentiles', 'sleeting', 'steeling'])
# (3, ['gentries', 'integers', 'steering'])
# (3, ["lament's", "mantel's", "mantle's"])
# (3, ['layering', 'relaying', 'yearling'])
# (3, ["leggin's", "neglig's", "niggle's"])
# (3, ["listen's", "silent's", "tinsel's"])
# (3, ['listener', 'reenlist', 'silenter'])
# (3, ['magnetos', 'megatons', 'montages'])
# (3, ["neuter's", "tenure's", "tureen's"])
# (3, ['outtakes', 'stakeout', 'takeouts'])
# (3, ['parental', 'paternal', 'prenatal'])
# (3, ["parley's", "player's", "replay's"])
# (3, ['pastries', 'raspiest', 'traipses'])
# (3, ['pertness', 'presents', 'serpents'])
# (3, ['platters', 'prattles', 'splatter'])
# (3, ['postured', 'proudest', 'sprouted'])
# (3, ["priest's", "sprite's", "stripe's"])
# (3, ['printers', 'reprints', 'sprinter'])
# (3, ['resistor', 'roisters', 'sorriest'])
# (3, ["resort's", "roster's", "sorter's"])
# (3, ['respects', 'scepters', 'specters'])
# (3, ["setter's", "street's", "tester's"])
# (3, ['stumbler', 'tumblers', 'tumbrels'])
# (3, ['thickest', 'thickets', 'thickset'])
# (4, ['construe', 'counters', 'recounts', 'trounces'])
# (4, ['inserted', 'nerdiest', 'resident', 'trendies'])
# (4, ['iterates', 'teariest', 'treaties', 'treatise'])
# (4, ['lameness', 'maleness', 'nameless', 'salesmen'])
# (4, ["luster's", "lustre's", "result's", "rustle's"])
# (4, ['painters', 'pantries', 'pertains', 'repaints'])
# (4, ['parroted', 'predator', 'prorated', 'teardrop'])
# (5, ['alerting', 'altering', 'integral', 'relating', 'triangle'])
# (5, ['angriest', 'gantries', 'ingrates', 'rangiest', 'tasering'])
# (5, ['restrain', 'retrains', 'strainer', 'terrains', 'trainers'])

# %%
# !redis-server --daemonize yes
# Out:
# 100182:C 08 Aug 2021 16:16:42.325 # oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# 100182:C 08 Aug 2021 16:16:42.325 # Redis version=5.0.3, bits=64, commit=00000000, modified=0, pid=100182, just started
# 100182:C 08 Aug 2021 16:16:42.325 # Configuration loaded

# %% [markdown]
# Here's an example from the [Redis tutorial on Real Python](https://realpython.com/python-redis/).

# %%
import redis

# %%
r = redis.Redis()

# %%
r.mset({"Croatia": "Zagreb", "Bahamas": "Nassau"})
# Out:
# True

# %%
r.get("Bahamas")
# Out:
# b'Nassau'

# %%
for key in r.keys():
    r.delete(key)

# %%
def all_anagrams_redis(word_iterator, r):
    """Finds all anagrams in a list of words.

    filename: string filename of the word list

    Returns: a map from each word to a list of its anagrams.
    """
    for word in word_iterator:
        t = signature(word)
        r.lpush(t, word)

# %%
all_anagrams_redis(iterate_words('american-english'), r)

# %%
r.keys()
# Out:
# [b'giinrw',
#  b"'Hasy",
#  b"'Zagnosuvy",
#  b"'acceinnnosv",
#  b'Nhooprrt',
#  b'ccegiiimnnosv',
#  b'accehst',
#  b'Maegirt',
#  b'Jaaintu',
#  b"'Daennos",
#  b'bddfmnosuu',
#  b"'aceimnoprst",
#  b'achktw',
#  b"'Rosss",
#  b'eehiilmmnosst',
#  b"'Keinrsst",
#  b'Saahnn',
#  b'addeegnr',
#  b"'aeinssswx",
#  b"'Sacehilmnns",
#  b'bbeiknor',
#  b'adiiooprsuv',
#  b'adeeehprsst',
#  b'ikrs',
#  b'eimossst',
#  b'delopsstu',
#  b'aadoprt',
#  b'ceginnovy',
#  b'eiorssu',
#  b'aeghinrrsstt',
#  b'aeimotx',
#  b'accefinost',
#  b"'aaaeimnqrsu",
#  b'Saeilnnov',
#  b'afllosw',
#  b'abgiiln',
#  b'Faeklnru',
#  b'diloy',
#  b'acn',
#  b'ddeloprs',
#  b'adgiluy',
#  b'deghhilorsstty',
#  b'aaegpsss',
#  b'eeept',
#  b'bdeefiils',
#  b'Eaeenrrst',
#  b'denorsu',
#  b'adeeeegnrrt',
#  b'cdeeu',
#  b'Aaadilnnsu',
#  b'degiklo',
#  b'Wiiklns',
#  b'aachrswy',
#  b"'Toost",
#  b'aacdeeps',
#  b"'aaeegmnoprst",
#  b"'Lefis",
#  b'eikooprs',
#  b'Oainsss',
#  b'acdimno',
#  b'acinopt',
#  b"'agorstu",
#  b"'Jadimssu",
#  b'deeglrs',
#  b"'Eaddrsw",
#  b'aceeekrrst',
#  b"'aehhst",
#  b'ailrsttu',
#  b"'acdhhioprrss",
#  b"'eiopstt",
#  b'acdelnnoos',
#  b'aaegimns',
#  b'aeehhsw',
#  b'egilt',
#  b'aacdiloz',
#  b'acilprrstu',
#  b'einrssstu',
#  b"'Caalorsy",
#  b'Maabmos',
#  b'abelmnorstuu',
#  b'almnorty',
#  b'Rdeeenrv',
#  b'acdefiip',
#  b'chlru',
#  b'dmoosy',
#  b'ceeiprs',
#  b'beeijlsu',
#  b"'Taehlsssy",
#  b'aehrtw',
#  b"'aadeklmorsw",
#  b'eiimmst',
#  b'afllnuuw',
#  b'ceehilmoorssssst',
#  b'egoorrsvw',
#  b'aceeghorrsv',
#  b'aelmpry',
#  b'Eahiiopt',
#  b"'Zgiilnsw",
#  b'aacghikmmnt',
#  b'deeilsvw',
#  b'adeefhrt',
#  b'aaacrwy',
#  b'biilmoty',
#  b'aacegilnss',
#  b'Faeehhinrt',
#  b'adehilsv',
#  b'cop',
#  b'deotuv',
#  b'aceeilnrssy',
#  b'acefiirt',
#  b'addenw',
#  b'aaillmrsy',
#  b'aciiimnnnooprstu',
#  b'deiooprst',
#  b'ceilmnoopt',
#  b'eeehilrssstv',
#  b"'Kaaceghjnnnsu",
#  b'deeoruv',
#  b'emnorsuu',
#  b'cdehmmu',
#  b'aeeemmnorst',
#  b'acgiilmnntu',
#  b"'dloors",
#  b'cemmotu',
#  b'Taehms',
#  b'Uaiopt',
#  b'ffgilnru',
#  b'Bekoor',
#  b"'aafimnnoorrsstt",
#  b'ceelnorssu',
#  b'Cadoorv',
#  b"'Kaaiss",
#  b'aeflostt',
#  b"'deeenpsss",
#  b"'cdinosstu",
#  b'aekmpu',
#  b'affgirssstu',
#  b"'Iinrsv",
#  b'aeegilmnrt',
#  b'Saabbht',
#  b"'ccceennorrsu",
#  b'eeeprsssx',
#  b'Neo',
#  b'ajsy',
#  b'beegimnostt',
#  b"'aillsv",
#  b'alosttu',
#  b'beeginnrs',
#  b'ghilnossst',
#  b'almnpsu',
#  b'ceiorrtu',
#  b'egiilnnv',
#  b"'adeilns",
#  b'achimnor',
#  b'morrsu',
#  b"'Saersssuu",
#  b'deioosstw',
#  b'abeerrty',
#  b'acdeinnoss',
#  b'cdeinostu',
#  b'beeelmrss',
#  b"'acinosss",
#  b'afilltuy',
#  b'aefimnnoott',
#  b'bdegghmuu',
#  b"'Celos",
#  b'aggiiinnort',
#  b"'aelsw",
#  b'aaeklmrw',
#  b'abhiltu',
#  b'Aacehnrr',
#  b'bdelorsw',
#  b'aaddeelrttu',
#  b"'chrssu",
#  b'bgilnnotu',
#  b'Aailv',
#  b'deiinosv',
#  b'fiinnossu',
#  b'bceehirstu',
#  b'aabdgiinrstz',
#  b"'aaosstwwy",
#  b'aeiilnrt',
#  b'depttu',
#  b'ddeelsu',
#  b'aistv',
#  b"'aaprsst",
#  b"'Maaeinnrs",
#  b'aeemnnprtt',
#  b'Aagintu',
#  b'allotw',
#  b'aaemrtu',
#  b'aehhisvy',
#  b"'ehlosw",
#  b'abcceeginnru',
#  b'aceiinorrstw',
#  b'aehhimmsss',
#  b'cdeeiilsvy',
#  b'aemrrry',
#  b'eefoprsss',
#  b'aeeillrtvy',
#  b'akqru',
#  b'hillooprw',
#  b"'cegorssu",
#  b'cdemmooors',
#  b'bdgiinrstu',
#  b"'aceeinrssst",
#  b"'cehnnorstu",
#  b'aesttt',
#  b'dinstu',
#  b'dimoorrty',
#  b'aabbehilnoprt',
#  b'ellotx',
#  b"'efiklnsu",
#  b"'deostux",
#  b'aefilnooprsss',
#  b'Labdmor',
#  b"'acehinnrsssu",
#  b'deiopsssss',
#  b"'aeeilrrstv",
#  b'aacilnrv',
#  b'ilops',
#  b'aioss',
#  b'eghostt',
#  b'loow',
#  b"'afirrs",
#  b'cceinnoorrsttu',
#  b'Np',
#  b'Fiiilnop',
#  b'aghlnostu',
#  b"'Haemnrs",
#  b'abcceemnnru',
#  b'Hsu',
#  b'addefginru',
#  b'aaemnprtt',
#  b'Senv',
#  b"'hinst",
#  b'Iadnr',
#  b'Beemnr',
#  b'acepss',
#  b'ablmnruu',
#  b'ceiopt',
#  b"'Lcilnnos",
#  b'eghlnooty',
#  b"'aegrstt",
#  b'ccenoorst',
#  b"'hmmoorssu",
#  b'aaaceenppr',
#  b'aacilnortvy',
#  b"'aaemnnrsstv",
#  b"'Maelnsu",
#  b"'egrrssuy",
#  b'ceeekrrssu',
#  b"'Haerstu",
#  b'aabdlnssst',
#  b'deeelrrsvy',
#  b'aabccdeikkp',
#  b'ackty',
#  b'Taess',
#  b'adisv',
#  b'abgilntt',
#  b'Gaerrtt',
#  b"'ceeeffhoossu",
#  b'Taint',
#  b'aacchilllossty',
#  b'Geen',
#  b"'celoost",
#  b"'Taejnos",
#  b'bdeeils',
#  b'eeehlmpst',
#  b'adlpruwy',
#  b'Ianosw',
#  b"'aceiinnoorsssttv",
#  b"'aiiinnnosstu",
#  b'deeeemrr',
#  b'aaghhins',
#  b'cceinnnoost',
#  b'efhirsy',
#  b"'aceginprsy",
#  b'aaelpp',
#  b'acdiort',
#  b"'aeeefhrrst",
#  b'ceeeenrrv',
#  b'Baberr',
#  b'adeehrtw',
#  b"'aachnss",
#  b'aeimrs',
#  b'Rany',
#  b'cdeeefitv',
#  b"'bbeilnrs",
#  b'estz',
#  b'doss',
#  b'filoooprst',
#  b"'Jaaacimns",
#  b"'eensttx",
#  b"'Caeeghnnops",
#  b'aahkllmr',
#  b'acceiiilnnoorst',
#  b'aaefinsttu',
#  b"'ghilst",
#  b'efrrsy',
#  b'aabcerst',
#  b"'aaimprsst",
#  b"'aeorsssss",
#  b'Kaimmmnouz',
#  b"'Tenorsy",
#  b"'adeggiilnnrsss",
#  b"'eeenoorsssttt",
#  b'Dot',
#  b"'Wbeersst",
#  b'einoprst',
#  b'Faeemnorrsy',
#  b'aacnst',
#  b'adegglr',
#  b'Acehir',
#  b'aeeilmmt',
#  b'addelss',
#  b'deeenrrt',
#  b"'Raabistuy",
#  b"'eginsv",
#  b'abcelmr',
#  b'beelnossu',
#  b'aeiimnnooprst',
#  b'ehiv',
#  b'Tloosty',
#  b"'ersst",
#  b'abeilvv',
#  b'behorrst',
#  b'Wdooorw',
#  b'Leenrr',
#  b'addegilnr',
#  b'aegilpps',
#  b"'ffmsu",
#  b"'Wegilrsy",
#  b"'Dceikrrs",
#  b'Paghinoostttt',
#  b'acdeetx',
#  b"'Ncehiinrs",
#  b'eglnnptuy',
#  b'bdginortu',
#  b'adrssw',
#  b'forrsuw',
#  b'fflosu\xc3\xa9',
#  b'Weeehlr',
#  b"'Jbeeelsz",
#  b"'cgiiilmnoorsst",
#  b'elloswy',
#  b"'cceklos",
#  b'ehw',
#  b'abcdehkmpu',
#  b'aefooprrtw',
#  b'psu',
#  b"'Bennssu",
#  b'ddehrsu',
#  b'deellory',
#  b"'Baadeghilnss",
#  b"'cceeeellnsx",
#  b"'cceeeinrst",
#  b"'Scknoostt",
#  b'Hadinr',
#  b"'accchloopssstuy",
#  b'Taceenrr',
#  b"'aaloprrsty",
#  b'eimnnorst',
#  b'eeghlnnt',
#  b'abbilot',
#  b'hhoopprss',
#  b'ddegiinr',
#  b'aceinnsst',
#  b"'oorrssw",
#  b'eegiilnrv',
#  b'acenrttu',
#  b'aacdlpr',
#  b'Cehir',
#  b"'aadefilmnnssttu",
#  b'adells',
#  b"'Waeist",
#  b'aabeelprs',
#  b"'Aacdklnsu",
#  b"'aaddiiilnopst",
#  b'ceeilnot',
#  b'Caaaabclnp',
#  b'cghiloopssty',
#  b'deijnx',
#  b'Aabegnruz',
#  b"'beeeilnnorsv",
#  b'adeeeggrst',
#  b"'allqssu",
#  b"'moopsssu",
#  b"'eginrssv",
#  b'eggilrrw',
#  b'aehimnors',
#  b"'ehlnssssu",
#  b"'aegmos",
#  b'agillor',
#  b'adeilnnru',
#  b'ahhkssy',
#  b'abhmsu',
#  b'denss',
#  b'Sadilrz',
#  b'ekrstuy',
#  b"'aabceelnrst",
#  b'fir',
#  b'aeegiiilllmtty',
#  b'eeiloprtx',
#  b'ceflnoorrsw',
#  b'cgiillossty',
#  b'eeimnrs',
#  b"'aeglpprs",
#  b'diloss',
#  b"'Mhmnoostu",
#  b'Tim',
#  b"'eeelnopsv",
#  b'acginorsu',
#  b'eimnoprtu',
#  b'efiinsu',
#  b"'Neehinsv",
#  b'dddeloo',
#  b'Sdehoorw',
#  b'acceeinoprsttv',
#  b'eilnpp',
#  b"'aehnrst",
#  b'aeeflmorrtu',
#  b'aghilmty',
#  b"'aafillnrs",
#  b'aabcegilnnorv',
#  b'Wciinnoss',
#  b'eefrstt',
#  b"'bdeeprrsu",
#  b'bfinorrsst',
#  b"'Maopstu",
#  b'ahtw',
#  b'Naadejmn',
#  b"'cillmooqsuu",
#  b'aceghhnorst',
#  b'Paeilnnossy',
#  b'Ziimnoss',
#  b'aceinnorrsst',
#  b'egmnoooss',
#  b'ehimnnooss',
#  b"'eiklnstw",
#  b"'abdhioprss",
#  b'bdeemnorsu',
#  b'eegrst',
#  b'cceeeinrt',
#  b"'ceinnorstu",
#  b'eerssst',
#  b'Baaeeinrs',
#  b"'Aelpps",
#  b'aafimnnoorrstt',
#  b'aaccdei',
#  b'ceiinosv',
#  b'ceiinoprsssstu',
#  b'efgilnrttu',
#  b'eghisttt',
#  b"'eehrstt",
#  b'eimnostty',
#  b'egilmns',
#  b'abfhlsu',
#  b"'aceimnorst",
#  b'acehilmoprstt',
#  b"'Celst",
#  b'aimsw',
#  b'abfllosst',
#  b'Babru',
#  b'aacdirty',
#  b'dgiinoprst',
#  b'aaceghnor',
#  b'Weells',
#  b'aensv',
#  b'Baadllr',
#  b"'Bestty",
#  b'adfginorrsu',
#  b"'dooswy",
#  b'acegnnpry',
#  b'cehss',
#  b"'acikpsx",
#  b'ceffiorsu',
#  b'adeehknr',
#  b'aceeiinrstt',
#  b"'aceiilmosv",
#  b'dghilnos',
#  b"'Acdilnors",
#  b"'adeeisstv",
#  b'Iaailnst',
#  b'abersss',
#  b"'Baccccioos",
#  b'acryz',
#  b"'aeggs",
#  b"'abbegrsu",
#  b"'Gaainsw",
#  b"'acdeimnsty",
#  b'bcceilru',
#  b"'Dacerstu",
#  b'eflorw',
#  b'bdejlmu',
#  b'aaceghillprr',
#  b"'acdehlnprstu",
#  b'aclps',
#  b'aadeiinopssst',
#  b"'chssssu",
#  b'Caaadenst',
#  b"'Pceisss",
#  b'aceiilnrstu',
#  b'deehnowy',
#  b'dfhiloorsy',
#  b"'adeginors",
#  b'Maaikrsu',
#  b'aegmnos',
#  b'ddeenw',
#  b'cellnoorrst',
#  b'cosw',
#  b'Reehrtu',
#  b'aegirssst',
#  b'acess',
#  b'Sadn',
#  b'eiqtuy',
#  b'deenrrrsu',
#  b'aaddeimnr',
#  b'dflo',
#  b"'eeorrrsst",
#  b'acceilmmor',
#  b"'Cciopst",
#  b"'ccceeeenrssx",
#  b"'chhlllooprsy",
#  b'ent',
#  b'aaccinostu',
#  b'deinsttuw',
#  b'eehlmoosw',
#  b'bdeeerr',
#  b'adfinnootu',
#  b'aaccdeeghilooprrrt',
#  b'accehs',
#  b"'Raissv",
#  b'adirwz',
#  b'bchnu',
#  b"'abessu",
#  b'deeilorsv',
#  b'abeffilny',
#  b'abeehrt',
#  b'aabdehhirrsst',
#  b'akklrssy',
#  b"'eglns",
#  b'fghiins',
#  b'aehinqssuv',
#  b'ijkllosy',
#  b'Neehinv',
#  b'aeggiimnnprt',
#  b'aeirrrt',
#  b'achmss',
#  b'abeghhkorrstu',
#  b'eehlopss',
#  b"'Remoors",
#  b'Baadeghilns',
#  b'adeeeinst',
#  b'Semoruy',
#  b"'demmos",
#  b"'Jeeilsttu",
#  b"'Ealss",
#  b"'cdeeeisttv",
#  b'bceeiilms',
#  b'abekoory',
#  b"'cdeeiprssst",
#  b'beeiilmnrt',
#  b'Ademnnsu',
#  b'deilmps',
#  b"'Abenrs",
#  b"'iops",
#  b'Eaeirrt',
#  b'deiprstz',
#  b"'Maeijs",
#  b"'aaceinnorstt",
#  b'adeeiimnoprtt',
#  b'alopr',
#  b'eikps',
#  b'Baeefinor',
#  b"'Baahkrsu",
#  b'Aaacdir',
#  b"'bdelostu",
#  b'ehhnoors',
#  b"'cnoopsu",
#  b'eeilmnsu',
#  b"'abfls",
#  b'abss',
#  b'Veelz',
#  b"'eelmopsy",
#  b'acilmsu',
#  b'aeinsttw',
#  b'deeoprstt',
#  b'aeeioprtv',
#  b'eeilnorsvw',
#  b'ahilyz',
#  b'Bdeehtuux',
#  b'Maahnort',
#  b'aabcikllm',
#  b'deeeiprstx',
#  b'aceillmnsy',
#  b"'Vailms",
#  b'aefiilmprs',
#  b'delorstuy',
#  b"'bnoss",
#  b"'iknrs",
#  b'deey',
#  b'achiirrtt',
#  b'bceeimnors',
#  b'Eciprsuu',
#  b'abeeswx',
#  b"'ainstw",
#  b"'Jaaeenpss",
#  b'acehilmmos',
#  b"'aadehlnrst",
#  b'ceiklnpssu',
#  b"'ccejnnorstuu",
#  b'acdlnors',
#  b"'acdeiilnnost",
#  b'adepw',
#  b'beelmm',
#  b'aegirw',
#  b'aacdgillmoty',
#  b"'ccdeefiinsy",
#  b'deefiilnnrss',
#  b"'aemrsssu",
#  b'aabdellst',
#  b'acehnnst',
#  b"'deeennrssst",
#  b'abeefnrrrstu',
#  b"'Gacchrssu",
#  b'ccelrsuuy',
#  b'Oadlnor',
#  b'aachimnor',
#  b"'Paabceimnrrs",
#  b'deeiinrssstt',
#  b'deffiiort',
#  b'dehloorsv',
#  b'Tdennosw',
#  b'ddginpu',
#  b"'cdeimnnost",
#  b'aegloorstuuy',
#  b'bcceimnnuy',
#  b'mnorstuu',
#  b"'giinsstt",
#  b'cceeilrt',
#  b"'Haabilnns",
#  b'aaiillnnostt',
#  b"'aaderrssvy",
#  b'Meeelmnop',
#  b'aluuv',
#  b"'Lennsy",
#  b'adefinoorrs',
#  b'aceeglmnoort',
#  b'cdeehilnprst',
#  b'deeoprw',
#  b'cddeens',
#  b"'Cehrrsy",
#  b"'aekossttu",
#  b"'adiorstu",
#  b'aabcdiinost',
#  b'ceersstu',
#  b'deginnopux',
#  b'aceimnrsst',
#  b'acchillnnooo',
#  b'aeefhinprt',
#  b'abccdeehkorr',
#  b'dfggiiinny',
#  b'ahlmnoor',
#  b'ggiiinnt',
#  b'Hakn',
#  b'gpu',
#  b"'abeerstt",
#  b'adhinsttw',
#  b'Haeill',
#  b'deehilrsv',
#  b'Gaahinn',
#  b"'Ailnsv",
#  b'Aaamrs',
#  b"'accimmnnostu",
#  b'Sadeensu',
#  b'eimoorst',
#  b'celrru',
#  b'eimmoprsu',
#  b"'Labemrst",
#  b'aaimnrs',
#  b'eefgiln',
#  b'Shoo',
#  b'aehiimnstu',
#  b'Mabeghr',
#  b'addefrt',
#  b"'mnoos",
#  b'cdeensst',
#  b"'aeersty",
#  b"'aaclnsu",
#  b'acdekkmopr',
#  b"'aeglmnorsw",
#  b"'aeoprrssstw",
#  b'dgiilnnps',
#  b'Heloy',
#  b'aelrstuv',
#  b'Apr',
#  b'Tbllmruu',
#  b'aeffimrrs',
#  b'Bertt',
#  b'eegirrst',
#  b"'acpsstu",
#  b"'abiils",
#  b'ceeiprss',
#  b'diostv',
#  b'aelrrstw',
#  b'ccklsu',
#  b"'acdhhinooprsy",
#  b'cdeeiklnort',
#  b"'iinnorsstu",
#  b'aeelrt',
#  b'Taadhiiknstz',
#  b'aehinppss',
#  b"'achors",
#  b'bbceeillrsuy',
#  b'defillnu',
#  b'eeillnosstv',
#  b'deiimmnuz',
#  b'aeglrru',
#  b'ceeimnoorsu',
#  b'cceorru',
#  b'acdefgin',
#  b'eegilnnuy',
#  b'degghrsu',
#  b'eflloruv',
#  b'deilmp',
#  b'adiinnoorst',
#  b'abcdeor',
#  b'egglmssu',
#  b'ioopprrstu',
#  b'ablprtuy',
#  b'aeghnosx',
#  b'Fdio',
#  b'akptu',
#  b'blo',
#  b'ddelnorsu',
#  b'Meennn',
#  b"'aegimrst",
#  b'bddeisu',
#  b"'adeginrs",
#  b'deeirvv',
#  b"'Daegss",
#  b'aceenpttx',
#  b'morstu',
#  b"'aehrs",
#  b'eghstu',
#  b'eeinqrsu',
#  b"'akklrssy",
#  b'ceeefnorr',
#  b'aehlnopstu',
#  b'Janno',
#  b'Maaiossst',
#  b"'eenrsv",
#  b'egiinrsstt',
#  b'adeginrtv',
#  b"'aairs",
#  b"'Dbehsu",
#  b'aabeehilpstz',
#  b'adeeeirrtt',
#  b"'aabchklss",
#  b"'adeeiopstv",
#  b"'Uaklnossvy",
#  b"'eilnoprssst",
#  b'aeeorssv',
#  b'deenorrtuv',
#  b'eikrsstt',
#  b'ceeeginrs',
#  b'aehimsss',
#  b"'efimnorsstu",
#  b'adfginrt',
#  b'eginvx',
#  b'adeelnrt',
#  b'aainnrstuy',
#  b"'adddoos",
#  b'aeilmnns',
#  b'efmnost',
#  b'bceklnuu',
#  b'ceeehqrux',
#  b'aeeflrss',
#  b'adeekmrrss',
#  b'aadgillo',
#  b'Taejno',
#  b'Maaailnsy',
#  b'cehlmsu',
#  b'Naacghnn',
#  b'aefiklr',
#  b'aaekprrt',
#  b'eginstt',
#  b'cegijnoprt',
#  b"'abbehorst",
#  b'adeghhilst',
#  b'eeinnqssuu',
#  b'enrw',
#  b'ddeeimnp',
#  b'aeeeinnpsssvx',
#  b"'Aaannnprsu",
#  b'ceeeimrrz',
#  b"'bcdgiikmnors",
#  b'Eeffil',
#  b'Saadlnov',
#  b'afgginor',
#  b"'Aacinns",
#  b'adfrty',
#  b'Taagkouw',
#  b"'deelrsw",
#  b'Bci',
#  b"'adeglmoorsty",
#  b'aeiilmnnrsstttu',
#  b'aiiilnt',
#  b'acenrst',
#  b'abessu',
#  b'ahy',
#  b"'Kaalsy",
#  b"'Caaailnst",
#  b'ccehilnors',
#  b"'acders",
#  b'aceehnp',
#  b'egilnsst',
#  b'cehilnopst',
#  b'aadeioppprrt',
#  b"'ceemnorsw",
#  b"'aciiinoqsstu",
#  b'adeeimrt',
#  b"'befinors",
#  b'aceehpr',
#  b'Daciimnnos',
#  b'deggiinns',
#  b"'ceehiopssw",
#  b'aeioprrrttu',
#  b'cdeeeelnnprs',
#  b'hnopy',
#  b"'Naors",
#  b'ceiloptu',
#  b'Hdiimnsu',
#  b'adhilry',
#  b'addelrsst',
#  b'acgilorsuy',
#  b'accmmoorss',
#  b'deiirvv',
#  b'acjkkssy',
#  b"'acns",
#  b"'aeeeinnssstttv",
#  b'deforst',
#  b'Uahir',
#  b"'elorsv",
#  b'ceiklnstuu',
#  b'opttuu',
#  b"'ehikrs",
#  b'aeehinrsst',
#  b"'aabegggs",
#  b"'eilprs",
#  b'aaachilprrt',
#  b'dginootu',
#  b"'bmsu",
#  b'Maimrz',
#  b'eehinooprss',
#  b'ddos',
#  b"'elmosty",
#  b'aaaaegnrtvxz',
#  b'deinrw',
#  b'ffmu',
#  b'Kaanz',
#  b"'Peis",
#  b'abeiklsy',
#  b"'aehrssw",
#  b'enovw',
#  b'eilnoorstuv',
#  b'aaccllorstu',
#  b'cdddefnoruw',
#  b'eeffrrsu',
#  b'adeenprr',
#  b'Bbeil',
#  b'abceiors',
#  b"'aabcrsstt",
#  b'cehimmru',
#  b'accdeeln',
#  b'aacginrstt',
#  b"'eiooooprsssst",
#  b'cdeeiltxy',
#  b'adeellmmrt',
#  b"'Beloos",
#  b'abeehirrt',
#  b'Jan',
#  b'aaefirr',
#  b"'aclosv",
#  b"'Geilorst",
#  b"'Haennss",
#  b'bbehlo',
#  b'eh',
#  b'eikmrstu',
#  b'aabciilpty',
#  b'Aainnorsz',
#  b'Jaenno',
#  b"'ceiinossssuv",
#  b'aagghiijmnst',
#  b'cefnor',
#  b'aeggnrst',
#  b'aaalmnoprr',
#  b"'Jacknoss",
#  b'Aadn',
#  b'cehoruv',
#  b'delopstu',
#  b"'aacdeiiiilmnnorstz",
#  b'beeeirrsw',
#  b'elor',
#  b'Taehnnrsu\xc3\xa4',
#  b'Taehiklnoss\xc3\xad',
#  b'aabcekqrrstu',
#  b'bbehinnossss',
#  b'cdeoprru',
#  b'aaaeimnqru',
#  b"'Alloops",
#  b'degilnos',
#  b'ghinosv',
#  b'acegiinrssttu',
#  b"'adinsty",
#  b'eilqruu',
#  b"'ahillnst",
#  b'cegghir',
#  b'beeqsstu',
#  b'eeeklnsss',
#  b'bdeeinorstx',
#  b'cdeiirtu',
#  b'aceioprrsu',
#  b"'Raaabnsst",
#  b'dddeei',
#  b'aabdekorsst',
#  b'addeilpsy',
#  b'aagiimnopprtx',
#  b"'ellw",
#  b'aaabiiiilmnntty',
#  b'acddeffhnu',
#  b"'Ladenrrs",
#  b'ceiikqu',
#  b'aaabcdiit',
#  b"'abdeiiilnostt",
#  b'eenprst',
#  b'adlmno',
#  b'eelnvy',
#  b'aceglmnry',
#  b"'eeennstt",
#  b'aeeginsv',
#  b"'beiklnsssu",
#  b'eilnpu',
#  b"'astx",
#  b"'Aans",
#  b'klsu',
#  b"'accenprstuuu",
#  b"'agiilnors",
#  b'EFdex',
#  b'aeeeimnprtt',
#  b'Gdelno',
#  b'adelopptu',
#  b'Aaderuvy',
#  b'Wegiinnp',
#  b'cggiinnos',
#  b"'aegillpss",
#  b'giknop',
#  b'aceeghhooprrrs',
#  b'cdeiinopt',
#  b'chopssy',
#  b'aklop',
#  b'deiprsy',
#  b"'abdhnssu",
#  b'eknoorstw',
#  b'ehhilllsy',
#  b'cghinnpu',
#  b'adginnor',
#  b'eiiprsv',
#  b'aeeemprst',
#  b'adgimmost',
#  b'aceiilmosv',
#  b'Hadiinnstu',
#  b"'Pacehiknps",
#  b'cceinprt',
#  b'aepsttu',
#  b'bdeemnortuu',
#  b'eeillmrs',
#  b"'degjsu",
#  b"'demnors",
#  b"'Iehmopst",
#  b'inpss',
#  b"'aeoprsstt",
#  b'adeghs',
#  b"'aaccdeeghilooprrrst",
#  b'aeggrst',
#  b'Idiors',
#  b'bbloy',
#  b"'aegillsty",
#  b'aailorrst',
#  b'ffghinoors',
#  b'deilnuwy',
#  b'aciimstv',
#  b"'ehirss",
#  b'ddeot',
#  b'aegghinnorv',
#  b"'Dadeefgilnrs",
#  b'aeeikmnors',
#  b'ceeeprsstu',
#  b"'ceeimnst",
#  ...]

# %%
r.lrange(b'opst', 0, -1)
# Out:
# [b'tops', b'stop', b'spot', b'pots', b'post', b'opts']

# %%
def print_anagram_sets_redis(r):
    """Prints the anagram sets in d.

    d: map from words to list of their anagrams
    """
    for key in r.keys():
        v = r.lrange(key, 0, -1)
        if len(v) > 1:
            print(len(v), v)

# %%
print_anagram_sets_redis(r)
# Out:
# 2 [b'catches', b'cachets']
# 2 [b"Kristen's", b"Kirsten's"]
# 2 [b'gardened', b'deranged']
# 2 [b'risk', b'irks']
# 2 [b'sounder', b'resound']
# 2 [b'lurch', b'churl']
# 3 [b'recipes', b'precise', b'pierces']
# 2 [b'droopiest', b'depositor']
# 2 [b'Brooke', b'Booker']
# 2 [b'Noe', b'Neo']
# 2 [b'suctioned', b'seduction']
# 2 [b"cassino's", b"caisson's"]
# 2 [b"Cole's", b"Cleo's"]
# 2 [b"weal's", b"wale's"]
# 2 [b'proteins', b'pointers']
# 3 [b'ups', b'sup', b'pus']
# 2 [b'instances', b'incessant']
# 2 [b'what', b'thaw']
# 2 [b'greets', b'egrets']
# 2 [b'vanes', b'naves']
# 2 [b'harkened', b'hankered']
# 3 [b'scalp', b'clasp', b'claps']
# 2 [b'scow', b'cows']
# 2 [b'ten', b'net']
# 2 [b"Arneb's", b"Abner's"]
# 2 [b'spike', b'pikes']
# 2 [b'preexisted', b'expediters']
# 2 [b"snob's", b"bos'ns"]
# 2 [b"Lynne's", b"Lenny's"]
# 2 [b'fleeing', b'feeling']
# 2 [b"moon's", b"mono's"]
# 2 [b'limped', b'dimple']
# 2 [b"rhea's", b"hare's"]
# 2 [b'testing', b'setting']
# 4 [b'trances', b'scanter', b'recants', b'canters']
# 2 [b"cedar's", b"cadre's"]
# 2 [b'frosted', b'defrost']
# 2 [b'heartiness', b'earthiness']
# 2 [b"washer's", b"hawser's"]
# 2 [b'he', b'eh']
# 2 [b'role', b'lore']
# 2 [b'producer', b'procured']
# 3 [b'serpent', b'repents', b'present']
# 2 [b'lupine', b'lineup']
# 2 [b'spins', b'snips']
# 2 [b'writhes', b'withers']
# 2 [b'scalloping', b'collapsing']
# 2 [b'signally', b'sallying']
# 2 [b"raga's", b"agar's"]
# 2 [b"char's", b"arch's"]
# 2 [b'maim', b'imam']
# 2 [b'hogs', b'gosh']
# 2 [b'toilers', b'loiters']
# 2 [b'deacon', b'canoed']
# 3 [b'traipses', b'raspiest', b'pastries']
# 2 [b"plum's", b"lump's"]
# 2 [b'slim', b'mils']
# 2 [b'hangings', b'gnashing']
# 2 [b'routes', b'ouster']
# 2 [b'atomizer', b'amortize']
# 2 [b'timezone', b'monetize']
# 2 [b'toque', b'quote']
# 3 [b'rouges', b'rogues', b'grouse']
# 2 [b'teasing', b'seating']
# 2 [b'car', b'arc']
# 2 [b'Kline', b'Klein']
# 2 [b'relation', b'oriental']
# 3 [b'spirea', b'praise', b'aspire']
# 2 [b'threat', b'hatter']
# 2 [b"defoliant's", b"deflation's"]
# 2 [b'sourest', b'ousters']
# 2 [b'outlay', b'layout']
# 2 [b'toaster', b'rotates']
# 2 [b'coeds', b'codes']
# 2 [b'worsen', b'owners']
# 2 [b'regiment', b'metering']
# 3 [b'vaster', b'starve', b'averts']
# 4 [b'soli', b'soil', b'silo', b'oils']
# 2 [b'urges', b'surge']
# 2 [b'rectifies', b'certifies']
# 4 [b'tabs', b'stab', b'bats', b'bast']
# 2 [b'grannies', b'earnings']
# 2 [b'scares', b'caress']
# 2 [b'poignancy', b'canopying']
# 2 [b'Aries', b'Aires']
# 2 [b"tutor's", b"trout's"]
# 2 [b'slick', b'licks']
# 2 [b'vector', b'covert']
# 3 [b'binges', b'beings', b'begins']
# 2 [b'sterna', b'astern']
# 2 [b'curries', b'cruiser']
# 2 [b'remark', b'marker']
# 2 [b'takeovers', b'overtakes']
# 2 [b'saunter', b'natures']
# 2 [b"vane's", b"nave's"]
# 2 [b'torte', b'otter']
# 2 [b"wand's", b"dawn's"]
# 2 [b'petards', b'departs']
# 2 [b'slivers', b'silvers']
# 4 [b'tastier', b'attires', b'artiste', b'artiest']
# 2 [b'founds', b'fondus']
# 2 [b'sharp', b'harps']
# 2 [b'kneeing', b'keening']
# 2 [b'proselyte', b'polyester']
# 2 [b'hairsbreadth', b'hairbreadths']
# 2 [b'diabetes', b'beadiest']
# 2 [b'tamest', b'mattes']
# 2 [b'autocrat', b'actuator']
# 2 [b'wined', b'widen']
# 2 [b'slathering', b'earthlings']
# 2 [b'retools', b'looters']
# 2 [b"Marina's", b"Marian's"]
# 2 [b'pediatric', b'patricide']
# 2 [b'Troy', b'Tory']
# 2 [b'relishing', b'hirelings']
# 2 [b"screen's", b"censer's"]
# 2 [b'debit', b'bidet']
# 2 [b'trial', b'trail']
# 2 [b'slapped', b'dapples']
# 2 [b'Tyre', b'Trey']
# 2 [b'scars', b'crass']
# 2 [b"Mia's", b"Mai's"]
# 2 [b'refills', b'fillers']
# 2 [b"melanin's", b"lineman's"]
# 2 [b'under', b'nuder']
# 2 [b'dangle', b'angled']
# 2 [b"dub's", b"bud's"]
# 2 [b"sooth's", b"shoot's"]
# 2 [b'yap', b'pay']
# 2 [b'defoliant', b'deflation']
# 2 [b'ipecac', b'icecap']
# 2 [b"indent's", b"dentin's"]
# 2 [b'scull', b'culls']
# 2 [b'scowling', b'cowlings']
# 2 [b'split', b'spilt']
# 2 [b'tsarinas', b'artisans']
# 2 [b'preserve', b'perverse']
# 2 [b'cleric', b'circle']
# 2 [b"sidebar's", b"seabird's"]
# 2 [b'coagulating', b'cataloguing']
# 3 [b'wrestle', b'welters', b'swelter']
# 2 [b'range', b'anger']
# 2 [b'tilts', b'stilt']
# 2 [b"Lorene's", b"Lenore's"]
# 2 [b'ruining', b'inuring']
# 2 [b'toiler', b'loiter']
# 2 [b'gutsy', b'gusty']
# 3 [b'send', b'ends', b'dens']
# 2 [b'signal', b'aligns']
# 2 [b"Elma's", b"Elam's"]
# 2 [b'scampies', b'escapism']
# 2 [b"bran's", b"barn's"]
# 2 [b'shrived', b'dervish']
# 4 [b'tacos', b'coats', b'coast', b'ascot']
# 2 [b'tonics', b'tocsin']
# 2 [b'tool', b'loot']
# 2 [b"ti's", b"it's"]
# 2 [b'weans', b'wanes']
# 2 [b'calibrate', b'bacterial']
# 2 [b'pique', b'equip']
# 2 [b"shoe's", b"hose's"]
# 2 [b'cretins', b'cistern']
# 2 [b'pulses', b'pluses']
# 2 [b"Bronte's", b"Breton's"]
# 2 [b"grits's", b"grist's"]
# 4 [b'spas', b'saps', b'pass', b'asps']
# 3 [b'searing', b'regains', b'erasing']
# 2 [b'trumpets', b'strumpet']
# 2 [b'medals', b'damsel']
# 2 [b'slides', b'sidles']
# 3 [b'rental', b'learnt', b'antler']
# 2 [b'decanted', b'decadent']
# 2 [b'teasel', b'elates']
# 2 [b'sensing', b'ensigns']
# 3 [b'breaks', b'brakes', b'bakers']
# 2 [b'boggling', b'blogging']
# 2 [b'medication', b'decimation']
# 2 [b'lets', b'lest']
# 2 [b'Martina', b'Martian']
# 2 [b'shearer', b'hearers']
# 2 [b"lineament's", b"alinement's"]
# 2 [b'braking', b'barking']
# 2 [b"reed's", b"deer's"]
# 2 [b'coasters', b'coarsest']
# 2 [b'valences', b'enclaves']
# 2 [b'greed', b'edger']
# 4 [b'tinsels', b'silents', b'listens', b'enlists']
# 2 [b'unhorsing', b'onrushing']
# 2 [b"charisma's", b"archaism's"]
# 3 [b'slope', b'poles', b'lopes']
# 2 [b"minute's", b"minuet's"]
# 2 [b'shaping', b'phasing']
# 2 [b"daub's", b"baud's"]
# 2 [b'parboil', b'bipolar']
# 2 [b"steel's", b"sleet's"]
# 3 [b'rafts', b'frats', b'farts']
# 4 [b'seducer', b'secured', b'rescued', b'reduces']
# 2 [b'crap', b'carp']
# 2 [b'harbored', b'abhorred']
# 2 [b'hays', b'ashy']
# 2 [b'ramp', b'pram']
# 2 [b'Crimean', b'Carmine']
# 2 [b'studs', b'dusts']
# 2 [b'scolded', b'coddles']
# 2 [b'minute', b'minuet']
# 2 [b'ogled', b'lodge']
# 3 [b'rebate', b'berate', b'beater']
# 2 [b"zeal's", b"laze's"]
# 2 [b'rawness', b'answers']
# 2 [b"stapler's", b"plaster's"]
# 2 [b'coeval', b'alcove']
# 2 [b'smarten', b'martens']
# 2 [b'represent', b'presenter']
# 2 [b'toga', b'goat']
# 2 [b'tram', b'mart']
# 2 [b"reprint's", b"printer's"]
# 4 [b'rubies', b'busier', b'buries', b'bruise']
# 2 [b'infielders', b'friendlies']
# 2 [b"reactor's", b"creator's"]
# 2 [b'dialects', b'citadels']
# 2 [b'leader', b'dealer']
# 2 [b'thing', b'night']
# 2 [b'roman', b'manor']
# 3 [b'stained', b'instead', b'detains']
# 2 [b'sledge', b'ledges']
# 2 [b'general', b'enlarge']
# 2 [b'tweeds', b'stewed']
# 4 [b'regal', b'large', b'lager', b'glare']
# 2 [b'tutor', b'trout']
# 2 [b'drive', b'diver']
# 2 [b'slier', b'riles']
# 3 [b'mead', b'made', b'dame']
# 2 [b"rapine's", b"panier's"]
# 2 [b'sack', b'cask']
# 2 [b'teazle', b'teazel']
# 4 [b'slide', b'sidle', b'idles', b'delis']
# 2 [b'Mira', b'Mari']
# 3 [b'Dena', b'Dean', b'Dane']
# 2 [b'respond', b'ponders']
# 5 [b'traps', b'tarps', b'strap', b'sprat', b'parts']
# 2 [b"Brooke's", b"Booker's"]
# 3 [b'stricter', b'restrict', b'critters']
# 3 [b'ogres', b'gorse', b'gores']
# 2 [b'pressed', b'depress']
# 2 [b'topic', b'optic']
# 2 [b"topside's", b"deposit's"]
# 2 [b'fuel', b'flue']
# 2 [b'reinvest', b'nerviest']
# 2 [b"span's", b"snap's"]
# 2 [b'searcher', b'research']
# 2 [b'brazier', b'bizarre']
# 2 [b'limited', b'delimit']
# 2 [b'repulsed', b'preludes']
# 2 [b'rectifiable', b'certifiable']
# 2 [b"carton's", b"cantor's"]
# 2 [b'shrove', b'hovers']
# 2 [b'rules', b'lures']
# 3 [b'era', b'ear', b'are']
# 3 [b'pool', b'polo', b'loop']
# 2 [b'directors', b'creditors']
# 2 [b'edifies', b'deifies']
# 2 [b'one', b'eon']
# 4 [b'storied', b'steroid', b'sortied', b'editors']
# 2 [b'suitcase', b'sauciest']
# 2 [b'scarier', b'carries']
# 2 [b'silken', b'likens']
# 2 [b'reactive', b'creative']
# 2 [b'reverses', b'reserves']
# 3 [b'sing', b'sign', b'gins']
# 2 [b'Arden', b'Andre']
# 2 [b'diaries', b'dairies']
# 2 [b"lease's", b"easel's"]
# 2 [b'curtsies', b'citruses']
# 3 [b'slit', b'silt', b'list']
# 2 [b'shoring', b'horsing']
# 2 [b"sneak's", b"snake's"]
# 4 [b'stripe', b'sprite', b'ripest', b'priest']
# 2 [b"coeval's", b"alcove's"]
# 2 [b"scalp's", b"clasp's"]
# 2 [b'freest', b'fester']
# 2 [b'greens', b'genres']
# 2 [b'washer', b'hawser']
# 2 [b'fats', b'fast']
# 2 [b"shore's", b"horse's"]
# 2 [b'crinkle', b'clinker']
# 2 [b'boredom', b'bedroom']
# 2 [b'ginkgos', b'gingkos']
# 2 [b'sinning', b'innings']
# 2 [b'cots', b'cost']
# 3 [b'seats', b'sates', b'asset']
# 2 [b'revel', b'lever']
# 2 [b"room's", b"moor's"]
# 2 [b'remiss', b'misers']
# 2 [b"won's", b"now's"]
# 2 [b'reels', b'leers']
# 2 [b'browse', b'bowers']
# 2 [b'bereaving', b'beavering']
# 2 [b'trains', b'strain']
# 2 [b"potash's", b"pathos's"]
# 2 [b"taste's", b"state's"]
# 2 [b'tan', b'ant']
# 2 [b'Sybil', b'Sibyl']
# 2 [b'yards', b'drays']
# 2 [b'silence', b'license']
# 2 [b'raining', b'ingrain']
# 2 [b'truss', b'rusts']
# 2 [b"rebate's", b"beater's"]
# 2 [b'discount', b'conduits']
# 2 [b'bowls', b'blows']
# 3 [b'slab', b'labs', b'albs']
# 2 [b'things', b'nights']
# 3 [b'rifle', b'lifer', b'flier']
# 2 [b'Brian', b'Brain']
# 2 [b'juncoes', b'jounces']
# 2 [b"cation's", b"action's"]
# 2 [b'romps', b'proms']
# 2 [b'vane', b'nave']
# 2 [b'striven', b'inverts']
# 2 [b'spinets', b'insteps']
# 2 [b'sliding', b'sidling']
# 2 [b'stressed', b'desserts']
# 2 [b'libeled', b'bellied']
# 2 [b'Roger', b'Regor']
# 2 [b'madras', b'dramas']
# 2 [b'relapsed', b'pleaders']
# 2 [b'mortise', b'moister']
# 2 [b'esoteric', b'coteries']
# 3 [b'skin', b'sink', b'inks']
# 2 [b'riled', b'idler']
# 2 [b'cola', b'coal']
# 2 [b'hissed', b'dishes']
# 3 [b'heats', b'hates', b'haste']
# 2 [b'pagers', b'grapes']
# 2 [b'starter', b'restart']
# 2 [b"topic's", b"optic's"]
# 2 [b'rebuffs', b'buffers']
# 2 [b'steerage', b'eagerest']
# 4 [b'points', b'pitons', b'piston', b'pintos']
# 2 [b'scalar', b'rascal']
# 3 [b'sucrose', b'sources', b'courses']
# 2 [b'descanted', b'decadents']
# 2 [b'Rocha', b'Roach']
# 2 [b"shotgun's", b"gunshot's"]
# 2 [b'mangle', b'legman']
# 2 [b'weak', b'wake']
# 2 [b"workhouse's", b"housework's"]
# 2 [b'loco', b'cool']
# 2 [b'tasting', b'stating']
# 2 [b'conversing', b'conserving']
# 2 [b'Mimosa', b'Maoism']
# 2 [b'lubes', b'blues']
# 2 [b'relax', b'laxer']
# 2 [b'usurping', b'pursuing']
# 2 [b'generals', b'enlarges']
# 2 [b'sleep', b'peels']
# 2 [b'sardine', b'sandier']
# 2 [b"melon's", b"lemon's"]
# 2 [b'gliders', b'girdles']
# 2 [b'indigents', b'destining']
# 2 [b'cleansing', b'cleanings']
# 2 [b'urns', b'runs']
# 2 [b'umpired', b'dumpier']
# 2 [b'sideboards', b'broadsides']
# 2 [b"dialect's", b"citadel's"]
# 2 [b'horsewomen', b'homeowners']
# 2 [b"maul's", b"alum's"]
# 2 [b'timescales', b'clematises']
# 2 [b'ginkgoes', b'gingkoes']
# 2 [b'scholar', b'chorals']
# 2 [b'header', b'adhere']
# 2 [b'seraph', b'phrase']
# 2 [b'princes', b'pincers']
# 2 [b'converses', b'conserves']
# 2 [b'wade', b'awed']
# 2 [b'poxes', b'expos']
# 4 [b'trays', b'stray', b'satyr', b'artsy']
# 2 [b'infests', b'fitness']
# 2 [b"knee's", b"keen's"]
# 2 [b'strokes', b'stokers']
# 2 [b'shim', b'hims']
# 2 [b"oceanic's", b"cocaine's"]
# 2 [b"china's", b"chain's"]
# 2 [b"waste's", b"sweat's"]
# 2 [b'roweled', b'lowered']
# 2 [b'potions', b'options']
# 2 [b'gods', b'dogs']
# 2 [b'miscue', b'cesium']
# 2 [b'resistance', b'ancestries']
# 3 [b"rime's", b"mire's", b"emir's"]
# 2 [b'docile', b'coiled']
# 2 [b'sanded', b'sadden']
# 2 [b'yanks', b'snaky']
# 2 [b"trot's", b"tort's"]
# 2 [b"racing's", b"caring's"]
# 3 [b'sealer', b'resale', b'reales']
# 4 [b'singer', b'signer', b'resign', b'reigns']
# 2 [b'paternalistic', b'antiparticles']
# 2 [b'scream', b'creams']
# 2 [b"magnate's", b"magenta's"]
# 2 [b'shill', b'hills']
# 2 [b'reactions', b'creations']
# 2 [b'decant', b'canted']
# 2 [b'sexist', b'exists']
# 2 [b'itches', b'ethics']
# 2 [b"pin's", b"nip's"]
# 2 [b'scud', b'cuds']
# 2 [b'oh', b'ho']
# 2 [b"takeout's", b"outtake's"]
# 2 [b'tarts', b'start']
# 2 [b'insatiable', b'banalities']
# 2 [b'sieved', b'devise']
# 2 [b'flares', b'falser']
# 2 [b'boats', b'boast']
# 3 [b'mace', b'came', b'acme']
# 3 [b'sorriest', b'roisters', b'resistor']
# 2 [b'prating', b'parting']
# 2 [b'rupee', b'puree']
# 2 [b'orientating', b'integration']
# 3 [b'niggles', b'negligs', b'leggins']
# 3 [b'rode', b'redo', b'doer']
# 3 [b'stabled', b'blasted', b'baldest']
# 2 [b'dying', b'dingy']
# 3 [b'ringside', b'residing', b'desiring']
# 2 [b'debug', b'budge']
# 2 [b'nigger', b'ginger']
# 2 [b'slued', b'duels']
# 2 [b'escorted', b'corseted']
# 3 [b'takeouts', b'stakeout', b'outtakes']
# 2 [b"slaver's", b"salver's"]
# 2 [b"vase's", b"save's"]
# 2 [b'cessation', b'canoeists']
# 2 [b'manual', b'alumna']
# 3 [b"montage's", b"megaton's", b"magneto's"]
# 4 [b'name', b'mean', b'mane', b'amen']
# 2 [b'shook', b'hooks']
# 3 [b'stiles', b'sliest', b'islets']
# 2 [b'snorted', b'rodents']
# 3 [b'rood', b'odor', b'door']
# 3 [b'tar', b'rat', b'art']
# 2 [b'garnered', b'gardener']
# 4 [b'tables', b'stable', b'bleats', b'ablest']
# 2 [b'satanism', b'mantissa']
# 2 [b"Crater's", b"Carter's"]
# 2 [b'roasting', b'organist']
# 2 [b'steelier', b'leeriest']
# 2 [b'spark', b'parks']
# 3 [b'recasts', b'casters', b'actress']
# 2 [b"rebroadcast's", b"broadcaster's"]
# 2 [b"lea's", b"ale's"]
# 2 [b'plumed', b'lumped']
# 2 [b'near', b'earn']
# 2 [b'solitary', b'royalist']
# 2 [b'steins', b'insets']
# 2 [b'repay', b'payer']
# 3 [b'ignited', b'editing', b'dieting']
# 2 [b'laddie', b'dialed']
# 3 [b'terrace', b'retrace', b'caterer']
# 2 [b'glibness', b'blessing']
# 2 [b'relates', b'realest']
# 2 [b"angle's", b"angel's"]
# 2 [b'stages', b'sagest']
# 3 [b'sadder', b'dreads', b'adders']
# 2 [b'corneas', b'coarsen']
# 2 [b'wee', b'ewe']
# 2 [b'prefect', b'perfect']
# 2 [b'rebuilds', b'builders']
# 2 [b'spawn', b'pawns']
# 2 [b'leafing', b'finagle']
# 2 [b"marcher's", b"charmer's"]
# 2 [b'ruffed', b'duffer']
# 3 [b"warder's", b"reward's", b"drawer's"]
# 2 [b'racking', b'arcking']
# 2 [b"reform's", b"former's"]
# 2 [b'nailing', b'alining']
# 2 [b'words', b'sword']
# 2 [b'gable', b'bagel']
# 2 [b'spans', b'snaps']
# 2 [b'um', b'mu']
# 2 [b'scuff', b'cuffs']
# 2 [b'incises', b'iciness']
# 2 [b'craving', b'carving']
# 2 [b'magnate', b'magenta']
# 2 [b'reed', b'deer']
# 3 [b"stop's", b"spot's", b"post's"]
# 2 [b'masking', b'makings']
# 2 [b'provides', b'disprove']
# 2 [b'rioted', b'editor']
# 4 [b'softer', b'foster', b'fortes', b'forest']
# 2 [b'leadership', b'dealership']
# 4 [b'singers', b'signers', b'resigns', b'ingress']
# 2 [b'curtsy', b'crusty']
# 2 [b'totalled', b'allotted']
# 2 [b'scrimp', b'crimps']
# 2 [b'rectify', b'certify']
# 2 [b'Jannie', b'Janine']
# 2 [b'overhangs', b'hangovers']
# 2 [b'turner', b'return']
# 3 [b'recanted', b'decanter', b'cantered']
# 2 [b'consoled', b'condoles']
# 3 [b"specter's", b"scepter's", b"respect's"]
# 3 [b'trestle', b'settler', b'letters']
# 2 [b'geed', b'edge']
# 2 [b'soured', b'roused']
# 2 [b'pathogens', b'heptagons']
# 2 [b"staple's", b"pastel's"]
# 2 [b'seasides', b'diseases']
# 2 [b'slaves', b'salves']
# 2 [b'steels', b'sleets']
# 2 [b'serials', b'airless']
# 2 [b'anodyne', b'annoyed']
# 2 [b'spouse', b'opuses']
# 2 [b'untidy', b'nudity']
# 3 [b'point', b'piton', b'pinto']
# 2 [b'teach', b'cheat']
# 2 [b'today', b'toady']
# 2 [b'collared', b'carolled']
# 3 [b'snub', b'nubs', b'buns']
# 2 [b'straying', b'stingray']
# 3 [b'tomes', b'smote', b'motes']
# 2 [b'mobbed', b'bombed']
# 3 [b'instance', b'canniest', b'ancients']
# 2 [b'undies', b'indues']
# 2 [b'lubing', b'bluing']
# 2 [b'trailers', b'retrials']
# 2 [b'hied', b'hide']
# 2 [b'lab', b'alb']
# 2 [b'sheave', b'heaves']
# 2 [b'briskets', b'briskest']
# 2 [b'permissiveness', b'impressiveness']
# 3 [b"trap's", b"tarp's", b"part's"]
# 2 [b"Conan's", b"Canon's"]
# 2 [b'cobblers', b'clobbers']
# 3 [b'bleary', b'barley', b'barely']
# 2 [b'Lelia', b'Leila']
# 2 [b'repertories', b'repertoires']
# 2 [b'soiled', b'oldies']
# 2 [b'pirated', b'partied']
# 2 [b'scoop', b'coops']
# 2 [b'dab', b'bad']
# 3 [b"tin's", b"nit's", b"isn't"]
# 2 [b'positron', b'portions']
# 2 [b'noiseless', b'lionesses']
# 2 [b"wear's", b"ware's"]
# 2 [b"Manila's", b"Malian's"]
# 2 [b'deiced', b'decide']
# 2 [b'recheck', b'checker']
# 2 [b"trial's", b"trail's"]
# 2 [b'wells', b'swell']
# 2 [b'staples', b'pastels']
# 2 [b'tingling', b'glinting']
# 4 [b'regally', b'largely', b'gallery', b'allergy']
# 2 [b'liaised', b'dailies']
# 2 [b'steamiest', b'estimates']
# 2 [b'neigh', b'hinge']
# 2 [b'tortilla', b'littoral']
# 3 [b'ideas', b'aside', b'aides']
# 2 [b'speller', b'respell']
# 2 [b'pal', b'lap']
# 2 [b'pages', b'gapes']
# 3 [b'tonnes', b'tenons', b'sonnet']
# 2 [b'saltpetre', b'saltpeter']
# 4 [b'tread', b'trade', b'tared', b'rated']
# 2 [b'stealing', b'genitals']
# 2 [b'overall', b'allover']
# 2 [b'tend', b'dent']
# 3 [b'tinseling', b'listening', b'enlisting']
# 2 [b'char', b'arch']
# 2 [b'stinted', b'dentist']
# 2 [b'shapes', b'phases']
# 2 [b'embracing', b'cambering']
# 2 [b'stanching', b'snatching']
# 2 [b'permutation', b'importunate']
# 2 [b'unwary', b'runway']
# 2 [b'cordon', b'condor']
# 3 [b'trig', b'grit', b'girt']
# 2 [b'Chianti', b'Chaitin']
# 2 [b'singing', b'signing']
# 2 [b'tipples', b'stipple']
# 2 [b"gamine's", b"enigma's"]
# 2 [b'hotel', b'helot']
# 2 [b'Boeing', b'Biogen']
# 2 [b'friend', b'finder']
# 2 [b"plug's", b"gulp's"]
# 2 [b'retries', b'retires']
# 2 [b'sideboard', b'broadside']
# 3 [b'panes', b'napes', b'aspen']
# 3 [b"thread's", b"hatred's", b"dearth's"]
# 2 [b'Gale', b'Gael']
# 2 [b"maleness's", b"lameness's"]
# 2 [b'repainted', b'pertained']
# 2 [b'peasant', b'anapest']
# 2 [b'seeing', b'genies']
# 2 [b"bos'n's", b"bo's'ns"]
# 2 [b'thorn', b'north']
# 3 [b'scarlet', b'clarets', b'cartels']
# 2 [b"singer's", b"signer's"]
# 2 [b'discrete', b'discreet']
# 2 [b'patine', b'pantie']
# 3 [b"tar's", b"rat's", b"art's"]
# 2 [b'tab', b'bat']
# 2 [b'framers', b'farmers']
# 2 [b'tsars', b'stars']
# 2 [b'scopes', b'copses']
# 2 [b"spinet's", b"instep's"]
# 2 [b'pearl', b'paler']
# 2 [b"amphitheatre's", b"amphitheater's"]
# 2 [b'evolved', b'devolve']
# 2 [b"recount's", b"counter's"]
# 3 [b'wolf', b'fowl', b'flow']
# 2 [b"toenail's", b"elation's"]
# 3 [b'tinseled', b'listened', b'enlisted']
# 2 [b'doc', b'cod']
# 3 [b'rams', b'mars', b'arms']
# 2 [b"towel's", b"owlet's"]
# 2 [b'inbuilt', b'builtin']
# 2 [b'bulge', b'bugle']
# 2 [b'ripped', b'dipper']
# 3 [b'termini', b'mintier', b'interim']
# 2 [b"theatre's", b"theater's"]
# 2 [b'recondition', b'conditioner']
# 2 [b'astral', b'altars']
# 2 [b'sausages', b'assuages']
# 2 [b'seldom', b'models']
# 2 [b'sausage', b'assuage']
# 2 [b"stein's", b"inset's"]
# 2 [b"shot's", b"host's"]
# 2 [b'edible', b'belied']
# 2 [b'snivel', b'livens']
# 2 [b'usual', b'luaus']
# 2 [b'prattle', b'platter']
# 2 [b"fuel's", b"flue's"]
# 2 [b"Eloise's", b"Eliseo's"]
# 2 [b'blankets', b'blankest']
# 3 [b'skid', b'kids', b'disk']
# 2 [b"Ronald's", b"Roland's"]
# 2 [b'sums', b'muss']
# 2 [b'trusties', b'rustiest']
# 2 [b'lifts', b'flits']
# 2 [b'Conley', b'Ceylon']
# 5 [b'tsar', b'tars', b'star', b'rats', b'arts']
# 2 [b'oink', b'ikon']
# 2 [b'freed', b'defer']
# 2 [b'cadet', b'acted']
# 3 [b'organ', b'groan', b'argon']
# 2 [b'shrikes', b'shrieks']
# 2 [b'tutors', b'trouts']
# 2 [b'thin', b'hint']
# 2 [b"revel's", b"lever's"]
# 2 [b'received', b'deceiver']
# 2 [b"platen's", b"planet's"]
# 2 [b'recedes', b'decrees']
# 2 [b'wonderful', b'underflow']
# 2 [b"mine's", b"mien's"]
# 2 [b'sprint', b'prints']
# 2 [b'tilling', b'lilting']
# 2 [b'vied', b'dive']
# 4 [b'tries', b'tires', b'tiers', b'rites']
# 2 [b'worker', b'rework']
# 2 [b'trot', b'tort']
# 2 [b'Lynne', b'Lenny']
# 2 [b'scrip', b'crisp']
# 2 [b'rouge', b'rogue']
# 2 [b"Castillo's", b"Callisto's"]
# 2 [b'beans', b'banes']
# 2 [b"rouge's", b"rogue's"]
# 2 [b'rosined', b'indorse']
# 2 [b'on', b'no']
# 3 [b"tear's", b"tare's", b"rate's"]
# 2 [b'green', b'genre']
# 3 [b"tester's", b"street's", b"setter's"]
# 2 [b'yaw', b'way']
# 2 [b'lean', b'lane']
# 2 [b'sphere', b'herpes']
# 2 [b'yelped', b'deeply']
# 2 [b'slabbed', b'dabbles']
# 2 [b'direct', b'credit']
# 2 [b'amphitheatres', b'amphitheaters']
# 2 [b'intends', b'indents']
# 3 [b'feta', b'feat', b'fate']
# 2 [b"Gila's", b"Gail's"]
# 2 [b"left's", b"felt's"]
# 2 [b'trialing', b'trailing']
# 2 [b'case', b'aces']
# 2 [b'titans', b'taints']
# 2 [b"Erie's", b"Eire's"]
# 3 [b'truce', b'cuter', b'cruet']
# 2 [b'queries', b'esquire']
# 2 [b"one's", b"eon's"]
# 2 [b'gentians', b'antigens']
# 5 [b'tinsel', b'silent', b'listen', b'inlets', b'enlist']
# 3 [b'ochre', b'ocher', b'chore']
# 2 [b'wishers', b'swisher']
# 2 [b'yarn', b'nary']
# 2 [b"rider's", b"drier's"]
# 5 [b'staled', b'slated', b'salted', b'lasted', b'deltas']
# 2 [b'trusses', b'russets']
# 2 [b"waters's", b"waster's"]
# 2 [b"Paula's", b"Palau's"]
# 2 [b'Leon', b'Leno']
# 2 [b"prattle's", b"platter's"]
# 2 [b"framer's", b"farmer's"]
# 2 [b'Eloise', b'Eliseo']
# 2 [b'staidest', b'distaste']
# 2 [b'scaliest', b'elastics']
# 3 [b'sheared', b'headers', b'adheres']
# 2 [b'media', b'aimed']
# 2 [b'bets', b'best']
# 3 [b'silenter', b'reenlist', b'listener']
# 3 [b'soles', b'sloes', b'loses']
# 2 [b'feigned', b'feeding']
# 2 [b"veal's", b"vale's"]
# 2 [b'undressing', b'undersigns']
# 2 [b'liberals', b'ballsier']
# 2 [b'scab', b'cabs']
# 3 [b'tureen', b'tenure', b'neuter']
# 2 [b'sparer', b'parser']
# 2 [b"spirea's", b"praise's"]
# 2 [b'wavier', b'waiver']
# 2 [b'laded', b'addle']
# 2 [b'taming', b'mating']
# 2 [b'macro', b'carom']
# 2 [b'sister', b'resist']
# 2 [b'simmering', b'immersing']
# 2 [b'internes', b'intenser']
# 2 [b'tints', b'stint']
# 4 [b'pleat', b'plate', b'petal', b'leapt']
# 2 [b'Marina', b'Marian']
# 2 [b'pooh', b'hoop']
# 2 [b'beseech', b'beeches']
# 3 [b'beasts', b'bastes', b'basest']
# 4 [b'trance', b'recant', b'nectar', b'canter']
# 2 [b'sores', b'roses']
# 2 [b"torso's", b"roost's"]
# 2 [b"Luisa's", b"Laius's"]
# 2 [b'lowed', b'dowel']
# 2 [b'flies', b'files']
# 2 [b'echos', b'chose']
# 3 [b'trams', b'smart', b'marts']
# 2 [b'spill', b'pills']
# 3 [b'twos', b'tows', b'stow']
# 2 [b'mislead', b'misdeal']
# 3 [b"mantle's", b"mantel's", b"lament's"]
# 2 [b'wades', b'sawed']
# 3 [b'tuns', b'stun', b'nuts']
# 2 [b'sabres', b'sabers']
# 2 [b"slip's", b"lisp's"]
# 2 [b"cordon's", b"condor's"]
# 2 [b"moat's", b"atom's"]
# 2 [b"coed's", b"code's"]
# 2 [b"domination's", b"admonition's"]
# 3 [b'vilely', b'lively', b'evilly']
# 2 [b'evict', b'civet']
# 2 [b'scramble', b'clambers']
# 2 [b"Pele's", b"Peel's"]
# 2 [b"stile's", b"islet's"]
# 2 [b'decompress', b'compressed']
# 2 [b'who', b'how']
# 2 [b'gobs', b'bogs']
# 2 [b"spin's", b"snip's"]
# 2 [b'refinish', b'finisher']
# 2 [b"roe's", b"ore's"]
# 3 [b'recall', b'cellar', b'caller']
# 2 [b'loath', b'altho']
# 7 [b'spear', b'spare', b'reaps', b'rapes', b'pears', b'parse', b'pares']
# 2 [b'renal', b'learn']
# 2 [b'upholsterers', b'reupholsters']
# 2 [b'diuretics', b'crudities']
# 2 [b'chasing', b'cashing']
# 2 [b'toenail', b'elation']
# 2 [b"yea's", b"aye's"]
# 4 [b'treatise', b'treaties', b'teariest', b'iterates']
# 2 [b"padre's", b"drape's"]
# 2 [b'tousled', b'loudest']
# 2 [b'tieing', b'ignite']
# 3 [b'remain', b'marine', b'airmen']
# 2 [b'framed', b'farmed']
# 4 [b'seal', b'sale', b'leas', b'ales']
# 2 [b'teller', b'retell']
# 3 [b'hotels', b'hostel', b'helots']
# 2 [b'scripted', b'predicts']
# 2 [b'parasite', b'aspirate']
# 2 [b'trialed', b'trailed']
# 2 [b'Nile', b'Neil']
# 2 [b'rabid', b'braid']
# 2 [b'raping', b'paring']
# 2 [b'voters', b'strove']
# 2 [b'zeal', b'laze']
# 2 [b'graze', b'gazer']
# 2 [b'predated', b'departed']
# 2 [b'maple', b'ample']
# 2 [b'hated', b'death']
# 3 [b'slip', b'lisp', b'lips']
# 2 [b'waning', b'awning']
# 2 [b'regaling', b'ganglier']
# 2 [b"binge's", b"being's"]
# 5 [b'siren', b'risen', b'rinse', b'resin', b'reins']
# 2 [b'sauce', b'cause']
# 3 [b'bead', b'bade', b'abed']
# 2 [b"edification's", b"deification's"]
# 2 [b'unset', b'tunes']
# 2 [b"tug's", b"gut's"]
# 2 [b"pea's", b"ape's"]
# 2 [b'sedge', b'edges']
# 2 [b'pan', b'nap']
# 2 [b'lease', b'easel']
# 3 [b'tams', b'mats', b'mast']
# 3 [b'race', b'care', b'acre']
# 2 [b'Mercia', b'Marcie']
# 2 [b'Foster', b'Forest']
# 2 [b'premisses', b'impresses']
# 5 [b'shear', b'share', b'rheas', b'hears', b'hares']
# 2 [b'reclaims', b'miracles']
# 2 [b'pealing', b'leaping']
# 2 [b'maul', b'alum']
# 2 [b'programed', b'deprogram']
# 3 [b'ramble', b'marble', b'blamer']
# 2 [b'reeds', b'deers']
# 2 [b'splaying', b'palsying']
# 2 [b'paged', b'gaped']
# 2 [b'emboss', b'besoms']
# 2 [b'iridescent', b'indiscreet']
# 2 [b'trucks', b'struck']
# 3 [b'sooth', b'shoot', b'hoots']
# 2 [b'treeing', b'integer']
# 2 [b'nonuser', b'neurons']
# 2 [b'glanced', b'clanged']
# 2 [b'tonal', b'talon']
# 2 [b"wee's", b"ewe's"]
# 2 [b'lacking', b'calking']
# 2 [b"mead's", b"dame's"]
# 3 [b'fostered', b'forested', b'deforest']
# 2 [b'several', b'reveals']
# 2 [b'sellers', b'resells']
# 2 [b'ransom', b'manors']
# 2 [b'stage', b'gates']
# 3 [b'simpers', b'premiss', b'impress']
# 2 [b'stagnation', b'antagonist']
# 2 [b'solar', b'orals']
# 2 [b'sombrely', b'somberly']
# 2 [b"infield's", b"infidel's"]
# 2 [b'mocha', b'macho']
# 2 [b'buys', b'busy']
# 2 [b'marcher', b'charmer']
# 2 [b'soils', b'silos']
# 2 [b'refer', b'freer']
# 2 [b'reliefs', b'refiles']
# 3 [b'niggle', b'neglig', b'leggin']
# 2 [b'shrives', b'shivers']
# 2 [b"mace's", b"acme's"]
# 2 [b'boots', b'boost']
# 2 [b"diary's", b"dairy's"]
# 2 [b'tonne', b'tenon']
# 2 [b'directing', b'crediting']
# 2 [b'goitre', b'goiter']
# 2 [b'reassure', b'erasures']
# 2 [b'owned', b'endow']
# 2 [b"yap's", b"pay's"]
# 2 [b'ogle', b'loge']
# 2 [b"grad's", b"drag's"]
# 2 [b'tooled', b'looted']
# 2 [b"breath's", b"bather's"]
# 2 [b"Crimean's", b"Carmine's"]
# 5 [b'trainers', b'terrains', b'strainer', b'retrains', b'restrain']
# 2 [b"spool's", b"sloop's"]
# 2 [b"uterus's", b"suture's"]
# 2 [b'redid', b'dried']
# 2 [b'roved', b'drove']
# 2 [b"nub's", b"bun's"]
# 2 [b"tike's", b"kite's"]
# 2 [b'images', b'ageism']
# 2 [b'weepers', b'sweeper']
# 2 [b"reverse's", b"reserve's"]
# 2 [b'patsy', b'pasty']
# 2 [b'toms', b'most']
# 2 [b'rebuffing', b'buffering']
# 2 [b'presets', b'pesters']
# 2 [b'spinier', b'inspire']
# 2 [b'surest', b'russet']
# 2 [b'tweeters', b'retweets']
# 2 [b'slung', b'lungs']
# 2 [b'where', b'hewer']
# 2 [b'matins', b'mantis']
# 3 [b"rood's", b"odor's", b"door's"]
# 2 [b'users', b'ruses']
# 2 [b'Monte', b'Monet']
# 2 [b"turner's", b"return's"]
# 2 [b'obtains', b'bastion']
# 3 [b'niter', b'inter', b'inert']
# 2 [b'theologians', b'anthologies']
# 2 [b'earbud', b'dauber']
# 2 [b'scrapes', b'parsecs']
# 2 [b'expected', b'excepted']
# 2 [b'squid', b'quids']
# 2 [b'murdering', b'demurring']
# 2 [b'isometric', b'eroticism']
# 4 [b'rustle', b'result', b'lustre', b'luster']
# 2 [b'simplest', b'misspelt']
# 2 [b'crashing', b'chagrins']
# 3 [b"khan's", b"hank's", b"ankh's"]
# 3 [b'slivered', b'silvered', b'delivers']
# 2 [b'usurped', b'pursued']
# 2 [b'respelt', b'petrels']
# 2 [b'storeys', b'oysters']
# 2 [b'scalene', b'cleanse']
# 3 [b'posted', b'despot', b'depots']
# 2 [b"plane's", b"panel's"]
# 3 [b'teased', b'sedate', b'seated']
# 2 [b'amidst', b'admits']
# 4 [b'leads', b'lades', b'deals', b'dales']
# 2 [b'heat', b'hate']
# 2 [b'mousse', b'mouses']
# 2 [b'lathing', b'halting']
# 3 [b"taser's", b"stare's", b"aster's"]
# 2 [b"testament's", b"statement's"]
# 2 [b'portal', b'patrol']
# 3 [b'sergeant', b'reagents', b'estrange']
# 2 [b'parent', b'entrap']
# 2 [b'moats', b'atoms']
# 2 [b'streams', b'masters']
# 2 [b"two's", b"tow's"]
# 2 [b'trendier', b'interred']
# 2 [b'shooter', b'hooters']
# 3 [b'modes', b'domes', b'demos']
# 3 [b'reals', b'laser', b'earls']
# 2 [b"sectional's", b"coastline's"]
# 3 [b"trance's", b"nectar's", b"canter's"]
# 3 [b'teem', b'mete', b'meet']
# 2 [b"slide's", b"sidle's"]
# 2 [b'organists', b'assorting']
# 5 [b'triangle', b'relating', b'integral', b'altering', b'alerting']
# 2 [b'muse', b'emus']
# 2 [b'curse', b'cures']
# 3 [b'tasered', b'sedater', b'dearest']
# 2 [b"sole's", b"sloe's"]
# 2 [b'rooms', b'moors']
# 2 [b'duelist', b'dilutes']
# 2 [b'burned', b'burden']
# 3 [b'meals', b'males', b'lames']
# 2 [b'tritest', b'titters']
# 2 [b"stray's", b"satyr's"]
# 2 [b'gofers', b'forges']
# 3 [b'stanch', b'snatch', b'chants']
# 2 [b'slashed', b'hassled']
# 2 [b"she'll", b"hell's"]
# 3 [b'Moira', b'Mario', b'Maori']
# 2 [b'lamb', b'balm']
# 4 [b'repairs', b'raspier', b'rapiers', b'parries']
# 2 [b'unripe', b'punier']
# 3 [b'waddles', b'swaddle', b'dawdles']
# 2 [b'breast', b'barest']
# 2 [b'taco', b'coat']
# 3 [b'silenced', b'licensed', b'declines']
# 2 [b'shat', b'hats']
# 4 [b'scrota', b'costar', b'castor', b'actors']
# 2 [b'gardenia', b'drainage']
# 2 [b'toques', b'quotes']
# 2 [b'trussed', b'dusters']
# 2 [b'tog', b'got']
# 2 [b'disparate', b'aspirated']
# 3 [b'uterine', b'reunite', b'retinue']
# 2 [b'tweeter', b'retweet']
# 2 [b'snoopier', b'poisoner']
# 3 [b'grab', b'garb', b'brag']
# 2 [b'snigger', b'niggers']
# 2 [b'Moro', b'Moor']
# 2 [b'tore', b'rote']
# 2 [b'slugger', b'gurgles']
# 2 [b'venerate', b'enervate']
# 2 [b'futon', b'fount']
# 2 [b'violated', b'dovetail']
# 3 [b'drabs', b'brads', b'bards']
# 2 [b'pasted', b'adepts']
# 2 [b'Jamie', b'Jaime']
# 3 [b'steering', b'integers', b'gentries']
# 2 [b'donate', b'atoned']
# 2 [b'indeed', b'denied']
# 3 [b'sired', b'rides', b'dries']
# 2 [b'whosoever', b'howsoever']
# 2 [b'upscale', b'capsule']
# 2 [b'purest', b'erupts']
# 2 [b'rear', b'rare']
# 2 [b'fuels', b'flues']
# 2 [b'woodland', b'download']
# 2 [b'Luria', b'Lauri']
# 2 [b'reforest', b'forester']
# 2 [b'steadier', b'readiest']
# 2 [b'orbits', b'bistro']
# 2 [b'tactile', b'lattice']
# 2 [b'unable', b'nebula']
# 2 [b'ribbed', b'bribed']
# 2 [b'peeking', b'keeping']
# 2 [b"skin's", b"sink's"]
# 2 [b'ameba', b'abeam']
# 2 [b'venerates', b'enervates']
# 3 [b'coatings', b'coasting', b'agnostic']
# 4 [b"plea's", b"peal's", b"pale's", b"leap's"]
# 2 [b'reaming', b'mangier']
# 3 [b'shire', b'hires', b'heirs']
# 2 [b'paps', b'apps']
# 3 [b'taros', b'sorta', b'roast']
# 2 [b'nab', b'ban']
# 2 [b'turners', b'returns']
# 2 [b'beak', b'bake']
# 2 [b'prestos', b'posters']
# 2 [b'stabling', b'blasting']
# 2 [b'debugger', b'begrudge']
# 2 [b"real's", b"earl's"]
# 2 [b"rub's", b"bur's"]
# 2 [b'cordons', b'condors']
# 2 [b'thatches', b'hatchets']
# 2 [b'strafe', b'faster']
# 2 [b'framing', b'farming']
# 2 [b"Monte's", b"Monet's"]
# 4 [b'tied', b'tide', b'edit', b'diet']
# 2 [b'umpire', b'impure']
# 2 [b"vector's", b"covert's"]
# 2 [b'boggled', b'blogged']
# 2 [b"idle's", b"deli's"]
# 2 [b'cartons', b'cantors']
# 2 [b'Elsie', b'Elise']
# 2 [b"tsar's", b"star's"]
# 2 [b'pulsing', b'plugins']
# 2 [b"Clemson's", b"Clemons's"]
# 2 [b"lab's", b"alb's"]
# 2 [b'wingspan', b'spawning']
# 2 [b'lube', b'blue']
# 2 [b"varlet's", b"travel's"]
# 2 [b"green's", b"genre's"]
# 2 [b"Roseann's", b"Rosanne's"]
# 2 [b"nib's", b"bin's"]
# 2 [b'section', b'notices']
# 2 [b'evicts', b'civets']
# 2 [b'reforests', b'foresters']
# 2 [b'storage', b'garotes']
# 2 [b'bowling', b'blowing']
# 2 [b'scant', b'cants']
# 2 [b'rambles', b'marbles']
# 2 [b'Kristen', b'Kirsten']
# 2 [b'adobe', b'abode']
# 2 [b'recur', b'curer']
# 2 [b'poled', b'loped']
# 3 [b'madden', b'demand', b'damned']
# 2 [b'spider', b'prides']
# 2 [b'tough', b'ought']
# 2 [b'romp', b'prom']
# 3 [b"trig's", b"grit's", b"girt's"]
# 2 [b'riming', b'miring']
# 2 [b"Aron's", b"Arno's"]
# 2 [b'spooned', b'snooped']
# 2 [b'liefest', b'lefties']
# 2 [b'rugged', b'grudge']
# 2 [b"tor's", b"rot's"]
# 2 [b'replaces', b'percales']
# 2 [b'spongier', b'reposing']
# 2 [b'Clemson', b'Clemons']
# 2 [b"turbine's", b"tribune's"]
# 2 [b'trappings', b'strapping']
# 2 [b'reined', b'denier']
# 3 [b'tickers', b'sticker', b'rickets']
# 2 [b'startling', b'rattlings']
# 2 [b'tripod', b'torpid']
# 2 [b'sedan', b'deans']
# 2 [b"median's", b"maiden's"]
# 2 [b'tun', b'nut']
# 2 [b"shah's", b"hash's"]
# 3 [b'wolfs', b'fowls', b'flows']
# 2 [b'golfs', b'flogs']
# 2 [b'great', b'grate']
# 2 [b'wordiness', b'rowdiness']
# 2 [b'upsets', b'setups']
# 2 [b'woodlands', b'downloads']
# 2 [b'partly', b'paltry']
# 2 [b'viewer', b'review']
# 2 [b'teaser', b'eaters']
# 2 [b'dubs', b'buds']
# 2 [b"threat's", b"hatter's"]
# 2 [b'knifing', b'finking']
# 4 [b'sonic', b'scion', b'icons', b'coins']
# 2 [b"futon's", b"fount's"]
# 2 [b'medicated', b'decimated']
# 2 [b'closets', b'closest']
# 2 [b'ruthless', b'hustlers']
# 2 [b'tine', b'nite']
# 2 [b'shaft', b'hafts']
# 2 [b'tabbies', b'babiest']
# 2 [b'medial', b'mailed']
# 2 [b'similes', b'missile']
# 2 [b'norms', b'morns']
# 2 [b"pyre's", b"prey's"]
# 2 [b'venal', b'navel']
# 2 [b'staggered', b'raggedest']
# 2 [b'coevals', b'alcoves']
# 3 [b'slop', b'pols', b'lops']
# 4 [b'tassel', b'steals', b'stales', b'slates']
# 2 [b'dream', b'armed']
# 2 [b'Bret', b'Bert']
# 2 [b'tentatively', b'attentively']
# 2 [b'emoted', b'demote']
# 2 [b"wonder's", b"downer's"]
# 2 [b'tour', b'rout']
# 2 [b"Lorena's", b"Lenora's"]
# 2 [b'nation', b'anoint']
# 2 [b'strung', b'grunts']
# 3 [b'lioness', b'lesions', b'insoles']
# 2 [b'rife', b'fire']
# 2 [b"usurper's", b"pursuer's"]
# 2 [b'pathogen', b'heptagon']
# 2 [b'startles', b'starlets']
# 2 [b'nearness', b'ensnares']
# 2 [b'lambskin', b'lambkins']
# 2 [b'poohing', b'hooping']
# 2 [b'moans', b'mason']
# 2 [b"Mimosa's", b"Maoism's"]
# 2 [b'debugs', b'budges']
# 2 [b'median', b'maiden']
# 2 [b'meh', b'hem']
# 2 [b'blest', b'belts']
# 2 [b"Elisa's", b"Elias's"]
# 2 [b"Chianti's", b"Chaitin's"]
# 2 [b'transience', b'nectarines']
# 2 [b'bulging', b'bugling']
# 2 [b'renew', b'newer']
# 6 [b'staple', b'pleats', b'plates', b'petals', b'pastel', b'palest']
# 2 [b'tracers', b'craters']
# 2 [b'seller', b'resell']
# 4 [b'traipse', b'pirates', b'pastier', b'parties']
# 2 [b"idyll's", b"dilly's"]
# 3 [b'tester', b'street', b'setter']
# 2 [b'virginal', b'rivaling']
# 2 [b"bowler's", b"blower's"]
# 2 [b'taunting', b'attuning']
# 2 [b'prepay', b'papery']
# 2 [b'super', b'purse']
# 2 [b'lesion', b'insole']
# 3 [b'smug', b'mugs', b'gums']
# 3 [b'reads', b'dears', b'dares']
# 2 [b'sim', b'ism']
# 2 [b'faulted', b'default']
# 2 [b'mastoid', b'diatoms']
# 2 [b'oscillation', b'colonialist']
# 3 [b'yeas', b'easy', b'ayes']
# 2 [b'contingent', b'contenting']
# 2 [b'married', b'admirer']
# 2 [b'nadirs', b'drains']
# 2 [b'cold', b'clod']
# 3 [b'wets', b'west', b'stew']
# 2 [b'critic', b'citric']
# 2 [b'inch', b'chin']
# 2 [b'Warren', b'Warner']
# 2 [b'tarpons', b'patrons']
# 3 [b"grater's", b"garter's", b"garret's"]
# 2 [b'shaven', b'havens']
# 2 [b"Conley's", b"Ceylon's"]
# 3 [b'plead', b'pedal', b'paled']
# 2 [b'tellers', b'retells']
# 2 [b'sharing', b'garnish']
# 2 [b'rustles', b'results']
# 2 [b'skit', b'kits']
# 2 [b'roped', b'pored']
# 2 [b'bristle', b'blister']
# 3 [b"steak's", b"stake's", b"skate's"]
# 2 [b'moat', b'atom']
# 2 [b'niceness', b'incenses']
# 2 [b'tetanus', b'attunes']
# 2 [b'spec', b'pecs']
# 2 [b'yest', b'stye']
# 3 [b"break's", b"brake's", b"baker's"]
# 2 [b'Snead', b'Sedna']
# 2 [b'tartan', b'rattan']
# 2 [b'sprayer', b'prayers']
# 2 [b'insetted', b'dinettes']
# 2 [b"ipecac's", b"icecap's"]
# 2 [b'warding', b'drawing']
# 2 [b'warbler', b'brawler']
# 2 [b'grandest', b'dragnets']
# 2 [b'topsides', b'deposits']
# 2 [b'from', b'form']
# 2 [b'snidest', b'dissent']
# 4 [b'salesmen', b'nameless', b'maleness', b'lameness']
# 2 [b'shrub', b'brush']
# 2 [b'sub', b'bus']
# 2 [b"ten's", b"net's"]
# 2 [b"decor's", b"credo's"]
# 2 [b'could', b'cloud']
# 2 [b'microns', b'crimson']
# 2 [b'trashes', b'rashest']
# 2 [b'ideal', b'ailed']
# 2 [b'reversing', b'reserving']
# 2 [b'weeds', b'sewed']
# 2 [b'thistle', b'lithest']
# 2 [b"once's", b"cone's"]
# 2 [b"Forster's", b"Forrest's"]
# 2 [b"costar's", b"castor's"]
# 2 [b'daises', b'asides']
# 3 [b'serpents', b'presents', b'pertness']
# 2 [b'Stine', b'Stein']
# 2 [b"raiment's", b"minaret's"]
# 3 [b'slack', b'lacks', b'calks']
# 2 [b"spoon's", b"snoop's"]
# 2 [b"fiche's", b"chief's"]
# 2 [b'reeling', b'leering']
# 2 [b"claret's", b"cartel's"]
# 3 [b"recap's", b"crape's", b"caper's"]
# 2 [b'stoplights', b'spotlights']
# 2 [b'slider', b'idlers']
# 2 [b'crooners', b'coroners']
# 2 [b'rumble', b'lumber']
# 2 [b'diary', b'dairy']
# 2 [b'predictions', b'description']
# 2 [b'hula', b'haul']
# 2 [b'iciest', b'cities']
# 2 [b'reality', b'irately']
# 2 [b'spectrum', b'crumpets']
# 2 [b'mantlepiece', b'mantelpiece']
# 2 [b'raga', b'agar']
# 2 [b'upstarts', b'startups']
# 2 [b'spates', b'pastes']
# 2 [b"freight's", b"fighter's"]
# 2 [b'gasp', b'gaps']
# 2 [b'resides', b'desires']
# 2 [b'adobes', b'abodes']
# 3 [b'tureens', b'tenures', b'neuters']
# 2 [b'nomads', b'damson']
# 2 [b'turnovers', b'overturns']
# 2 [b'schematic', b'catechism']
# 6 [b'sepal', b'pleas', b'peals', b'pales', b'leaps', b'lapse']
# 2 [b'ruled', b'lured']
# 2 [b'squad', b'quads']
# 2 [b'lance', b'clean']
# 2 [b'ratcheting', b'chattering']
# 2 [b'steaming', b'mangiest']
# 3 [b'vales', b'slave', b'salve']
# 2 [b"tablet's", b"battle's"]
# 2 [b'ponies', b'opines']
# 3 [b"wolf's", b"fowl's", b"flow's"]
# 2 [b'tending', b'denting']
# 2 [b"trader's", b"retard's"]
# 2 [b'daze', b'adze']
# 2 [b"toast's", b"stoat's"]
# 2 [b'Luisa', b'Laius']
# 2 [b'rogering', b'reorging']
# 2 [b"prod's", b"drop's"]
# 2 [b'scalped', b'clasped']
# 3 [b'snag', b'sang', b'nags']
# 2 [b"veil's", b"evil's"]
# 2 [b'pamper', b'mapper']
# 2 [b'niggaz', b'gazing']
# 2 [b"Wylie's", b"Wiley's"]
# 2 [b'indulged', b'deluding']
# 3 [b'rectal', b'claret', b'cartel']
# 3 [b'slayer', b'relays', b'layers']
# 2 [b'slaving', b'salving']
# 2 [b'wearers', b'swearer']
# 2 [b'drained', b'dandier']
# 2 [b'tasteless', b'stateless']
# 2 [b'bassi', b'basis']
# 2 [b'wallows', b'swallow']
# 3 [b'thickset', b'thickets', b'thickest']
# 2 [b'streaks', b'skaters']
# 2 [b'idyll', b'dilly']
# 2 [b'silences', b'licenses']
# 2 [b'velour', b'louver']
# 2 [b"Moro's", b"Moor's"]
# 2 [b'signified', b'dignifies']
# 2 [b'engraves', b'avengers']
# 2 [b'hearty', b'earthy']
# 2 [b'rebuff', b'buffer']
# 2 [b'pervading', b'depraving']
# 2 [b'spoiled', b'despoil']
# 2 [b'tone', b'note']
# 3 [b'shred', b'sherd', b'herds']
# 2 [b'smock', b'mocks']
# 2 [b'warbled', b'brawled']
# 2 [b'scalars', b'rascals']
# 2 [b"ogle's", b"loge's"]
# 2 [b'Spenser', b'Serpens']
# 3 [b'wired', b'wider', b'weird']
# 2 [b'sidebars', b'seabirds']
# 2 [b'shone', b'hones']
# 2 [b'sharping', b'phrasing']
# 2 [b'hostlers', b'holsters']
# 2 [b'mediums', b'dummies']
# 2 [b"lupine's", b"lineup's"]
# 2 [b"fractal's", b"flatcar's"]
# 2 [b'scam', b'cams']
# 2 [b"friend's", b"finder's"]
# 3 [b'education', b'cautioned', b'auctioned']
# 2 [b'reefs', b'frees']
# 2 [b"neigh's", b"hinge's"]
# 2 [b'pager', b'grape']
# 2 [b'hurled', b'hurdle']
# 3 [b'these', b'thees', b'sheet']
# 2 [b'nods', b'dons']
# 2 [b'locates', b'lactose']
# 2 [b'ringer', b'erring']
# 2 [b"Suriname's", b"Sumerian's"]
# 3 [b'larges', b'lagers', b'glares']
# 2 [b'disinters', b'dirtiness']
# 2 [b'trainee', b'retinae']
# 2 [b'raises', b'arises']
# 2 [b'reefing', b'freeing']
# 2 [b'staring', b'ratings']
# 2 [b'smidge', b'midges']
# 2 [b'craves', b'carves']
# 2 [b'repeater', b'repartee']
# 2 [b'failed', b'afield']
# 2 [b'striking', b'skirting']
# 2 [b"overlay's", b"layover's"]
# 2 [b'rimmed', b'dimmer']
# 3 [b'reviled', b'relived', b'deliver']
# 2 [b'staph', b'paths']
# 3 [b'vainer', b'ravine', b'naiver']
# 2 [b"orgy's", b"gyro's"]
# 2 [b"volley's", b"lovely's"]
# 3 [b'read', b'dear', b'dare']
# 2 [b"itch's", b"chit's"]
# 2 [b'spiking', b'pigskin']
# 3 [b'tins', b'snit', b'nits']
# 2 [b'driblets', b'bristled']
# 2 [b'nabs', b'bans']
# 2 [b'seals', b'sales']
# 2 [b"year's", b"aery's"]
# 2 [b'page', b'gape']
# 2 [b'doubles', b'bloused']
# 2 [b'precipitate', b'peripatetic']
# 2 [b'tidiness', b'insisted']
# 2 [b'spoons', b'snoops']
# 2 [b'teaching', b'cheating']
# 2 [b'craved', b'carved']
# 2 [b'wrap', b'warp']
# 2 [b'napped', b'append']
# 2 [b'never', b'nerve']
# 2 [b'tortillas', b'littorals']
# 2 [b'varlets', b'travels']
# 2 [b'realization', b'rationalize']
# 2 [b'straits', b'artists']
# 2 [b'rafting', b'farting']
# 2 [b'ream', b'mare']
# 2 [b'strained', b'randiest']
# 2 [b'sample', b'maples']
# 2 [b"Warren's", b"Warner's"]
# 2 [b'senatorial', b'rationales']
# 2 [b'ultimate', b'mutilate']
# 2 [b'inspection', b'inceptions']
# 2 [b'cat', b'act']
# 2 [b"starter's", b"restart's"]
# 2 [b'marching', b'charming']
# 2 [b"lube's", b"blue's"]
# 3 [b"trace's", b"crate's", b"caret's"]
# 2 [b'sheath', b'heaths']
# 2 [b'node', b'done']
# 2 [b'coagulate', b'catalogue']
# 2 [b'shovel', b'hovels']
# 2 [b"timbre's", b"timber's"]
# 2 [b"what's", b"thaw's"]
# 2 [b"login's", b"lingo's"]
# 3 [b'leading', b'dealing', b'aligned']
# 2 [b"wasn't", b"want's"]
# 2 [b'Jonas', b'Jason']
# 2 [b'misprint', b'imprints']
# 4 [b'tea', b'eta', b'eat', b'ate']
# 2 [b'fined', b'fiend']
# 2 [b'whereon', b'nowhere']
# 2 [b'restarting', b'registrant']
# 3 [b'yaps', b'spay', b'pays']
# 2 [b'lobe', b'bole']
# 2 [b'sniper', b'ripens']
# 2 [b'dazes', b'adzes']
# 2 [b'welder', b'lewder']
# 2 [b'cuspid', b'cupids']
# 2 [b'smash', b'shams']
# 2 [b'contrail', b'cilantro']
# 3 [b"spa's", b"sap's", b"asp's"]
# 3 [b"raft's", b"frat's", b"fart's"]
# 2 [b'she', b'hes']
# 2 [b'teazles', b'teazels']
# 3 [b'wens', b'sewn', b'news']
# 2 [b'harried', b'hardier']
# 3 [b'rupees', b'purees', b'peruse']
# 3 [b'stops', b'spots', b'posts']
# 2 [b"Dion's", b"Dino's"]
# 2 [b"sybarite's", b"bestiary's"]
# 2 [b'nighties', b'heisting']
# 2 [b"adobe's", b"abode's"]
# 2 [b'telephony', b'polythene']
# 2 [b'sages', b'gases']
# 4 [b'scare', b'races', b'cares', b'acres']
# 2 [b"moral's", b"molar's"]
# 2 [b'towel', b'owlet']
# 2 [b'sisal', b'sails']
# 2 [b'enamored', b'demeanor']
# 2 [b'suited', b'duties']
# 2 [b'recasting', b'caterings']
# 2 [b'upholsterer', b'reupholster']
# 2 [b'tooling', b'looting']
# 2 [b'director', b'creditor']
# 2 [b'prepared', b'dapperer']
# 2 [b'limeade', b'emailed']
# 2 [b'nixed', b'index']
# 3 [b'yaws', b'ways', b'sway']
# 2 [b"great's", b"grate's"]
# 2 [b"right's", b"girth's"]
# 2 [b"triage's", b"gaiter's"]
# 2 [b"nacre's", b"crane's"]
# 2 [b"cobbler's", b"clobber's"]
# 2 [b'reinventing', b'intervening']
# 2 [b'emendation', b'denominate']
# 3 [b'shrike', b'shriek', b'hikers']
# 2 [b'reefed', b'feeder']
# 2 [b'breath', b'bather']
# 2 [b'slaved', b'salved']
# 2 [b'tucks', b'stuck']
# 2 [b'permissions', b'impressions']
# 2 [b"rectitude's", b"certitude's"]
# 2 [b'meatier', b'emirate']
# 2 [b"sire's", b"rise's"]
# 2 [b'sasses', b'assess']
# 2 [b'broads', b'boards']
# 2 [b'end', b'den']
# 2 [b'rescinded', b'discerned']
# 2 [b"stoplight's", b"spotlight's"]
# 2 [b'Jeannie', b'Jeanine']
# 3 [b'tire', b'tier', b'rite']
# 2 [b"reel's", b"leer's"]
# 2 [b'retool', b'looter']
# 2 [b'repetitions', b'petitioners']
# 2 [b'when', b'hewn']
# 2 [b'iced', b'dice']
# 2 [b"Jannie's", b"Janine's"]
# 2 [b'souring', b'rousing']
# 4 [b'spa', b'sap', b'pas', b'asp']
# 2 [b'hoarse', b'ashore']
# 2 [b"repetition's", b"petitioner's"]
# 2 [b'lag', b'gal']
# 2 [b'Sara', b'Saar']
# 2 [b'Pele', b'Peel']
# 2 [b'piques', b'equips']
# 3 [b'slaver', b'salver', b'ravels']
# 2 [b'canoeist', b'aconites']
# 2 [b"voile's", b"olive's"]
# 2 [b'oldie', b'oiled']
# 2 [b"yaws's", b"sway's"]
# 3 [b'dread', b'dared', b'adder']
# 2 [b'nib', b'bin']
# 2 [b'noel', b'lone']
# 2 [b'melon', b'lemon']
# 2 [b'venerating', b'enervating']
# 2 [b'rubes', b'rebus']
# 2 [b"Frieda's", b"Freida's"]
# 2 [b'flirtation', b'filtration']
# 2 [b"prefect's", b"perfect's"]
# 2 [b'tridents', b'strident']
# 3 [b'springier', b'respiring', b'reprising']
# 2 [b'graphically', b'calligraphy']
# 2 [b'mango', b'among']
# 3 [b'wroth', b'worth', b'throw']
# 2 [b'ugh', b'hug']
# 2 [b'redhead', b'adhered']
# 2 [b'wire', b'weir']
# 3 [b'placer', b'parcel', b'carpel']
# 3 [b'tips', b'spit', b'pits']
# 2 [b"resource's", b"recourse's"]
# 2 [b'weepings', b'sweeping']
# 2 [b'rowel', b'lower']
# 2 [b'geocentric', b'egocentric']
# 2 [b'using', b'suing']
# 3 [b'tumbrels', b'tumblers', b'stumbler']
# 2 [b'ruble', b'bluer']
# 2 [b'tuna', b'aunt']
# 3 [b'rhea', b'hear', b'hare']
# 2 [b'thinker', b'rethink']
# 2 [b'reprogram', b'programer']
# 2 [b'cosmic', b'comics']
# 2 [b'rambling', b'marbling']
# 2 [b'Elnora', b'Elanor']
# 2 [b"Satan's", b"Santa's"]
# 2 [b"Dianne's", b"Dannie's"]
# 2 [b'hedonists', b'dishonest']
# 2 [b'lessen', b'lenses']
# 2 [b'recounting', b'countering']
# 2 [b'nutriments', b'instrument']
# 2 [b"mangle's", b"legman's"]
# 4 [b'teardrop', b'prorated', b'predator', b'parroted']
# 2 [b"yaw's", b"way's"]
# 2 [b'poem', b'mope']
# 2 [b'wagered', b'ragweed']
# 2 [b'nude', b'dune']
# 2 [b'shearing', b'hearings']
# 2 [b"drive's", b"diver's"]
# 2 [b'tarries', b'artsier']
# 2 [b'Hydra', b'Hardy']
# 2 [b'tilled', b'lilted']
# 2 [b'shock', b'hocks']
# 2 [b'sterner', b'renters']
# 3 [b"teacher's", b"hectare's", b"cheater's"]
# 2 [b'wrests', b'strews']
# 2 [b'rectifications', b'certifications']
# 2 [b'robe', b'bore']
# 2 [b'strolled', b'drollest']
# 2 [b'lubbers', b'burbles']
# 2 [b'streamlined', b'derailments']
# 2 [b'Stone', b'Seton']
# 2 [b'restful', b'fluster']
# 2 [b'reprocessed', b'predecessor']
# 2 [b'steamier', b'emirates']
# 2 [b'inures', b'insure']
# 3 [b'spireas', b'praises', b'aspires']
# 2 [b"schematic's", b"catechism's"]
# 2 [b"end's", b"den's"]
# 3 [b'servile', b'reviles', b'relives']
# 2 [b'marsh', b'harms']
# 2 [b'patch', b'chapt']
# 2 [b"inch's", b"chin's"]
# 2 [b'grease', b'agrees']
# 3 [b'top', b'pot', b'opt']
# 2 [b"loin's", b"lion's"]
# 2 [b'grubs', b'burgs']
# 3 [b'nearest', b'eastern', b'earnest']
# 2 [b'meditates', b'estimated']
# 2 [b'blabbed', b'babbled']
# 2 [b'wakes', b'askew']
# 2 [b'frayed', b'defray']
# 3 [b'sepals', b'passel', b'lapses']
# 2 [b"terrace's", b"caterer's"]
# 5 [b'trashed', b'threads', b'hatreds', b'hardest', b'dearths']
# 2 [b'mid', b'dim']
# 2 [b'stairs', b'sitars']
# 2 [b'outings', b'ousting']
# 2 [b'rebound', b'bounder']
# 4 [b'shale', b'leash', b'heals', b'hales']
# 2 [b'intoxicate', b'excitation']
# 2 [b'juts', b'just']
# 2 [b"trifle's", b"filter's"]
# 2 [b"user's", b"ruse's"]
# 2 [b'tug', b'gut']
# 2 [b'shunt', b'hunts']
# 3 [b'reloads', b'ordeals', b'loaders']
# 2 [b'repels', b'lepers']
# 2 [b'subs', b'buss']
# 2 [b'china', b'chain']
# 3 [b'lies', b'leis', b'isle']
# 2 [b"rupee's", b"puree's"]
# 3 [b"grab's", b"garb's", b"brag's"]
# 2 [b'strobe', b'sorbet']
# 3 [b'search', b'chaser', b'arches']
# 2 [b'ringtone', b'nitrogen']
# 2 [b'rogered', b'reorged']
# 5 [b'trees', b'terse', b'steer', b'reset', b'ester']
# 2 [b'upholds', b'holdups']
# 4 [b'tens', b'sent', b'nets', b'nest']
# 2 [b"Shelia's", b"Sheila's"]
# 2 [b'sarees', b'erases']
# 2 [b'atomizers', b'amortizes']
# 2 [b"nigga's", b"aging's"]
# 2 [b'leveraged', b'everglade']
# 2 [b'replaying', b'parleying']
# 2 [b'lambs', b'balms']
# 3 [b'recalls', b'cellars', b'callers']
# 2 [b'Cornelia', b'Caroline']
# 2 [b'with', b'whit']
# 2 [b'rankle', b'lanker']
# 2 [b'floored', b'flooder']
# 2 [b'ratcheted', b'chattered']
# 2 [b'vote', b'veto']
# 3 [b'mitered', b'merited', b'demerit']
# 2 [b"director's", b"creditor's"]
# 2 [b'traded', b'darted']
# 2 [b'lashes', b'hassle']
# 2 [b'vape', b'pave']
# 2 [b'pleading', b'pedaling']
# 4 [b'debar', b'bread', b'beard', b'bared']
# 3 [b'sole', b'sloe', b'lose']
# 3 [b'resided', b'desired', b'derides']
# 4 [b'verse', b'veers', b'sever', b'serve']
# 2 [b'recitals', b'articles']
# 2 [b"shad's", b"dash's"]
# 2 [b"strap's", b"sprat's"]
# 2 [b"senate's", b"sateen's"]
# 2 [b"glider's", b"girdle's"]
# 2 [b'rogers', b'reorgs']
# 2 [b'sublets', b'bustles']
# 2 [b'versed', b'served']
# 2 [b'sleazier', b'realizes']
# 2 [b'spoon', b'snoop']
# 3 [b'redoubt', b'obtrude', b'doubter']
# 2 [b'outsource', b'courteous']
# 2 [b"remote's", b"meteor's"]
# 2 [b'medal', b'lamed']
# 2 [b'lamenting', b'alignment']
# 2 [b'Ronald', b'Roland']
# 2 [b"shan't", b"hasn't"]
# 2 [b"Boeing's", b"Biogen's"]
# 2 [b"strife's", b"sifter's"]
# 2 [b'simmered', b'immersed']
# 2 [b"seam's", b"mesa's"]
# 3 [b'ogre', b'gore', b'ergo']
# 3 [b"Lena's", b"Lean's", b"Lane's"]
# 2 [b"shtick's", b"kitsch's"]
# 2 [b'Conan', b'Canon']
# 2 [b'slogs', b'gloss']
# 2 [b"oink's", b"ikon's"]
# 2 [b'tablets', b'battles']
# 2 [b'loner', b'enrol']
# 3 [b'toured', b'routed', b'detour']
# 3 [b'wines', b'swine', b'sinew']
# 3 [b'tailed', b'dilate', b'detail']
# 2 [b"truce's", b"cruet's"]
# 2 [b"destiny's", b"density's"]
# 3 [b'suborned', b'rebounds', b'bounders']
# 5 [b'raced', b'cedar', b'cared', b'cadre', b'arced']
# 2 [b'Tutsi', b'Titus']
# 2 [b'issued', b'disuse']
# 2 [b'slight', b'lights']
# 2 [b'peered', b'deeper']
# 2 [b'mescal', b'camels']
# 2 [b'presides', b'disperse']
# 2 [b'scone', b'cones']
# 2 [b'derailed', b'deadlier']
# 3 [b'namely', b'meanly', b'laymen']
# 2 [b'resource', b'recourse']
# 3 [b'plane', b'penal', b'panel']
# 2 [b'marina', b'airman']
# 2 [b'sneaks', b'snakes']
# 2 [b'rebutting', b'buttering']
# 3 [b"pone's", b"peon's", b"open's"]
# 2 [b'tangible', b'bleating']
# 2 [b'cosplay', b'calypso']
# 2 [b'shoes', b'hoses']
# 2 [b'went', b'newt']
# 2 [b'reheat', b'heater']
# 2 [b'reheats', b'heaters']
# 3 [b'smear', b'reams', b'mares']
# 2 [b'pole', b'lope']
# 2 [b'votes', b'stove']
# 2 [b'spars', b'rasps']
# 2 [b'solder', b'resold']
# 2 [b'refining', b'infringe']
# 2 [b'rank', b'nark']
# 2 [b'scalping', b'clasping']
# 2 [b'patois', b'patios']
# 2 [b"refill's", b"filler's"]
# 2 [b"peek's", b"keep's"]
# 2 [b'doorbells', b'bordellos']
# 2 [b'saddle', b'addles']
# 4 [b"rustle's", b"result's", b"lustre's", b"luster's"]
# 2 [b'shaded', b'dashed']
# 3 [b'specter', b'scepter', b'respect']
# 2 [b'predating', b'departing']
# 2 [b'hostile', b'holiest']
# 2 [b'slags', b'glass']
# 2 [b'crabs', b'carbs']
# 2 [b'cautioning', b'auctioning']
# 2 [b"junta's", b"jaunt's"]
# 2 [b'Crater', b'Carter']
# 3 [b'elbow', b'bowel', b'below']
# 2 [b'latex', b'exalt']
# 2 [b"mad's", b"dam's"]
# 2 [b'coagulated', b'catalogued']
# 2 [b'wrestles', b'swelters']
# 2 [b'martial', b'marital']
# 2 [b'shrines', b'shiners']
# 2 [b'tidiest', b'ditties']
# 2 [b'twits', b'twist']
# 2 [b'crinkles', b'clinkers']
# 2 [b'staplers', b'plasters']
# 2 [b"sack's", b"cask's"]
# 2 [b"shag's", b"gash's"]
# 2 [b"wheal's", b"whale's"]
# 2 [b"fringe's", b"finger's"]
# 2 [b'rings', b'grins']
# 2 [b'concreting', b'concerting']
# 2 [b'slicking', b'lickings']
# 2 [b'slacking', b'calkings']
# 2 [b"proselyte's", b"polyester's"]
# 2 [b'spew', b'pews']
# 2 [b'fieriest', b'feistier']
# 2 [b'sectional', b'coastline']
# 2 [b"viand's", b"divan's"]
# 2 [b'rices', b'cries']
# 2 [b"slam's", b"alms's"]
# 2 [b'misleading', b'misdealing']
# 2 [b'chisel', b'chiles']
# 2 [b'sisters', b'resists']
# 2 [b"cola's", b"coal's"]
# 3 [b'succor', b'occurs', b'crocus']
# 2 [b"Nile's", b"Neil's"]
# 2 [b'theses', b'sheets']
# 2 [b'semiprivate', b'imperatives']
# 2 [b'idyl', b'idly']
# 2 [b'terry', b'retry']
# 2 [b'Aron', b'Arno']
# 2 [b"caution's", b"auction's"]
# 2 [b'mounted', b'demount']
# 2 [b"detonation's", b"denotation's"]
# 2 [b"vole's", b"love's"]
# 2 [b'burgles', b'buglers']
# 2 [b'harkens', b'hankers']
# 2 [b"owl's", b"low's"]
# 2 [b'sectarians', b'ascertains']
# 2 [b'vaped', b'paved']
# ...
# 2 [b'ridges', b'dirges']
# 2 [b'owlish', b'lowish']
# 2 [b'gamine', b'enigma']
# 2 [b'medians', b'maidens']
# 2 [b'motels', b'molest']
# 2 [b"throe's", b"other's"]
# 2 [b'poems', b'mopes']
# 3 [b'whats', b'thaws', b'swath']
# 2 [b'testable', b'settable']
# 2 [b'hocking', b'choking']
# 2 [b'tailing', b'intagli']
# 3 [b'meal', b'male', b'lame']
# 2 [b"tartan's", b"rattan's"]
# 2 [b'entailed', b'dateline']
# 2 [b"tab's", b"bat's"]
# 2 [b'nod', b'don']
# 3 [b'reload', b'ordeal', b'loader']
# 2 [b'rejoin', b'joiner']
# 2 [b'heady', b'hayed']
# 2 [b'Marta', b'Marat']
# 2 [b"singing's", b"signing's"]
# 4 [b'plea', b'peal', b'pale', b'leap']
# 3 [b"tureen's", b"tenure's", b"neuter's"]
# 2 [b"ward's", b"draw's"]
# 2 [b'stamen', b'mantes']
# 2 [b'sheeting', b'seething']
# 2 [b"reaction's", b"creation's"]
# 3 [b'stance', b'enacts', b'ascent']
# 2 [b'sofa', b'oafs']
# 3 [b'traders', b'starred', b'retards']
# 2 [b'rued', b'rude']
# 2 [b'ridged', b'girded']
# 2 [b"nigger's", b"ginger's"]
# 2 [b'forded', b'fodder']
# 2 [b'loafed', b'foaled']
# 2 [b'weest', b'sweet']
# 2 [b'line', b'lien']
# 2 [b'repeals', b'relapse']
# 2 [b'fringes', b'fingers']
# 2 [b'lobsters', b'bolsters']
# 2 [b"Jeffrey's", b"Jeffery's"]
# 2 [b'relearns', b'learners']
# 2 [b"tarpon's", b"patron's"]
# 2 [b"portal's", b"patrol's"]
# 2 [b'transom', b'matrons']
# 2 [b"grub's", b"burg's"]
# 2 [b'signets', b'ingests']
# 2 [b'oceanic', b'cocaine']
# 2 [b'amphitheatre', b'amphitheater']
# 2 [b'receded', b'decreed']
# 2 [b'destinies', b'densities']
# 2 [b'shotguns', b'gunshots']
# 3 [b'rider', b'drier', b'direr']
# 2 [b"mocha's", b"macho's"]
# 2 [b'spatter', b'patters']
# 2 [b'simpered', b'premised']
# 2 [b'enures', b'ensure']
# 2 [b"infraction's", b"infarction's"]
# 2 [b'god', b'dog']
# 2 [b'glided', b'gilded']
# 2 [b'leaders', b'dealers']
# 2 [b'souped', b'pseudo']
# 2 [b'lubed', b'blued']
# 2 [b"shrine's", b"shiner's"]
# 3 [b'odes', b'dose', b'does']
# 2 [b'mountaineer', b'enumeration']
# 2 [b'lineaments', b'alinements']
# 2 [b'sheering', b'greenish']
# 2 [b'sties', b'sites']
# 2 [b"potion's", b"option's"]
# 2 [b'locust', b'clouts']
# 2 [b"tram's", b"mart's"]
# 2 [b'tang', b'gnat']
# 2 [b'unlisted', b'insulted']
# 3 [b'thermos', b'smother', b'mothers']
# 2 [b'seared', b'erased']
# 2 [b'tubed', b'debut']
# 2 [b"tacitness's", b"cattiness's"]
# 2 [b'loners', b'enrols']
# 3 [b'life', b'lief', b'file']
# 3 [b'startle', b'starlet', b'rattles']
# 2 [b'cupsful', b'cupfuls']
# 2 [b"lath's", b"halt's"]
# 3 [b'prenatal', b'paternal', b'parental']
# 2 [b'raked', b'drake']
# 2 [b"ring's", b"grin's"]
# 2 [b'fractals', b'flatcars']
# 3 [b"pool's", b"polo's", b"loop's"]
# 2 [b'sanserif', b'fairness']
# 2 [b'pigmy', b'gimpy']
# 2 [b'dourest', b'detours']
# 2 [b'piebald', b'bipedal']
# 3 [b'sorters', b'rosters', b'resorts']
# 2 [b'expects', b'excepts']
# 2 [b'Yeats', b'Yates']
# 2 [b'smolder', b'molders']
# 3 [b"Melba's", b"Mable's", b"Mabel's"]
# 2 [b'spoonsful', b'spoonfuls']
# 2 [b"Donnie's", b"Dionne's"]
# 3 [b'revised', b'diverse', b'derives']
# 2 [b'cassinos', b'caissons']
# 2 [b'dosing', b'doings']
# 3 [b'worse', b'swore', b'sower']
# 2 [b"sideboard's", b"broadside's"]
# 2 [b'sail', b'ails']
# 2 [b'ogles', b'loges']
# 2 [b'swines', b'sinews']
# 2 [b'veering', b'reeving']
# 2 [b'respires', b'reprises']
# 2 [b'stroke', b'stoker']
# 2 [b"warbler's", b"brawler's"]
# 2 [b'complied', b'compiled']
# 2 [b'Tisha', b'Thais']
# 2 [b'sermonized', b'modernizes']
# 2 [b"succor's", b"crocus's"]
# 2 [b'stipulated', b'platitudes']
# 2 [b'swan', b'sawn']
# 2 [b'has', b'ash']
# 3 [b'grits', b'grist', b'girts']
# 2 [b'hangs', b'gnash']
# 2 [b'sobered', b'bedsore']
# 2 [b'shreds', b'sherds']
# 2 [b'skeptic', b'pickets']
# 2 [b"glibness's", b"blessing's"]
# 2 [b'mindless', b'mildness']
# 2 [b'region', b'ignore']
# 2 [b"nod's", b"don's"]
# 2 [b'leaned', b'leaden']
# 2 [b'throne', b'hornet']
# 2 [b"tortilla's", b"littoral's"]
# 2 [b"tap's", b"pat's"]
# 2 [b'reeled', b'leered']
# 2 [b'mood', b'doom']
# 2 [b'ocean', b'canoe']
# 2 [b"gun's", b"gnu's"]
# 2 [b"patsy's", b"pasty's"]
# 2 [b"trainer's", b"terrain's"]
# 2 [b"Mercia's", b"Marcie's"]
# 2 [b'morays', b'mayors']
# 2 [b'tamps', b'stamp']
# 2 [b'raffia', b'affair']
# 3 [b'splatter', b'prattles', b'platters']
# 2 [b'rend', b'nerd']
# 2 [b'bra', b'bar']
# 2 [b'ensured', b'endures']
# 2 [b'scrips', b'crisps']
# 2 [b'fatness', b'fastens']
# 3 [b'steeling', b'sleeting', b'gentiles']
# 2 [b"woodland's", b"download's"]
# 2 [b'mobbing', b'bombing']
# 4 [b'spool', b'sloop', b'pools', b'loops']
# 2 [b'wresting', b'strewing']
# 2 [b'frothiest', b'fortieths']
# 2 [b'sleeve', b'levees']
# 2 [b'whits', b'whist']
# 2 [b'framer', b'farmer']
# 2 [b'tinkers', b'stinker']
# 2 [b'refiled', b'fielder']
# 2 [b'radon', b'adorn']
# 3 [b'voles', b'solve', b'loves']
# 2 [b'senders', b'redness']
# 2 [b"pane's", b"nape's"]
# 2 [b'steps', b'pests']
# 2 [b'tacit', b'attic']
# 2 [b'replaced', b'parceled']
# 2 [b'rechecked', b'checkered']
# 2 [b'nacre', b'crane']
# 3 [b'topical', b'optical', b'capitol']
# 3 [b'trader', b'tarred', b'retard']
# 2 [b'loafs', b'foals']
# 2 [b'icon', b'coin']
# 2 [b'weirder', b'rewired']
# 2 [b'gusset', b'guests']
# 2 [b'reconditions', b'conditioners']
# 2 [b'keystone', b'keynotes']
# 2 [b"Albireo's", b"Alberio's"]
# 2 [b'trials', b'trails']
# 2 [b'regards', b'graders']
# 2 [b'jets', b'jest']
# 3 [b"point's", b"piton's", b"pinto's"]
# 2 [b'simple', b'impels']
# 2 [b"south's", b"shout's"]
# 2 [b'ricked', b'dicker']
# 2 [b'slighted', b'delights']
# 2 [b'pervades', b'depraves']
# 2 [b'steamship', b'shipmates']
# 4 [b"rail's", b"lira's", b"liar's", b"lair's"]
# 2 [b'hobs', b'bosh']
# 2 [b'burnt', b'brunt']
# 2 [b'rejoins', b'joiners']
# 2 [b'unhorsed', b'enshroud']
# 2 [b'permission', b'impression']
# 3 [b"team's", b"meat's", b"mate's"]
# 2 [b'reclaim', b'miracle']
# 2 [b'permeating', b'impregnate']
# 3 [b'slits', b'silts', b'lists']
# 2 [b'trading', b'darting']
# 2 [b'breaths', b'bathers']
# 2 [b'turbine', b'tribune']
# 2 [b'climates', b'clematis']
# 2 [b'leases', b'easels']
# 2 [b'rap', b'par']
# 2 [b'tumbrel', b'tumbler']
# 2 [b'freak', b'faker']
# 2 [b'tends', b'dents']
# 2 [b'supreme', b'presume']
# 2 [b'deigned', b'deeding']
# 2 [b"bowl's", b"blow's"]
# 2 [b'spores', b'posers']
# 2 [b'warblers', b'brawlers']
# 2 [b'smartest', b'mattress']
# 2 [b'Durban', b'Dunbar']
# 2 [b'rears', b'rares']
# 2 [b"romaine's", b"moraine's"]
# 2 [b"spear's", b"spare's"]
# 2 [b'relayed', b'layered']
# 2 [b'eager', b'agree']
# 2 [b'cravings', b'carvings']
# 2 [b'crotches', b'crochets']
# 2 [b'teenager', b'generate']
# 5 [b'sabre', b'saber', b'bears', b'baser', b'bares']
# 2 [b"ridge's", b"dirge's"]
# 2 [b"medication's", b"decimation's"]
# 2 [b'Manila', b'Malian']
# 3 [b'spoilt', b'pistol', b'pilots']
# 2 [b"tun's", b"nut's"]
# 2 [b'pretense', b'preteens']
# 2 [b"table's", b"bleat's"]
# 2 [b"tone's", b"note's"]
# 2 [b"freak's", b"faker's"]
# 2 [b"spotter's", b"protest's"]
# 2 [b'rereads', b'readers']
# 2 [b'tensors', b'stoners']
# 2 [b"Tyre's", b"Trey's"]
# 2 [b'umping', b'impugn']
# 2 [b'doorbell', b'bordello']
# 3 [b'specters', b'scepters', b'respects']
# 2 [b'replacing', b'parceling']
# 2 [b'sobbing', b'gibbons']
# 2 [b'reel', b'leer']
# 2 [b'praline', b'plainer']
# 3 [b"siren's", b"rinse's", b"resin's"]
# 2 [b'leaf', b'flea']
# 2 [b'spines', b'snipes']
# 2 [b'chased', b'cashed']
# 2 [b'borne', b'boner']
# 2 [b'scent', b'cents']
# 2 [b'reef', b'free']
# 2 [b'sassing', b'assigns']
# 2 [b"doc's", b"cod's"]
# 3 [b'wards', b'sward', b'draws']
# 2 [b'triage', b'gaiter']
# 2 [b'curies', b'cruise']
# 2 [b'lefts', b'felts']
# 2 [b'logarithmic', b'algorithmic']
# 2 [b"velour's", b"louver's"]
# 2 [b'beset', b'beets']
# 2 [b'gables', b'bagels']
# 2 [b"stupor's", b"sprout's"]
# 2 [b'nudes', b'dunes']
# 2 [b'pelt', b'lept']
# 2 [b"shear's", b"share's"]
# 2 [b'cupolas', b'copulas']
# 2 [b"seaside's", b"disease's"]
# 3 [b'nailed', b'denial', b'alined']
# 2 [b"recast's", b"caster's"]
# 2 [b'encrusts', b'curtness']
# 2 [b'vacates', b'caveats']
# 3 [b'reside', b'eiders', b'desire']
# 2 [b'rending', b'grinned']
# 3 [b"stain's", b"satin's", b"saint's"]
# 2 [b"blame's", b"amble's"]
# 2 [b'table', b'bleat']
# 4 [b'stifle', b'itself', b'fliest', b'filets']
# 2 [b"Bernanke's", b"Banneker's"]
# 2 [b'simpering', b'premising']
# 2 [b'misdeed', b'demised']
# 2 [b'decamp', b'camped']
# 2 [b"moneybag's", b"bogeyman's"]
# 2 [b'bowl', b'blow']
# 2 [b"idea's", b"aide's"]
# 2 [b"solitary's", b"royalist's"]
# 3 [b'tyroes', b'storey', b'oyster']
# 4 [b'severer', b'reverse', b'reveres', b'reserve']
# 2 [b"partisan's", b"aspirant's"]
# 2 [b'isolating', b'intaglios']
# 2 [b'marched', b'charmed']
# 2 [b'malinger', b'germinal']
# 2 [b'oinks', b'ikons']
# 2 [b'bushels', b'blushes']
# 2 [b"vote's", b"veto's"]
# 2 [b'sombre', b'somber']
# 2 [b'fiches', b'chiefs']
# 2 [b"Elsie's", b"Elise's"]
# 2 [b"ramble's", b"marble's"]
# 2 [b'surmise', b'mussier']
# 2 [b'crashes', b'chasers']
# 2 [b'meg', b'gem']
# 3 [b'gleans', b'angles', b'angels']
# 2 [b'login', b'lingo']
# 2 [b"Gale's", b"Gael's"]
# 2 [b'stationed', b'antidotes']
# 2 [b'requite', b'quieter']
# 2 [b'shallow', b'hallows']
# 2 [b'sifts', b'fists']
# 3 [b'speak', b'spake', b'peaks']
# 2 [b'remotes', b'meteors']
# 3 [b'raft', b'frat', b'fart']
# 2 [b'morals', b'molars']
# 2 [b'restoring', b'resorting']
# 2 [b'enraging', b'angering']
# 2 [b'paternalism', b'parliaments']
# 2 [b'specie', b'pieces']
# 2 [b'writs', b'wrist']
# 2 [b'redevelop', b'developer']
# 2 [b'pointiest', b'petitions']
# 2 [b'solider', b'soldier']
# 2 [b'signatory', b'gyrations']
# 2 [b"rectification's", b"certification's"]
# 2 [b'techs', b'chest']
# 2 [b'cleats', b'castle']
# 2 [b'shall', b'halls']
# 2 [b"tang's", b"gnat's"]
# 2 [b"parasite's", b"aspirate's"]
# 2 [b"sealer's", b"resale's"]
# 2 [b'heartier', b'earthier']
# 2 [b'shorn', b'horns']
# 2 [b'sips', b'piss']
# 2 [b'skiers', b'kisser']
# 3 [b'spiel', b'plies', b'piles']
# 2 [b'tripods', b'disport']
# 2 [b'pleaded', b'pedaled']
# 2 [b'securer', b'rescuer']
# 2 [b"stone's", b"onset's"]
# 2 [b'vectors', b'coverts']
# 2 [b'patching', b'nightcap']
# 2 [b'liberal', b'braille']
# 2 [b'valence', b'enclave']
# 2 [b"urn's", b"run's"]
# 2 [b'trisected', b'directest']
# 2 [b'peek', b'keep']
# 2 [b'naked', b'knead']
# 5 [b'tasering', b'rangiest', b'ingrates', b'gantries', b'angriest']
# 2 [b'spasm', b'spams']
# 2 [b'trifling', b'flirting']
# 3 [b'recap', b'crape', b'caper']
# 2 [b'Molnar', b'Marlon']
# 3 [b'seams', b'sames', b'mesas']
# 2 [b'wriggles', b'wigglers']
# 2 [b'papal', b'appal']
# 2 [b'saree', b'erase']
# 2 [b'tablet', b'battle']
# 2 [b'earliest', b'ateliers']
# 2 [b'rearmed', b'dreamer']
# 2 [b'laurels', b'allures']
# 2 [b'remade', b'reamed']
# 2 [b'wriggle', b'wiggler']
# 2 [b"insect's", b"incest's"]
# 2 [b'manhunts', b'huntsman']
# 3 [b'solemn', b'melons', b'lemons']
# 2 [b'wonder', b'downer']
# 2 [b'float', b'aloft']
# 2 [b'sedition', b'editions']
# 2 [b'unblocks', b'sunblock']
# 2 [b"fo'c'sle's", b"fo'c's'les"]
# 2 [b'shaped', b'phased']
# 2 [b'pliant', b'plaint']
# 4 [b'names', b'means', b'manse', b'manes']
# 2 [b'feared', b'deafer']
# 2 [b"tool's", b"loot's"]
# 2 [b"Clara's", b"Carla's"]
# 3 [b'trellis', b'tillers', b'stiller']
# 2 [b"shrike's", b"shriek's"]
# 2 [b'impinged', b'impeding']
# 3 [b"timer's", b"miter's", b"merit's"]
# 4 [b'shank', b'khans', b'hanks', b'ankhs']
# 2 [b'slough', b'ghouls']
# 2 [b'secure', b'rescue']
# 2 [b'trailer', b'retrial']
# 2 [b'fresco', b'forces']
# 2 [b'straiten', b'nitrates']
# 2 [b'Georgina', b'Georgian']
# 2 [b'dances', b'ascend']
# 2 [b'ribbing', b'bribing']
# 2 [b'comrade', b'caromed']
# 2 [b'knees', b'keens']
# 3 [b'terns', b'stern', b'rents']
# 2 [b'edify', b'deify']
# 2 [b'Donnie', b'Dionne']
# 2 [b'lupines', b'lineups']
# 4 [b'time', b'mite', b'item', b'emit']
# 2 [b'freaks', b'fakers']
# 2 [b'war', b'raw']
# 2 [b'freshets', b'freshest']
# 2 [b'usurpers', b'pursuers']
# 2 [b'law', b'awl']
# 2 [b'edification', b'deification']
# 2 [b'tapirs', b'rapist']
# 4 [b'prated', b'petard', b'parted', b'depart']
# 2 [b'spoliation', b'positional']
# 2 [b'some', b'emos']
# 3 [b'wolfing', b'fowling', b'flowing']
# 2 [b'tike', b'kite']
# 2 [b'misdealt', b'medalist']
# 3 [b"stripe's", b"sprite's", b"priest's"]
# 2 [b'overlays', b'layovers']
# 2 [b'skipper', b'kippers']
# 2 [b"Brian's", b"Brain's"]
# 2 [b"teardrop's", b"predator's"]
# 2 [b'pended', b'depend']
# 2 [b'sappier', b'apprise']
# 2 [b'lapped', b'dapple']
# 2 [b'golf', b'flog']
# 2 [b'bobbling', b'blobbing']
# 2 [b'sings', b'signs']
# 2 [b'viewers', b'reviews']
# 2 [b"ordeal's", b"loader's"]
# 2 [b"Moreno's", b"Monroe's"]
# 2 [b'slivering', b'silvering']
# 4 [b'ranged', b'garden', b'gander', b'danger']
# 2 [b'neat', b'ante']
# 2 [b'iffiest', b'fifties']
# 2 [b'rambled', b'marbled']
# 2 [b"Cornelia's", b"Caroline's"]
# 2 [b"Tutsi's", b"Titus's"]
# 2 [b'obsess', b'bosses']
# 2 [b'positioned', b'deposition']
# 2 [b'touts', b'stout']
# 2 [b"ode's", b"doe's"]
# 2 [b'tile', b'lite']
# 2 [b"Stendhal's", b"Shetland's"]
# 2 [b'procurers', b'precursor']
# 2 [b'squatter', b'quartets']
# 2 [b'lighted', b'delight']
# 2 [b'redesigns', b'designers']
# 2 [b"curd's", b"crud's"]
# 2 [b"soil's", b"silo's"]
# 2 [b'gringo', b'goring']
# 2 [b'scowl', b'cowls']
# 2 [b'slob', b'lobs']
# 2 [b'goslings', b'glossing']
# 3 [b'shape', b'phase', b'heaps']
# 2 [b"storey's", b"oyster's"]
# 2 [b"heartiness's", b"earthiness's"]
# 2 [b'biased', b'abides']
# 2 [b'initiated', b'dietitian']
# 2 [b'ordains', b'inroads']
# 2 [b'drives', b'divers']
# 2 [b"lather's", b"halter's"]
# 2 [b'lobes', b'boles']
# 2 [b'pimentos', b'nepotism']
# 2 [b"worse's", b"sower's"]
# 2 [b"nude's", b"dune's"]
# 2 [b'sectionals', b'coastlines']
# 2 [b"lurch's", b"churl's"]
# 2 [b'slinking', b'inklings']
# 3 [b'retinal', b'reliant', b'latrine']
# 2 [b'stockier', b'rockiest']
# 2 [b'elbows', b'bowels']
# 2 [b"pose's", b"peso's"]
# 2 [b'vapes', b'paves']
# 2 [b'melded', b'meddle']
# 3 [b'sager', b'rages', b'gears']
# 2 [b'colts', b'clots']
# 2 [b'suppler', b'purples']
# 2 [b'Armenian', b'Annmarie']
# 2 [b'bowler', b'blower']
# 2 [b'exits', b'exist']
# 2 [b'veriest', b'restive']
# 2 [b'riffing', b'griffin']
# 2 [b'conversation', b'conservation']
# 2 [b'tots', b'tost']
# 2 [b'totalling', b'allotting']
# 3 [b'tasked', b'staked', b'skated']
# 2 [b'toughs', b'sought']
# 2 [b'tail', b'alit']
# 2 [b'potash', b'pathos']
# 2 [b'tensed', b'nested']
# 2 [b'scorers', b'crosser']
# 2 [b'overcast', b'overacts']
# 2 [b"trappings's", b"strapping's"]
# 2 [b'chaster', b'archest']
# 2 [b'wikis', b'kiwis']
# 2 [b'rentals', b'antlers']
# 2 [b'outlooks', b'lookouts']
# 2 [b'mischance', b'mechanics']
# 2 [b'ref', b'fer']
# 3 [b'teachers', b'hectares', b'cheaters']
# 2 [b'ode', b'doe']
# 2 [b'ugliest', b'gluiest']
# 2 [b'Forster', b'Forrest']
# 2 [b"Micheal's", b"Michael's"]
# 2 [b'rename', b'meaner']
# 3 [b"replay's", b"player's", b"parley's"]
# 2 [b'toed', b'dote']
# 2 [b"rule's", b"lure's"]
# 2 [b'harboring', b'abhorring']
# 2 [b'desecration', b'considerate']
# 2 [b'formed', b'deform']
# 2 [b'nitrate', b'nattier']
# 2 [b'crash', b'chars']
# 2 [b'breaded', b'bearded']
# 3 [b'relay', b'layer', b'early']
# 2 [b'was', b'saw']
# 2 [b'quite', b'quiet']
# 2 [b"gob's", b"bog's"]
# 2 [b'schema', b'sachem']
# 2 [b"beta's", b"beat's"]
# 3 [b'psalm', b'palms', b'lamps']
# 2 [b'milf', b'film']
# 3 [b'slot', b'lots', b'lost']
# 2 [b'repays', b'payers']
# 3 [b'timings', b'smiting', b'misting']
# 2 [b'caged', b'cadge']
# 2 [b"Roman's", b"Ramon's"]
# 2 [b"wrestle's", b"swelter's"]
# 2 [b'yeps', b'espy']
# 2 [b'smit', b'mist']
# 3 [b'stories', b'sorties', b'rosiest']
# 2 [b"searcher's", b"research's"]
# 3 [b'revile', b'relive', b'eviler']
# 2 [b'drooled', b'doodler']
# 2 [b'fiber', b'brief']
# 2 [b'score', b'cores']
# 2 [b'nibs', b'bins']
# 2 [b'strays', b'satyrs']
# 2 [b'solid', b'idols']
# 2 [b"Stone's", b"Seton's"]
# 2 [b'rockets', b'restock']
# 2 [b"poem's", b"mope's"]
# 5 [b'sera', b'sear', b'eras', b'ears', b'ares']
# 2 [b"scat's", b"cast's"]
# 2 [b"sphere's", b"herpes's"]
# 3 [b'veined', b'envied', b'endive']
# 2 [b'resinous', b'neurosis']
# 2 [b"goitre's", b"goiter's"]
# 2 [b'ti', b'it']
# 2 [b"Marta's", b"Marat's"]
# 2 [b'tarpon', b'patron']
# 2 [b'rectifying', b'certifying']
# 2 [b'coral', b'carol']
# 2 [b'toast', b'stoat']
# 2 [b'scad', b'cads']
# 2 [b'sip', b'pis']
# 2 [b'talkers', b'stalker']
# 2 [b'sleeping', b'peelings']
# 2 [b"trinket's", b"knitter's"]
# 2 [b'wed', b'dew']
# 2 [b"Bengali's", b"Belgian's"]
# 3 [b"tire's", b"tier's", b"rite's"]
# 2 [b'inters', b'insert']
# 2 [b'nail', b'lain']
# 2 [b'moonstone', b'monotones']
# 2 [b'maxes', b'exams']
# 2 [b'latrines', b'entrails']
# 2 [b'granted', b'dragnet']
# 2 [b'testifies', b'feistiest']
# 2 [b'zoned', b'dozen']
# 2 [b'refined', b'definer']
# 4 [b'raped', b'pared', b'padre', b'drape']
# 2 [b'snores', b'sensor']
# 2 [b'wildness', b'swindles']
# 2 [b'gifted', b'fidget']
# 2 [b'endued', b'denude']
# 2 [b'found', b'fondu']
# 2 [b"worth's", b"throw's"]
# 3 [b'eluded', b'dueled', b'delude']
# 2 [b'trusts', b'struts']
# 4 [b'taps', b'spat', b'pats', b'past']

# %%
# !killall redis-server
